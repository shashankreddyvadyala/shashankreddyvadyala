# %%
import random
import pandas as pd
from sqlalchemy import create_engine

def coss_prd(username='', password='', DB='', ASR=0, AG=0, AN=0, S=0, N=0, BS=0, T=(), P=(), BR=0, brf=0, Table='TEMP_ALLOC_DAT_TBL', dsout='Alloc', seed=0):
    # Set up local variables
    i = 0
    grpfmt = ""
    allocfmt = ""
    blkfmt = ""
    TrtNo = 0
    Grps = ""
    GrpNo = 0
    Blocks = 0
    Total = 0
    endno = 0
    colen = 0
    cfmt = ""

    # Validate parameter AN (>=4)
    allocfmt = f'z{AN}'
    grpfmt = 'z4.'
    if AN < 4:
        print("Length of CID number must be at least 4.")
        return

    # Validate parameters T and P
    TrtNo = len(T)
    if TrtNo != len(P):
        print("Number of treatment regimen ratios must match number of treatment regimens.")
        return

    if TrtNo == 0:
        print("There must be at least one treatment regimen.")
        return

    # Validate parameter N
    if N < BS:
        print("Total CID number must be no less than blocking factor.")
        return

    # Validate assumption 5
    GrpNo = 0
    for i in range(TrtNo):
        GrpNo += P[i]

    if BS % GrpNo != 0:
        print("Blocking size is not a multiple of the sum of treatment regimen ratios.")
        return

    # Validate assumption 6
    if (S + N - 10 ** AN) > 0:
        bigN = "9" * AN
        print(f"Total CID number N={N} exceeds the capacity between {S} and {bigN}")
        return

    # Derive macro variables
    total = BS * ((N + BS - 1) // BS)
    Blocks = total // BS
    EndNo = N + S - 1
    colen = AN
    cfmt = colen + brf

    # Derive and validate Block No# parameters
    ln = 996 // cfmt
    blockmin = BR
    blockmax = blockmin + Blocks - 1
    blkfmt = f'z{brf}'
    bsiz = len(str(BR))
    if bsiz != brf:
        print("Length of Block No# range must match the size given.")
        return

    # Generate and insert component schedules into a DataFrame
    schedules = []

    if total == BS and BS > 1000:
        GrpNo = BS // GrpNo

        for i in range(TrtNo):
            P[i] = GrpNo * P[i]

        for i in range(TrtNo):
            for block_no in range(blockmin, blockmax + 1):
                GROUP = T[i]
                for _ in range(P[i]):
                    ran = random.random()
                    schedules.append((ASR, AG, AN, block_no, S))
    else:
        for k in range(BS // GrpNo):
            for i in range(TrtNo):
                for j in range(P[i]):
                    Grps += T[i]

        for block_no in range(blockmin, blockmax + 1):
            for i in range(BS):
                ran = random.random()
                schedules.append((ASR, AG, random.randint(1, AN), block_no, S))
                S += 1

    # Create a DataFrame from the generated data
    df = pd.DataFrame(schedules, columns=['ASR', 'AG', 'AN', 'BlockNo', 'Alloc'])

    # Establish a database connection using SQLAlchemy
    engine = create_engine(f'oracle://{username}:{password}@{DB}')

    # Insert the DataFrame into the Oracle database table
    df.to_sql(Table, con=engine, if_exists='replace', index=False)

    # Optional: Generate summary reports using Pandas functions

    # Optional: Handle errors and generate error messages if needed
    print("Process completed successfully.")

# Example usage:
#coss_prd(username='your_username', password='your_password', DB='your_database_connection', ASR=123, AG=456, AN=789, S=1, N=1000, BS=100, T=[1, 2], P=[0.6, 0.4], BR=1, brf=9, Table='YourTableName')

# %%
import random
import pandas as pd

def coss_prd(ASR='', AG='', AN=0, S=0, N=0, BS=0, T='', P='', BR='', brf='', Table='TEMP_ALLOC_DAT_TBL', dsout='Alloc', seed=0):
    # Convert input parameters to appropriate types
    ASR = str(ASR)
    AG = str(AG)
    AN = int(AN)
    S = int(S)
    N = int(N)
    BS = int(BS)
    T = [int(t) for t in T.split()]
    P = [int(p) for p in P.split()]
    BR = str(BR)
    brf = str(brf)
    seed = int(seed)

    # Initialize local variables
    endno = N
    allocfmt = f'z{AN}.'
    grpfmt = 'z4.'
    TrtNo = len(P)

    # Check if the number of treatment regimen ratios matches the number of treatment regimens
    if TrtNo != len(T):
        print("Number of treatment regimen ratios must match the number of treatment regimens.")
        return

    # Check if there is at least one treatment regimen
    if TrtNo == 0:
        print("There must be at least one treatment regimen.")
        return

    # Check if N is greater than or equal to BS
    if N < BS:
        print("Total CID number must be no less than blocking factor.")
        return

    GrpNo = 0

    # Calculate the sum of treatment regimen ratios
    for i in range(TrtNo):
        grp_name = f'grp{P[i]}'
        globals()[grp_name] = P[i]
        GrpNo += P[i]

    # Check if BS is a multiple of the sum of treatment regimen ratios
    if BS % GrpNo != 0:
        print("Blocking size is not a multiple of the sum of treatment regimen ratios.")
        return

    # Check if N exceeds the capacity between S and 10^AN
    if S + N - 10**AN > 0:
        print(f"Total CID number N={N} exceeds the capacity between {S} and 10^{AN}")
        return

    # Calculate various parameters
    total = BS * ((N + BS - 1) // BS)
    Blocks = total // BS
    EndNo = N + S - 1
    colen = AN
    cfmt = colen + int(brf)

    ln = 996 // cfmt
    blockmin = int(BR)
    blockmax = blockmin + Blocks - 1
    blkfmt = f'z{int(brf)}.'
    bsiz = len(BR)

    # Check if the length of Block No# range matches the size given
    if bsiz != int(brf):
        print("Length of Block No# range must match the size given.")
        return

    # Check if total is equal to BS and BS is greater than 1000
    if total == BS and BS > 1000:
        Grpno = BS // GrpNo

        # Generate schedule data
        schedule_data = []
        for i in range(TrtNo):
            for block_no in range(blockmin, blockmax + 1):
                GROUP = f"Trt{T[i]}"
                for _ in range(grpno * P[i]):
                    ran = random.uniform(0, 1)
                    schedule_data.append((ASR, block_no, AG, GROUP, ran))

        # Create a DataFrame
        df = pd.DataFrame(schedule_data, columns=['ASR', 'block_no', 'AG', 'GROUP', 'ran'])

        # Additional processing or output as needed
        print(df)

    else:
        Grps = ""
        for k in range(BS // GrpNo):
            for i in range(TrtNo):
                for j in range(P[i]):
                    Grps += f" Trt{T[i]}"

        # Generate schedule data
        schedule_data = []
        alloc = S
        for block_no in range(blockmin, blockmax + 1):
            for _ in range(BS):
                ran = random.uniform(0, 1)
                schedule_data.append((ASR, block_no, AG, Grps.strip(), alloc, ran))
                alloc += 1

        # Create a DataFrame
        df = pd.DataFrame(schedule_data, columns=['ASR', 'block_no', 'AG', 'GROUP', 'alloc', 'ran'])

        # Additional processing or output as needed
        print(df)

# Sample data for testing
sample_data = {
    'ASR': 'ASR123',
    'AG': 'AG456',
    'AN': 6,
    'S': 1000,
    'N': 1000010,
    'BS': 60,
    'T': '1 2',
    'P': '20 40',
    'BR': '001',
    'brf': '3',
    'seed': 12345,
}

# Call the coss_prd function with the sample data
coss_prd(**sample_data)
# Out:
# Total CID number N=1000010 exceeds the capacity between 1000 and 10^6

# %%
import random

def coss_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, seed=0):
    schedules = []

    # Calculate the total number of schedules
    total_schedules = BS * ((N + BS - 1) // BS)

    # Check if the total CID number exceeds the capacity
    if N > 10 ** AN:
        print(f"Total CID number N={N} exceeds the capacity between {S} and {10 ** AN}")
        return schedules

    # Check if the blocking size is a multiple of the sum of treatment regimen ratios
    TrtNo = len(P)
    if TrtNo != len(T):
        print("Number of treatment regimen ratios must match the number of treatment regimens.")
        return schedules

    # Calculate the sum of treatment regimen ratios
    GrpNo = sum(P)

    # Check if the blocking size is a multiple of the sum of treatment regimen ratios
    if BS % GrpNo != 0:
        print("Blocking size is not a multiple of the sum of treatment regimen ratios.")
        return schedules

    # Generate schedules
    for block_no in range(BR, BR + (total_schedules // BS)):
        for i in range(TrtNo):
            for j in range(P[i]):
                ASR_schedule = ASR
                AG_schedule = AG
                block_schedule = block_no
                S_schedule = S + random.randint(0, 10 ** AN - 1)
                schedules.append((ASR_schedule, AG_schedule, AN, block_schedule, S_schedule))

    return schedules

if __name__ == "__main__":
    # Sample data
    sample_data = {
    "ASR": "ASR001",
    "AG": "AG123",
    "AN": 6,
    "S": 1000,
    "N": 1000000,  # Adjusted N value
    "BS": 1000,
    "T": [1, 2, 1],
    "P": [1, 2, 1],
    "BR": 5,
    "brf": 2,
}

    # Call the coss_prd function with the sample data
    schedules = coss_prd(**sample_data)

    # Further processing logic here (use the 'schedules' list)
    if schedules:
        print("Generated Schedules:")
        for schedule in schedules:
            ASR, AG, AN, block_no, S = schedule
            print(f"ASR: {ASR}, AG: {AG}, AN: {AN}, Block No: {block_no}, S: {S}")
# Out:
# Generated Schedules:
# ASR: ASR001, AG: AG123, AN: 6, Block No: 5, S: 213936
# ASR: ASR001, AG: AG123, AN: 6, Block No: 5, S: 616437
# ASR: ASR001, AG: AG123, AN: 6, Block No: 5, S: 618950
# ASR: ASR001, AG: AG123, AN: 6, Block No: 5, S: 169312
# ASR: ASR001, AG: AG123, AN: 6, Block No: 6, S: 571102
# ASR: ASR001, AG: AG123, AN: 6, Block No: 6, S: 112154
# ASR: ASR001, AG: AG123, AN: 6, Block No: 6, S: 523938
# ASR: ASR001, AG: AG123, AN: 6, Block No: 6, S: 885970
# ASR: ASR001, AG: AG123, AN: 6, Block No: 7, S: 961934
# ASR: ASR001, AG: AG123, AN: 6, Block No: 7, S: 345810
# ASR: ASR001, AG: AG123, AN: 6, Block No: 7, S: 145416
# ASR: ASR001, AG: AG123, AN: 6, Block No: 7, S: 914404
# ASR: ASR001, AG: AG123, AN: 6, Block No: 8, S: 311785
# ASR: ASR001, AG: AG123, AN: 6, Block No: 8, S: 348123
# ASR: ASR001, AG: AG123, AN: 6, Block No: 8, S: 206086
# ASR: ASR001, AG: AG123, AN: 6, Block No: 8, S: 978568
# ASR: ASR001, AG: AG123, AN: 6, Block No: 9, S: 702239
# ASR: ASR001, AG: AG123, AN: 6, Block No: 9, S: 576390
# ASR: ASR001, AG: AG123, AN: 6, Block No: 9, S: 107940
# ASR: ASR001, AG: AG123, AN: 6, Block No: 9, S: 563807
# ASR: ASR001, AG: AG123, AN: 6, Block No: 10, S: 529533
# ASR: ASR001, AG: AG123, AN: 6, Block No: 10, S: 719073
# ASR: ASR001, AG: AG123, AN: 6, Block No: 10, S: 433569
# ASR: ASR001, AG: AG123, AN: 6, Block No: 10, S: 988685
# ASR: ASR001, AG: AG123, AN: 6, Block No: 11, S: 488876
# ASR: ASR001, AG: AG123, AN: 6, Block No: 11, S: 220923
# ASR: ASR001, AG: AG123, AN: 6, Block No: 11, S: 585901
# ASR: ASR001, AG: AG123, AN: 6, Block No: 11, S: 87818
# ASR: ASR001, AG: AG123, AN: 6, Block No: 12, S: 940651
# ASR: ASR001, AG: AG123, AN: 6, Block No: 12, S: 682818
# ASR: ASR001, AG: AG123, AN: 6, Block No: 12, S: 768704
# ASR: ASR001, AG: AG123, AN: 6, Block No: 12, S: 751101
# ASR: ASR001, AG: AG123, AN: 6, Block No: 13, S: 515379
# ASR: ASR001, AG: AG123, AN: 6, Block No: 13, S: 307472
# ASR: ASR001, AG: AG123, AN: 6, Block No: 13, S: 290318
# ASR: ASR001, AG: AG123, AN: 6, Block No: 13, S: 873638
# ASR: ASR001, AG: AG123, AN: 6, Block No: 14, S: 930148
# ASR: ASR001, AG: AG123, AN: 6, Block No: 14, S: 328170
# ASR: ASR001, AG: AG123, AN: 6, Block No: 14, S: 545623
# ASR: ASR001, AG: AG123, AN: 6, Block No: 14, S: 295434
# ASR: ASR001, AG: AG123, AN: 6, Block No: 15, S: 389099
# ASR: ASR001, AG: AG123, AN: 6, Block No: 15, S: 773749
# ASR: ASR001, AG: AG123, AN: 6, Block No: 15, S: 344817
# ASR: ASR001, AG: AG123, AN: 6, Block No: 15, S: 327306
# ASR: ASR001, AG: AG123, AN: 6, Block No: 16, S: 999752
# ASR: ASR001, AG: AG123, AN: 6, Block No: 16, S: 864142
# ASR: ASR001, AG: AG123, AN: 6, Block No: 16, S: 224309
# ASR: ASR001, AG: AG123, AN: 6, Block No: 16, S: 689703
# ASR: ASR001, AG: AG123, AN: 6, Block No: 17, S: 782562
# ASR: ASR001, AG: AG123, AN: 6, Block No: 17, S: 404537
# ASR: ASR001, AG: AG123, AN: 6, Block No: 17, S: 758773
# ASR: ASR001, AG: AG123, AN: 6, Block No: 17, S: 930327
# ASR: ASR001, AG: AG123, AN: 6, Block No: 18, S: 926755
# ASR: ASR001, AG: AG123, AN: 6, Block No: 18, S: 461861
# ASR: ASR001, AG: AG123, AN: 6, Block No: 18, S: 51155
# ASR: ASR001, AG: AG123, AN: 6, Block No: 18, S: 385707
# ASR: ASR001, AG: AG123, AN: 6, Block No: 19, S: 136995
# ASR: ASR001, AG: AG123, AN: 6, Block No: 19, S: 231468
# ASR: ASR001, AG: AG123, AN: 6, Block No: 19, S: 40873
# ASR: ASR001, AG: AG123, AN: 6, Block No: 19, S: 808483
# ASR: ASR001, AG: AG123, AN: 6, Block No: 20, S: 809680
# ASR: ASR001, AG: AG123, AN: 6, Block No: 20, S: 181047
# ASR: ASR001, AG: AG123, AN: 6, Block No: 20, S: 805486
# ASR: ASR001, AG: AG123, AN: 6, Block No: 20, S: 929754
# ASR: ASR001, AG: AG123, AN: 6, Block No: 21, S: 824063
# ASR: ASR001, AG: AG123, AN: 6, Block No: 21, S: 334879
# ASR: ASR001, AG: AG123, AN: 6, Block No: 21, S: 352403
# ASR: ASR001, AG: AG123, AN: 6, Block No: 21, S: 629936
# ASR: ASR001, AG: AG123, AN: 6, Block No: 22, S: 762829
# ASR: ASR001, AG: AG123, AN: 6, Block No: 22, S: 611641
# ASR: ASR001, AG: AG123, AN: 6, Block No: 22, S: 277839
# ASR: ASR001, AG: AG123, AN: 6, Block No: 22, S: 436590
# ASR: ASR001, AG: AG123, AN: 6, Block No: 23, S: 957827
# ASR: ASR001, AG: AG123, AN: 6, Block No: 23, S: 782536
# ASR: ASR001, AG: AG123, AN: 6, Block No: 23, S: 542933
# ASR: ASR001, AG: AG123, AN: 6, Block No: 23, S: 258344
# ASR: ASR001, AG: AG123, AN: 6, Block No: 24, S: 917337
# ASR: ASR001, AG: AG123, AN: 6, Block No: 24, S: 800722
# ASR: ASR001, AG: AG123, AN: 6, Block No: 24, S: 567250
# ASR: ASR001, AG: AG123, AN: 6, Block No: 24, S: 486408
# ASR: ASR001, AG: AG123, AN: 6, Block No: 25, S: 58052
# ASR: ASR001, AG: AG123, AN: 6, Block No: 25, S: 619327
# ASR: ASR001, AG: AG123, AN: 6, Block No: 25, S: 231310
# ASR: ASR001, AG: AG123, AN: 6, Block No: 25, S: 758896
# ASR: ASR001, AG: AG123, AN: 6, Block No: 26, S: 517398
# ASR: ASR001, AG: AG123, AN: 6, Block No: 26, S: 967477
# ASR: ASR001, AG: AG123, AN: 6, Block No: 26, S: 839465
# ASR: ASR001, AG: AG123, AN: 6, Block No: 26, S: 723485
# ASR: ASR001, AG: AG123, AN: 6, Block No: 27, S: 184678
# ASR: ASR001, AG: AG123, AN: 6, Block No: 27, S: 748127
# ASR: ASR001, AG: AG123, AN: 6, Block No: 27, S: 1249
# ASR: ASR001, AG: AG123, AN: 6, Block No: 27, S: 214078
# ASR: ASR001, AG: AG123, AN: 6, Block No: 28, S: 824316
# ASR: ASR001, AG: AG123, AN: 6, Block No: 28, S: 207069
# ASR: ASR001, AG: AG123, AN: 6, Block No: 28, S: 799306
# ASR: ASR001, AG: AG123, AN: 6, Block No: 28, S: 359064
# ASR: ASR001, AG: AG123, AN: 6, Block No: 29, S: 662792
# ASR: ASR001, AG: AG123, AN: 6, Block No: 29, S: 845955
# ASR: ASR001, AG: AG123, AN: 6, Block No: 29, S: 612037
# ASR: ASR001, AG: AG123, AN: 6, Block No: 29, S: 47422
# ASR: ASR001, AG: AG123, AN: 6, Block No: 30, S: 397029
# ASR: ASR001, AG: AG123, AN: 6, Block No: 30, S: 805443
# ASR: ASR001, AG: AG123, AN: 6, Block No: 30, S: 579238
# ASR: ASR001, AG: AG123, AN: 6, Block No: 30, S: 384532
# ASR: ASR001, AG: AG123, AN: 6, Block No: 31, S: 964346
# ASR: ASR001, AG: AG123, AN: 6, Block No: 31, S: 602982
# ASR: ASR001, AG: AG123, AN: 6, Block No: 31, S: 380634
# ASR: ASR001, AG: AG123, AN: 6, Block No: 31, S: 226444
# ASR: ASR001, AG: AG123, AN: 6, Block No: 32, S: 116745
# ASR: ASR001, AG: AG123, AN: 6, Block No: 32, S: 469251
# ASR: ASR001, AG: AG123, AN: 6, Block No: 32, S: 875586
# ASR: ASR001, AG: AG123, AN: 6, Block No: 32, S: 973151
# ASR: ASR001, AG: AG123, AN: 6, Block No: 33, S: 21578
# ASR: ASR001, AG: AG123, AN: 6, Block No: 33, S: 310458
# ASR: ASR001, AG: AG123, AN: 6, Block No: 33, S: 837948
# ASR: ASR001, AG: AG123, AN: 6, Block No: 33, S: 243611
# ASR: ASR001, AG: AG123, AN: 6, Block No: 34, S: 359975
# ASR: ASR001, AG: AG123, AN: 6, Block No: 34, S: 380805
# ASR: ASR001, AG: AG123, AN: 6, Block No: 34, S: 241954
# ASR: ASR001, AG: AG123, AN: 6, Block No: 34, S: 511474
# ASR: ASR001, AG: AG123, AN: 6, Block No: 35, S: 772874
# ASR: ASR001, AG: AG123, AN: 6, Block No: 35, S: 646806
# ASR: ASR001, AG: AG123, AN: 6, Block No: 35, S: 585279
# ASR: ASR001, AG: AG123, AN: 6, Block No: 35, S: 694971
# ASR: ASR001, AG: AG123, AN: 6, Block No: 36, S: 397337
# ASR: ASR001, AG: AG123, AN: 6, Block No: 36, S: 37334
# ASR: ASR001, AG: AG123, AN: 6, Block No: 36, S: 848492
# ASR: ASR001, AG: AG123, AN: 6, Block No: 36, S: 491034
# ASR: ASR001, AG: AG123, AN: 6, Block No: 37, S: 803134
# ASR: ASR001, AG: AG123, AN: 6, Block No: 37, S: 254427
# ASR: ASR001, AG: AG123, AN: 6, Block No: 37, S: 795395
# ASR: ASR001, AG: AG123, AN: 6, Block No: 37, S: 872252
# ASR: ASR001, AG: AG123, AN: 6, Block No: 38, S: 193126
# ASR: ASR001, AG: AG123, AN: 6, Block No: 38, S: 625047
# ASR: ASR001, AG: AG123, AN: 6, Block No: 38, S: 613707
# ASR: ASR001, AG: AG123, AN: 6, Block No: 38, S: 237224
# ASR: ASR001, AG: AG123, AN: 6, Block No: 39, S: 844587
# ASR: ASR001, AG: AG123, AN: 6, Block No: 39, S: 695226
# ASR: ASR001, AG: AG123, AN: 6, Block No: 39, S: 911942
# ASR: ASR001, AG: AG123, AN: 6, Block No: 39, S: 323424
# ASR: ASR001, AG: AG123, AN: 6, Block No: 40, S: 258244
# ASR: ASR001, AG: AG123, AN: 6, Block No: 40, S: 38440
# ASR: ASR001, AG: AG123, AN: 6, Block No: 40, S: 270438
# ASR: ASR001, AG: AG123, AN: 6, Block No: 40, S: 348586
# ASR: ASR001, AG: AG123, AN: 6, Block No: 41, S: 307014
# ASR: ASR001, AG: AG123, AN: 6, Block No: 41, S: 991559
# ASR: ASR001, AG: AG123, AN: 6, Block No: 41, S: 813009
# ASR: ASR001, AG: AG123, AN: 6, Block No: 41, S: 408223
# ASR: ASR001, AG: AG123, AN: 6, Block No: 42, S: 200715
# ASR: ASR001, AG: AG123, AN: 6, Block No: 42, S: 781100
# ASR: ASR001, AG: AG123, AN: 6, Block No: 42, S: 1000044
# ASR: ASR001, AG: AG123, AN: 6, Block No: 42, S: 843914
# ASR: ASR001, AG: AG123, AN: 6, Block No: 43, S: 240804
# ASR: ASR001, AG: AG123, AN: 6, Block No: 43, S: 357150
# ASR: ASR001, AG: AG123, AN: 6, Block No: 43, S: 30622
# ASR: ASR001, AG: AG123, AN: 6, Block No: 43, S: 927840
# ASR: ASR001, AG: AG123, AN: 6, Block No: 44, S: 758496
# ASR: ASR001, AG: AG123, AN: 6, Block No: 44, S: 505508
# ASR: ASR001, AG: AG123, AN: 6, Block No: 44, S: 793276
# ASR: ASR001, AG: AG123, AN: 6, Block No: 44, S: 150349
# ASR: ASR001, AG: AG123, AN: 6, Block No: 45, S: 433606
# ASR: ASR001, AG: AG123, AN: 6, Block No: 45, S: 228913
# ASR: ASR001, AG: AG123, AN: 6, Block No: 45, S: 380826
# ASR: ASR001, AG: AG123, AN: 6, Block No: 45, S: 979704
# ASR: ASR001, AG: AG123, AN: 6, Block No: 46, S: 781054
# ASR: ASR001, AG: AG123, AN: 6, Block No: 46, S: 717480
# ASR: ASR001, AG: AG123, AN: 6, Block No: 46, S: 189392
# ASR: ASR001, AG: AG123, AN: 6, Block No: 46, S: 143722
# ASR: ASR001, AG: AG123, AN: 6, Block No: 47, S: 11748
# ASR: ASR001, AG: AG123, AN: 6, Block No: 47, S: 559677
# ASR: ASR001, AG: AG123, AN: 6, Block No: 47, S: 182869
# ASR: ASR001, AG: AG123, AN: 6, Block No: 47, S: 597275
# ASR: ASR001, AG: AG123, AN: 6, Block No: 48, S: 407305
# ASR: ASR001, AG: AG123, AN: 6, Block No: 48, S: 687128
# ASR: ASR001, AG: AG123, AN: 6, Block No: 48, S: 130101
# ASR: ASR001, AG: AG123, AN: 6, Block No: 48, S: 642526
# ASR: ASR001, AG: AG123, AN: 6, Block No: 49, S: 67482
# ASR: ASR001, AG: AG123, AN: 6, Block No: 49, S: 11988
# ASR: ASR001, AG: AG123, AN: 6, Block No: 49, S: 532400
# ASR: ASR001, AG: AG123, AN: 6, Block No: 49, S: 76780
# ASR: ASR001, AG: AG123, AN: 6, Block No: 50, S: 973266
# ASR: ASR001, AG: AG123, AN: 6, Block No: 50, S: 747267
# ASR: ASR001, AG: AG123, AN: 6, Block No: 50, S: 312963
# ASR: ASR001, AG: AG123, AN: 6, Block No: 50, S: 747409
# ASR: ASR001, AG: AG123, AN: 6, Block No: 51, S: 433191
# ASR: ASR001, AG: AG123, AN: 6, Block No: 51, S: 79297
# ASR: ASR001, AG: AG123, AN: 6, Block No: 51, S: 98364
# ASR: ASR001, AG: AG123, AN: 6, Block No: 51, S: 668614
# ASR: ASR001, AG: AG123, AN: 6, Block No: 52, S: 680544
# ASR: ASR001, AG: AG123, AN: 6, Block No: 52, S: 162516
# ASR: ASR001, AG: AG123, AN: 6, Block No: 52, S: 795772
# ASR: ASR001, AG: AG123, AN: 6, Block No: 52, S: 934510
# ASR: ASR001, AG: AG123, AN: 6, Block No: 53, S: 565328
# ASR: ASR001, AG: AG123, AN: 6, Block No: 53, S: 33621
# ASR: ASR001, AG: AG123, AN: 6, Block No: 53, S: 496701
# ASR: ASR001, AG: AG123, AN: 6, Block No: 53, S: 863332
# ASR: ASR001, AG: AG123, AN: 6, Block No: 54, S: 964213
# ASR: ASR001, AG: AG123, AN: 6, Block No: 54, S: 971127
# ASR: ASR001, AG: AG123, AN: 6, Block No: 54, S: 471781
# ASR: ASR001, AG: AG123, AN: 6, Block No: 54, S: 584546
# ASR: ASR001, AG: AG123, AN: 6, Block No: 55, S: 90916
# ASR: ASR001, AG: AG123, AN: 6, Block No: 55, S: 287814
# ASR: ASR001, AG: AG123, AN: 6, Block No: 55, S: 761664
# ASR: ASR001, AG: AG123, AN: 6, Block No: 55, S: 38388
# ASR: ASR001, AG: AG123, AN: 6, Block No: 56, S: 311220
# ASR: ASR001, AG: AG123, AN: 6, Block No: 56, S: 462860
# ASR: ASR001, AG: AG123, AN: 6, Block No: 56, S: 272565
# ASR: ASR001, AG: AG123, AN: 6, Block No: 56, S: 261456
# ASR: ASR001, AG: AG123, AN: 6, Block No: 57, S: 176269
# ASR: ASR001, AG: AG123, AN: 6, Block No: 57, S: 687751
# ASR: ASR001, AG: AG123, AN: 6, Block No: 57, S: 714365
# ASR: ASR001, AG: AG123, AN: 6, Block No: 57, S: 367174
# ASR: ASR001, AG: AG123, AN: 6, Block No: 58, S: 558984
# ASR: ASR001, AG: AG123, AN: 6, Block No: 58, S: 599596
# ASR: ASR001, AG: AG123, AN: 6, Block No: 58, S: 964014
# ASR: ASR001, AG: AG123, AN: 6, Block No: 58, S: 732276
# ASR: ASR001, AG: AG123, AN: 6, Block No: 59, S: 237155
# ASR: ASR001, AG: AG123, AN: 6, Block No: 59, S: 721963
# ASR: ASR001, AG: AG123, AN: 6, Block No: 59, S: 641707
# ASR: ASR001, AG: AG123, AN: 6, Block No: 59, S: 246420
# ASR: ASR001, AG: AG123, AN: 6, Block No: 60, S: 746568
# ASR: ASR001, AG: AG123, AN: 6, Block No: 60, S: 667961
# ASR: ASR001, AG: AG123, AN: 6, Block No: 60, S: 250465
# ASR: ASR001, AG: AG123, AN: 6, Block No: 60, S: 762277
# ASR: ASR001, AG: AG123, AN: 6, Block No: 61, S: 149832
# ASR: ASR001, AG: AG123, AN: 6, Block No: 61, S: 750004
# ASR: ASR001, AG: AG123, AN: 6, Block No: 61, S: 731427
# ASR: ASR001, AG: AG123, AN: 6, Block No: 61, S: 688602
# ASR: ASR001, AG: AG123, AN: 6, Block No: 62, S: 502694
# ASR: ASR001, AG: AG123, AN: 6, Block No: 62, S: 970341
# ASR: ASR001, AG: AG123, AN: 6, Block No: 62, S: 233700
# ASR: ASR001, AG: AG123, AN: 6, Block No: 62, S: 193587
# ASR: ASR001, AG: AG123, AN: 6, Block No: 63, S: 933931
# ASR: ASR001, AG: AG123, AN: 6, Block No: 63, S: 920912
# ASR: ASR001, AG: AG123, AN: 6, Block No: 63, S: 886975
# ASR: ASR001, AG: AG123, AN: 6, Block No: 63, S: 180551
# ASR: ASR001, AG: AG123, AN: 6, Block No: 64, S: 638263
# ASR: ASR001, AG: AG123, AN: 6, Block No: 64, S: 796995
# ASR: ASR001, AG: AG123, AN: 6, Block No: 64, S: 369415
# ASR: ASR001, AG: AG123, AN: 6, Block No: 64, S: 191801
# ASR: ASR001, AG: AG123, AN: 6, Block No: 65, S: 29409
# ASR: ASR001, AG: AG123, AN: 6, Block No: 65, S: 167775
# ASR: ASR001, AG: AG123, AN: 6, Block No: 65, S: 335733
# ASR: ASR001, AG: AG123, AN: 6, Block No: 65, S: 166417
# ASR: ASR001, AG: AG123, AN: 6, Block No: 66, S: 806088
# ASR: ASR001, AG: AG123, AN: 6, Block No: 66, S: 875790
# ASR: ASR001, AG: AG123, AN: 6, Block No: 66, S: 901786
# ASR: ASR001, AG: AG123, AN: 6, Block No: 66, S: 474556
# ASR: ASR001, AG: AG123, AN: 6, Block No: 67, S: 202815
# ASR: ASR001, AG: AG123, AN: 6, Block No: 67, S: 824325
# ASR: ASR001, AG: AG123, AN: 6, Block No: 67, S: 240452
# ASR: ASR001, AG: AG123, AN: 6, Block No: 67, S: 45925
# ASR: ASR001, AG: AG123, AN: 6, Block No: 68, S: 297188
# ASR: ASR001, AG: AG123, AN: 6, Block No: 68, S: 626516
# ASR: ASR001, AG: AG123, AN: 6, Block No: 68, S: 990746
# ASR: ASR001, AG: AG123, AN: 6, Block No: 68, S: 986370
# ASR: ASR001, AG: AG123, AN: 6, Block No: 69, S: 286325
# ASR: ASR001, AG: AG123, AN: 6, Block No: 69, S: 243790
# ASR: ASR001, AG: AG123, AN: 6, Block No: 69, S: 238789
# ASR: ASR001, AG: AG123, AN: 6, Block No: 69, S: 189955
# ASR: ASR001, AG: AG123, AN: 6, Block No: 70, S: 532741
# ASR: ASR001, AG: AG123, AN: 6, Block No: 70, S: 677109
# ASR: ASR001, AG: AG123, AN: 6, Block No: 70, S: 840944
# ASR: ASR001, AG: AG123, AN: 6, Block No: 70, S: 70905
# ASR: ASR001, AG: AG123, AN: 6, Block No: 71, S: 181503
# ASR: ASR001, AG: AG123, AN: 6, Block No: 71, S: 811684
# ASR: ASR001, AG: AG123, AN: 6, Block No: 71, S: 203669
# ASR: ASR001, AG: AG123, AN: 6, Block No: 71, S: 699595
# ASR: ASR001, AG: AG123, AN: 6, Block No: 72, S: 526655
# ASR: ASR001, AG: AG123, AN: 6, Block No: 72, S: 696864
# ASR: ASR001, AG: AG123, AN: 6, Block No: 72, S: 337465
# ASR: ASR001, AG: AG123, AN: 6, Block No: 72, S: 679534
# ASR: ASR001, AG: AG123, AN: 6, Block No: 73, S: 982732
# ASR: ASR001, AG: AG123, AN: 6, Block No: 73, S: 467249
# ASR: ASR001, AG: AG123, AN: 6, Block No: 73, S: 813433
# ASR: ASR001, AG: AG123, AN: 6, Block No: 73, S: 905286
# ASR: ASR001, AG: AG123, AN: 6, Block No: 74, S: 548019
# ASR: ASR001, AG: AG123, AN: 6, Block No: 74, S: 133372
# ASR: ASR001, AG: AG123, AN: 6, Block No: 74, S: 648174
# ASR: ASR001, AG: AG123, AN: 6, Block No: 74, S: 589608
# ASR: ASR001, AG: AG123, AN: 6, Block No: 75, S: 149334
# ASR: ASR001, AG: AG123, AN: 6, Block No: 75, S: 539925
# ASR: ASR001, AG: AG123, AN: 6, Block No: 75, S: 780827
# ASR: ASR001, AG: AG123, AN: 6, Block No: 75, S: 238059
# ASR: ASR001, AG: AG123, AN: 6, Block No: 76, S: 16128
# ASR: ASR001, AG: AG123, AN: 6, Block No: 76, S: 517535
# ASR: ASR001, AG: AG123, AN: 6, Block No: 76, S: 946394
# ASR: ASR001, AG: AG123, AN: 6, Block No: 76, S: 334874
# ASR: ASR001, AG: AG123, AN: 6, Block No: 77, S: 258605
# ASR: ASR001, AG: AG123, AN: 6, Block No: 77, S: 952831
# ASR: ASR001, AG: AG123, AN: 6, Block No: 77, S: 77162
# ASR: ASR001, AG: AG123, AN: 6, Block No: 77, S: 648581
# ASR: ASR001, AG: AG123, AN: 6, Block No: 78, S: 886630
# ASR: ASR001, AG: AG123, AN: 6, Block No: 78, S: 50894
# ASR: ASR001, AG: AG123, AN: 6, Block No: 78, S: 160345
# ASR: ASR001, AG: AG123, AN: 6, Block No: 78, S: 761635
# ASR: ASR001, AG: AG123, AN: 6, Block No: 79, S: 338089
# ASR: ASR001, AG: AG123, AN: 6, Block No: 79, S: 358629
# ASR: ASR001, AG: AG123, AN: 6, Block No: 79, S: 499672
# ASR: ASR001, AG: AG123, AN: 6, Block No: 79, S: 123678
# ASR: ASR001, AG: AG123, AN: 6, Block No: 80, S: 885851
# ASR: ASR001, AG: AG123, AN: 6, Block No: 80, S: 594845
# ASR: ASR001, AG: AG123, AN: 6, Block No: 80, S: 663534
# ASR: ASR001, AG: AG123, AN: 6, Block No: 80, S: 484526
# ASR: ASR001, AG: AG123, AN: 6, Block No: 81, S: 12039
# ASR: ASR001, AG: AG123, AN: 6, Block No: 81, S: 556153
# ASR: ASR001, AG: AG123, AN: 6, Block No: 81, S: 829913
# ASR: ASR001, AG: AG123, AN: 6, Block No: 81, S: 969691
# ASR: ASR001, AG: AG123, AN: 6, Block No: 82, S: 994587
# ASR: ASR001, AG: AG123, AN: 6, Block No: 82, S: 211621
# ASR: ASR001, AG: AG123, AN: 6, Block No: 82, S: 765127
# ASR: ASR001, AG: AG123, AN: 6, Block No: 82, S: 86029
# ASR: ASR001, AG: AG123, AN: 6, Block No: 83, S: 810525
# ASR: ASR001, AG: AG123, AN: 6, Block No: 83, S: 216333
# ASR: ASR001, AG: AG123, AN: 6, Block No: 83, S: 528439
# ASR: ASR001, AG: AG123, AN: 6, Block No: 83, S: 587186
# ASR: ASR001, AG: AG123, AN: 6, Block No: 84, S: 714599
# ASR: ASR001, AG: AG123, AN: 6, Block No: 84, S: 717370
# ASR: ASR001, AG: AG123, AN: 6, Block No: 84, S: 959485
# ASR: ASR001, AG: AG123, AN: 6, Block No: 84, S: 845896
# ASR: ASR001, AG: AG123, AN: 6, Block No: 85, S: 323722
# ASR: ASR001, AG: AG123, AN: 6, Block No: 85, S: 477087
# ASR: ASR001, AG: AG123, AN: 6, Block No: 85, S: 62314
# ASR: ASR001, AG: AG123, AN: 6, Block No: 85, S: 693079
# ASR: ASR001, AG: AG123, AN: 6, Block No: 86, S: 575899
# ASR: ASR001, AG: AG123, AN: 6, Block No: 86, S: 213666
# ASR: ASR001, AG: AG123, AN: 6, Block No: 86, S: 444378
# ASR: ASR001, AG: AG123, AN: 6, Block No: 86, S: 769106
# ASR: ASR001, AG: AG123, AN: 6, Block No: 87, S: 92336
# ASR: ASR001, AG: AG123, AN: 6, Block No: 87, S: 510811
# ASR: ASR001, AG: AG123, AN: 6, Block No: 87, S: 616178
# ASR: ASR001, AG: AG123, AN: 6, Block No: 87, S: 880221
# ASR: ASR001, AG: AG123, AN: 6, Block No: 88, S: 280415
# ASR: ASR001, AG: AG123, AN: 6, Block No: 88, S: 463577
# ASR: ASR001, AG: AG123, AN: 6, Block No: 88, S: 531247
# ASR: ASR001, AG: AG123, AN: 6, Block No: 88, S: 272356
# ASR: ASR001, AG: AG123, AN: 6, Block No: 89, S: 321343
# ASR: ASR001, AG: AG123, AN: 6, Block No: 89, S: 295263
# ASR: ASR001, AG: AG123, AN: 6, Block No: 89, S: 864344
# ASR: ASR001, AG: AG123, AN: 6, Block No: 89, S: 8494
# ASR: ASR001, AG: AG123, AN: 6, Block No: 90, S: 817715
# ASR: ASR001, AG: AG123, AN: 6, Block No: 90, S: 733867
# ASR: ASR001, AG: AG123, AN: 6, Block No: 90, S: 906193
# ASR: ASR001, AG: AG123, AN: 6, Block No: 90, S: 703827
# ASR: ASR001, AG: AG123, AN: 6, Block No: 91, S: 246953
# ASR: ASR001, AG: AG123, AN: 6, Block No: 91, S: 763255
# ASR: ASR001, AG: AG123, AN: 6, Block No: 91, S: 40756
# ASR: ASR001, AG: AG123, AN: 6, Block No: 91, S: 749183
# ASR: ASR001, AG: AG123, AN: 6, Block No: 92, S: 305177
# ASR: ASR001, AG: AG123, AN: 6, Block No: 92, S: 776589
# ASR: ASR001, AG: AG123, AN: 6, Block No: 92, S: 272572
# ASR: ASR001, AG: AG123, AN: 6, Block No: 92, S: 220599
# ASR: ASR001, AG: AG123, AN: 6, Block No: 93, S: 356621
# ASR: ASR001, AG: AG123, AN: 6, Block No: 93, S: 107482
# ASR: ASR001, AG: AG123, AN: 6, Block No: 93, S: 844483
# ASR: ASR001, AG: AG123, AN: 6, Block No: 93, S: 732505
# ASR: ASR001, AG: AG123, AN: 6, Block No: 94, S: 725013
# ASR: ASR001, AG: AG123, AN: 6, Block No: 94, S: 86774
# ASR: ASR001, AG: AG123, AN: 6, Block No: 94, S: 541974
# ASR: ASR001, AG: AG123, AN: 6, Block No: 94, S: 218040
# ASR: ASR001, AG: AG123, AN: 6, Block No: 95, S: 458532
# ASR: ASR001, AG: AG123, AN: 6, Block No: 95, S: 772272
# ASR: ASR001, AG: AG123, AN: 6, Block No: 95, S: 819746
# ASR: ASR001, AG: AG123, AN: 6, Block No: 95, S: 524998
# ASR: ASR001, AG: AG123, AN: 6, Block No: 96, S: 999756
# ASR: ASR001, AG: AG123, AN: 6, Block No: 96, S: 321318
# ASR: ASR001, AG: AG123, AN: 6, Block No: 96, S: 746915
# ASR: ASR001, AG: AG123, AN: 6, Block No: 96, S: 685812
# ASR: ASR001, AG: AG123, AN: 6, Block No: 97, S: 751196
# ASR: ASR001, AG: AG123, AN: 6, Block No: 97, S: 724084
# ASR: ASR001, AG: AG123, AN: 6, Block No: 97, S: 167888
# ASR: ASR001, AG: AG123, AN: 6, Block No: 97, S: 624070
# ASR: ASR001, AG: AG123, AN: 6, Block No: 98, S: 83652
# ASR: ASR001, AG: AG123, AN: 6, Block No: 98, S: 503020
# ASR: ASR001, AG: AG123, AN: 6, Block No: 98, S: 271711
# ASR: ASR001, AG: AG123, AN: 6, Block No: 98, S: 379737
# ASR: ASR001, AG: AG123, AN: 6, Block No: 99, S: 261434
# ASR: ASR001, AG: AG123, AN: 6, Block No: 99, S: 479485
# ASR: ASR001, AG: AG123, AN: 6, Block No: 99, S: 679218
# ASR: ASR001, AG: AG123, AN: 6, Block No: 99, S: 854001
# ASR: ASR001, AG: AG123, AN: 6, Block No: 100, S: 833765
# ASR: ASR001, AG: AG123, AN: 6, Block No: 100, S: 189603
# ASR: ASR001, AG: AG123, AN: 6, Block No: 100, S: 469837
# ASR: ASR001, AG: AG123, AN: 6, Block No: 100, S: 987642
# ASR: ASR001, AG: AG123, AN: 6, Block No: 101, S: 464093
# ASR: ASR001, AG: AG123, AN: 6, Block No: 101, S: 790569
# ASR: ASR001, AG: AG123, AN: 6, Block No: 101, S: 633007
# ASR: ASR001, AG: AG123, AN: 6, Block No: 101, S: 795455
# ASR: ASR001, AG: AG123, AN: 6, Block No: 102, S: 463045
# ASR: ASR001, AG: AG123, AN: 6, Block No: 102, S: 376200
# ASR: ASR001, AG: AG123, AN: 6, Block No: 102, S: 937608
# ASR: ASR001, AG: AG123, AN: 6, Block No: 102, S: 750978
# ASR: ASR001, AG: AG123, AN: 6, Block No: 103, S: 973352
# ASR: ASR001, AG: AG123, AN: 6, Block No: 103, S: 975653
# ASR: ASR001, AG: AG123, AN: 6, Block No: 103, S: 365528
# ASR: ASR001, AG: AG123, AN: 6, Block No: 103, S: 414621
# ASR: ASR001, AG: AG123, AN: 6, Block No: 104, S: 573302
# ASR: ASR001, AG: AG123, AN: 6, Block No: 104, S: 805198
# ASR: ASR001, AG: AG123, AN: 6, Block No: 104, S: 442978
# ASR: ASR001, AG: AG123, AN: 6, Block No: 104, S: 432818
# ASR: ASR001, AG: AG123, AN: 6, Block No: 105, S: 486316
# ASR: ASR001, AG: AG123, AN: 6, Block No: 105, S: 798728
# ASR: ASR001, AG: AG123, AN: 6, Block No: 105, S: 455652
# ASR: ASR001, AG: AG123, AN: 6, Block No: 105, S: 99553
# ASR: ASR001, AG: AG123, AN: 6, Block No: 106, S: 936072
# ASR: ASR001, AG: AG123, AN: 6, Block No: 106, S: 173332
# ASR: ASR001, AG: AG123, AN: 6, Block No: 106, S: 946891
# ASR: ASR001, AG: AG123, AN: 6, Block No: 106, S: 134892
# ASR: ASR001, AG: AG123, AN: 6, Block No: 107, S: 311492
# ASR: ASR001, AG: AG123, AN: 6, Block No: 107, S: 417089
# ASR: ASR001, AG: AG123, AN: 6, Block No: 107, S: 560271
# ASR: ASR001, AG: AG123, AN: 6, Block No: 107, S: 492554
# ASR: ASR001, AG: AG123, AN: 6, Block No: 108, S: 491043
# ASR: ASR001, AG: AG123, AN: 6, Block No: 108, S: 946208
# ASR: ASR001, AG: AG123, AN: 6, Block No: 108, S: 581659
# ASR: ASR001, AG: AG123, AN: 6, Block No: 108, S: 756097
# ASR: ASR001, AG: AG123, AN: 6, Block No: 109, S: 992887
# ASR: ASR001, AG: AG123, AN: 6, Block No: 109, S: 16576
# ASR: ASR001, AG: AG123, AN: 6, Block No: 109, S: 769673
# ASR: ASR001, AG: AG123, AN: 6, Block No: 109, S: 142654
# ASR: ASR001, AG: AG123, AN: 6, Block No: 110, S: 451671
# ASR: ASR001, AG: AG123, AN: 6, Block No: 110, S: 980363
# ASR: ASR001, AG: AG123, AN: 6, Block No: 110, S: 858406
# ASR: ASR001, AG: AG123, AN: 6, Block No: 110, S: 924506
# ASR: ASR001, AG: AG123, AN: 6, Block No: 111, S: 272685
# ASR: ASR001, AG: AG123, AN: 6, Block No: 111, S: 953447
# ASR: ASR001, AG: AG123, AN: 6, Block No: 111, S: 995569
# ASR: ASR001, AG: AG123, AN: 6, Block No: 111, S: 576190
# ASR: ASR001, AG: AG123, AN: 6, Block No: 112, S: 972675
# ASR: ASR001, AG: AG123, AN: 6, Block No: 112, S: 113177
# ASR: ASR001, AG: AG123, AN: 6, Block No: 112, S: 521308
# ASR: ASR001, AG: AG123, AN: 6, Block No: 112, S: 784899
# ASR: ASR001, AG: AG123, AN: 6, Block No: 113, S: 785713
# ASR: ASR001, AG: AG123, AN: 6, Block No: 113, S: 726847
# ASR: ASR001, AG: AG123, AN: 6, Block No: 113, S: 793803
# ASR: ASR001, AG: AG123, AN: 6, Block No: 113, S: 203392
# ASR: ASR001, AG: AG123, AN: 6, Block No: 114, S: 346466
# ASR: ASR001, AG: AG123, AN: 6, Block No: 114, S: 603444
# ASR: ASR001, AG: AG123, AN: 6, Block No: 114, S: 393812
# ASR: ASR001, AG: AG123, AN: 6, Block No: 114, S: 442763
# ASR: ASR001, AG: AG123, AN: 6, Block No: 115, S: 212924
# ASR: ASR001, AG: AG123, AN: 6, Block No: 115, S: 505934
# ASR: ASR001, AG: AG123, AN: 6, Block No: 115, S: 831165
# ASR: ASR001, AG: AG123, AN: 6, Block No: 115, S: 960726
# ASR: ASR001, AG: AG123, AN: 6, Block No: 116, S: 375974
# ASR: ASR001, AG: AG123, AN: 6, Block No: 116, S: 517787
# ASR: ASR001, AG: AG123, AN: 6, Block No: 116, S: 511842
# ASR: ASR001, AG: AG123, AN: 6, Block No: 116, S: 527696
# ASR: ASR001, AG: AG123, AN: 6, Block No: 117, S: 501254
# ASR: ASR001, AG: AG123, AN: 6, Block No: 117, S: 283915
# ASR: ASR001, AG: AG123, AN: 6, Block No: 117, S: 359420
# ASR: ASR001, AG: AG123, AN: 6, Block No: 117, S: 405772
# ASR: ASR001, AG: AG123, AN: 6, Block No: 118, S: 174885
# ASR: ASR001, AG: AG123, AN: 6, Block No: 118, S: 690808
# ASR: ASR001, AG: AG123, AN: 6, Block No: 118, S: 917084
# ASR: ASR001, AG: AG123, AN: 6, Block No: 118, S: 170944
# ASR: ASR001, AG: AG123, AN: 6, Block No: 119, S: 465724
# ASR: ASR001, AG: AG123, AN: 6, Block No: 119, S: 373560
# ASR: ASR001, AG: AG123, AN: 6, Block No: 119, S: 320313
# ASR: ASR001, AG: AG123, AN: 6, Block No: 119, S: 674211
# ASR: ASR001, AG: AG123, AN: 6, Block No: 120, S: 891369
# ASR: ASR001, AG: AG123, AN: 6, Block No: 120, S: 823122
# ASR: ASR001, AG: AG123, AN: 6, Block No: 120, S: 978170
# ASR: ASR001, AG: AG123, AN: 6, Block No: 120, S: 189208
# ASR: ASR001, AG: AG123, AN: 6, Block No: 121, S: 826431
# ASR: ASR001, AG: AG123, AN: 6, Block No: 121, S: 854666
# ASR: ASR001, AG: AG123, AN: 6, Block No: 121, S: 461567
# ASR: ASR001, AG: AG123, AN: 6, Block No: 121, S: 694736
# ASR: ASR001, AG: AG123, AN: 6, Block No: 122, S: 220413
# ASR: ASR001, AG: AG123, AN: 6, Block No: 122, S: 166330
# ASR: ASR001, AG: AG123, AN: 6, Block No: 122, S: 171405
# ASR: ASR001, AG: AG123, AN: 6, Block No: 122, S: 231374
# ASR: ASR001, AG: AG123, AN: 6, Block No: 123, S: 412784
# ASR: ASR001, AG: AG123, AN: 6, Block No: 123, S: 951325
# ASR: ASR001, AG: AG123, AN: 6, Block No: 123, S: 238108
# ASR: ASR001, AG: AG123, AN: 6, Block No: 123, S: 567784
# ASR: ASR001, AG: AG123, AN: 6, Block No: 124, S: 358849
# ASR: ASR001, AG: AG123, AN: 6, Block No: 124, S: 974230
# ASR: ASR001, AG: AG123, AN: 6, Block No: 124, S: 490591
# ASR: ASR001, AG: AG123, AN: 6, Block No: 124, S: 397963
# ASR: ASR001, AG: AG123, AN: 6, Block No: 125, S: 679886
# ASR: ASR001, AG: AG123, AN: 6, Block No: 125, S: 251343
# ASR: ASR001, AG: AG123, AN: 6, Block No: 125, S: 532019
# ASR: ASR001, AG: AG123, AN: 6, Block No: 125, S: 560434
# ASR: ASR001, AG: AG123, AN: 6, Block No: 126, S: 80486
# ASR: ASR001, AG: AG123, AN: 6, Block No: 126, S: 175669
# ASR: ASR001, AG: AG123, AN: 6, Block No: 126, S: 587997
# ASR: ASR001, AG: AG123, AN: 6, Block No: 126, S: 411665
# ASR: ASR001, AG: AG123, AN: 6, Block No: 127, S: 306305
# ASR: ASR001, AG: AG123, AN: 6, Block No: 127, S: 864121
# ASR: ASR001, AG: AG123, AN: 6, Block No: 127, S: 890174
# ASR: ASR001, AG: AG123, AN: 6, Block No: 127, S: 958272
# ASR: ASR001, AG: AG123, AN: 6, Block No: 128, S: 452624
# ASR: ASR001, AG: AG123, AN: 6, Block No: 128, S: 589656
# ASR: ASR001, AG: AG123, AN: 6, Block No: 128, S: 123687
# ASR: ASR001, AG: AG123, AN: 6, Block No: 128, S: 846792
# ASR: ASR001, AG: AG123, AN: 6, Block No: 129, S: 603156
# ASR: ASR001, AG: AG123, AN: 6, Block No: 129, S: 688540
# ASR: ASR001, AG: AG123, AN: 6, Block No: 129, S: 192571
# ASR: ASR001, AG: AG123, AN: 6, Block No: 129, S: 568294
# ASR: ASR001, AG: AG123, AN: 6, Block No: 130, S: 834616
# ASR: ASR001, AG: AG123, AN: 6, Block No: 130, S: 314027
# ASR: ASR001, AG: AG123, AN: 6, Block No: 130, S: 368503
# ASR: ASR001, AG: AG123, AN: 6, Block No: 130, S: 247925
# ASR: ASR001, AG: AG123, AN: 6, Block No: 131, S: 513804
# ASR: ASR001, AG: AG123, AN: 6, Block No: 131, S: 685080
# ASR: ASR001, AG: AG123, AN: 6, Block No: 131, S: 359455
# ASR: ASR001, AG: AG123, AN: 6, Block No: 131, S: 941141
# ASR: ASR001, AG: AG123, AN: 6, Block No: 132, S: 45186
# ASR: ASR001, AG: AG123, AN: 6, Block No: 132, S: 945701
# ASR: ASR001, AG: AG123, AN: 6, Block No: 132, S: 237950
# ASR: ASR001, AG: AG123, AN: 6, Block No: 132, S: 555482
# ASR: ASR001, AG: AG123, AN: 6, Block No: 133, S: 750844
# ASR: ASR001, AG: AG123, AN: 6, Block No: 133, S: 809400
# ASR: ASR001, AG: AG123, AN: 6, Block No: 133, S: 249044
# ASR: ASR001, AG: AG123, AN: 6, Block No: 133, S: 376935
# ASR: ASR001, AG: AG123, AN: 6, Block No: 134, S: 695603
# ASR: ASR001, AG: AG123, AN: 6, Block No: 134, S: 266905
# ASR: ASR001, AG: AG123, AN: 6, Block No: 134, S: 812662
# ASR: ASR001, AG: AG123, AN: 6, Block No: 134, S: 851083
# ASR: ASR001, AG: AG123, AN: 6, Block No: 135, S: 249075
# ASR: ASR001, AG: AG123, AN: 6, Block No: 135, S: 374196
# ASR: ASR001, AG: AG123, AN: 6, Block No: 135, S: 62028
# ASR: ASR001, AG: AG123, AN: 6, Block No: 135, S: 462672
# ASR: ASR001, AG: AG123, AN: 6, Block No: 136, S: 267297
# ASR: ASR001, AG: AG123, AN: 6, Block No: 136, S: 331514
# ASR: ASR001, AG: AG123, AN: 6, Block No: 136, S: 744884
# ASR: ASR001, AG: AG123, AN: 6, Block No: 136, S: 171586
# ASR: ASR001, AG: AG123, AN: 6, Block No: 137, S: 532530
# ASR: ASR001, AG: AG123, AN: 6, Block No: 137, S: 803293
# ASR: ASR001, AG: AG123, AN: 6, Block No: 137, S: 617592
# ASR: ASR001, AG: AG123, AN: 6, Block No: 137, S: 671176
# ASR: ASR001, AG: AG123, AN: 6, Block No: 138, S: 173112
# ASR: ASR001, AG: AG123, AN: 6, Block No: 138, S: 834281
# ASR: ASR001, AG: AG123, AN: 6, Block No: 138, S: 980533
# ASR: ASR001, AG: AG123, AN: 6, Block No: 138, S: 687135
# ASR: ASR001, AG: AG123, AN: 6, Block No: 139, S: 761611
# ASR: ASR001, AG: AG123, AN: 6, Block No: 139, S: 978166
# ASR: ASR001, AG: AG123, AN: 6, Block No: 139, S: 895347
# ASR: ASR001, AG: AG123, AN: 6, Block No: 139, S: 261690
# ASR: ASR001, AG: AG123, AN: 6, Block No: 140, S: 546952
# ASR: ASR001, AG: AG123, AN: 6, Block No: 140, S: 2527
# ASR: ASR001, AG: AG123, AN: 6, Block No: 140, S: 451030
# ASR: ASR001, AG: AG123, AN: 6, Block No: 140, S: 624898
# ASR: ASR001, AG: AG123, AN: 6, Block No: 141, S: 803567
# ASR: ASR001, AG: AG123, AN: 6, Block No: 141, S: 578963
# ASR: ASR001, AG: AG123, AN: 6, Block No: 141, S: 77984
# ASR: ASR001, AG: AG123, AN: 6, Block No: 141, S: 878558
# ASR: ASR001, AG: AG123, AN: 6, Block No: 142, S: 291562
# ASR: ASR001, AG: AG123, AN: 6, Block No: 142, S: 630209
# ASR: ASR001, AG: AG123, AN: 6, Block No: 142, S: 551879
# ASR: ASR001, AG: AG123, AN: 6, Block No: 142, S: 208103
# ASR: ASR001, AG: AG123, AN: 6, Block No: 143, S: 282765
# ASR: ASR001, AG: AG123, AN: 6, Block No: 143, S: 111385
# ASR: ASR001, AG: AG123, AN: 6, Block No: 143, S: 831470
# ASR: ASR001, AG: AG123, AN: 6, Block No: 143, S: 642995
# ASR: ASR001, AG: AG123, AN: 6, Block No: 144, S: 314628
# ASR: ASR001, AG: AG123, AN: 6, Block No: 144, S: 680356
# ASR: ASR001, AG: AG123, AN: 6, Block No: 144, S: 671651
# ASR: ASR001, AG: AG123, AN: 6, Block No: 144, S: 279731
# ASR: ASR001, AG: AG123, AN: 6, Block No: 145, S: 478788
# ASR: ASR001, AG: AG123, AN: 6, Block No: 145, S: 672063
# ASR: ASR001, AG: AG123, AN: 6, Block No: 145, S: 339746
# ASR: ASR001, AG: AG123, AN: 6, Block No: 145, S: 31753
# ASR: ASR001, AG: AG123, AN: 6, Block No: 146, S: 986753
# ASR: ASR001, AG: AG123, AN: 6, Block No: 146, S: 448758
# ASR: ASR001, AG: AG123, AN: 6, Block No: 146, S: 266826
# ASR: ASR001, AG: AG123, AN: 6, Block No: 146, S: 965188
# ASR: ASR001, AG: AG123, AN: 6, Block No: 147, S: 153497
# ASR: ASR001, AG: AG123, AN: 6, Block No: 147, S: 386095
# ASR: ASR001, AG: AG123, AN: 6, Block No: 147, S: 368210
# ASR: ASR001, AG: AG123, AN: 6, Block No: 147, S: 878989
# ASR: ASR001, AG: AG123, AN: 6, Block No: 148, S: 459679
# ASR: ASR001, AG: AG123, AN: 6, Block No: 148, S: 175472
# ASR: ASR001, AG: AG123, AN: 6, Block No: 148, S: 634913
# ASR: ASR001, AG: AG123, AN: 6, Block No: 148, S: 110296
# ASR: ASR001, AG: AG123, AN: 6, Block No: 149, S: 15753
# ASR: ASR001, AG: AG123, AN: 6, Block No: 149, S: 690979
# ASR: ASR001, AG: AG123, AN: 6, Block No: 149, S: 641720
# ASR: ASR001, AG: AG123, AN: 6, Block No: 149, S: 156662
# ASR: ASR001, AG: AG123, AN: 6, Block No: 150, S: 342236
# ASR: ASR001, AG: AG123, AN: 6, Block No: 150, S: 577985
# ASR: ASR001, AG: AG123, AN: 6, Block No: 150, S: 192123
# ASR: ASR001, AG: AG123, AN: 6, Block No: 150, S: 186318
# ASR: ASR001, AG: AG123, AN: 6, Block No: 151, S: 633197
# ASR: ASR001, AG: AG123, AN: 6, Block No: 151, S: 830304
# ASR: ASR001, AG: AG123, AN: 6, Block No: 151, S: 119245
# ASR: ASR001, AG: AG123, AN: 6, Block No: 151, S: 790123
# ASR: ASR001, AG: AG123, AN: 6, Block No: 152, S: 366715
# ASR: ASR001, AG: AG123, AN: 6, Block No: 152, S: 146025
# ASR: ASR001, AG: AG123, AN: 6, Block No: 152, S: 278162
# ASR: ASR001, AG: AG123, AN: 6, Block No: 152, S: 660312
# ASR: ASR001, AG: AG123, AN: 6, Block No: 153, S: 101288
# ASR: ASR001, AG: AG123, AN: 6, Block No: 153, S: 829976
# ASR: ASR001, AG: AG123, AN: 6, Block No: 153, S: 40800
# ASR: ASR001, AG: AG123, AN: 6, Block No: 153, S: 594277
# ASR: ASR001, AG: AG123, AN: 6, Block No: 154, S: 604315
# ASR: ASR001, AG: AG123, AN: 6, Block No: 154, S: 499778
# ASR: ASR001, AG: AG123, AN: 6, Block No: 154, S: 466709
# ASR: ASR001, AG: AG123, AN: 6, Block No: 154, S: 197534
# ASR: ASR001, AG: AG123, AN: 6, Block No: 155, S: 939008
# ASR: ASR001, AG: AG123, AN: 6, Block No: 155, S: 295744
# ASR: ASR001, AG: AG123, AN: 6, Block No: 155, S: 252963
# ASR: ASR001, AG: AG123, AN: 6, Block No: 155, S: 863570
# ASR: ASR001, AG: AG123, AN: 6, Block No: 156, S: 584218
# ASR: ASR001, AG: AG123, AN: 6, Block No: 156, S: 802589
# ASR: ASR001, AG: AG123, AN: 6, Block No: 156, S: 343025
# ASR: ASR001, AG: AG123, AN: 6, Block No: 156, S: 108328
# ASR: ASR001, AG: AG123, AN: 6, Block No: 157, S: 159343
# ASR: ASR001, AG: AG123, AN: 6, Block No: 157, S: 546950
# ASR: ASR001, AG: AG123, AN: 6, Block No: 157, S: 106674
# ASR: ASR001, AG: AG123, AN: 6, Block No: 157, S: 179131
# ASR: ASR001, AG: AG123, AN: 6, Block No: 158, S: 948589
# ASR: ASR001, AG: AG123, AN: 6, Block No: 158, S: 826962
# ASR: ASR001, AG: AG123, AN: 6, Block No: 158, S: 696381
# ASR: ASR001, AG: AG123, AN: 6, Block No: 158, S: 29983
# ASR: ASR001, AG: AG123, AN: 6, Block No: 159, S: 86302
# ASR: ASR001, AG: AG123, AN: 6, Block No: 159, S: 940207
# ASR: ASR001, AG: AG123, AN: 6, Block No: 159, S: 873836
# ASR: ASR001, AG: AG123, AN: 6, Block No: 159, S: 752466
# ASR: ASR001, AG: AG123, AN: 6, Block No: 160, S: 510723
# ASR: ASR001, AG: AG123, AN: 6, Block No: 160, S: 938211
# ASR: ASR001, AG: AG123, AN: 6, Block No: 160, S: 373880
# ASR: ASR001, AG: AG123, AN: 6, Block No: 160, S: 177145
# ASR: ASR001, AG: AG123, AN: 6, Block No: 161, S: 240977
# ASR: ASR001, AG: AG123, AN: 6, Block No: 161, S: 28031
# ASR: ASR001, AG: AG123, AN: 6, Block No: 161, S: 442464
# ASR: ASR001, AG: AG123, AN: 6, Block No: 161, S: 793156
# ASR: ASR001, AG: AG123, AN: 6, Block No: 162, S: 595810
# ASR: ASR001, AG: AG123, AN: 6, Block No: 162, S: 100147
# ASR: ASR001, AG: AG123, AN: 6, Block No: 162, S: 128280
# ASR: ASR001, AG: AG123, AN: 6, Block No: 162, S: 591159
# ASR: ASR001, AG: AG123, AN: 6, Block No: 163, S: 240358
# ASR: ASR001, AG: AG123, AN: 6, Block No: 163, S: 292056
# ASR: ASR001, AG: AG123, AN: 6, Block No: 163, S: 528532
# ASR: ASR001, AG: AG123, AN: 6, Block No: 163, S: 624306
# ASR: ASR001, AG: AG123, AN: 6, Block No: 164, S: 829311
# ASR: ASR001, AG: AG123, AN: 6, Block No: 164, S: 511898
# ASR: ASR001, AG: AG123, AN: 6, Block No: 164, S: 494030
# ASR: ASR001, AG: AG123, AN: 6, Block No: 164, S: 652179
# ASR: ASR001, AG: AG123, AN: 6, Block No: 165, S: 819762
# ASR: ASR001, AG: AG123, AN: 6, Block No: 165, S: 41047
# ASR: ASR001, AG: AG123, AN: 6, Block No: 165, S: 522183
# ASR: ASR001, AG: AG123, AN: 6, Block No: 165, S: 764100
# ASR: ASR001, AG: AG123, AN: 6, Block No: 166, S: 42943
# ASR: ASR001, AG: AG123, AN: 6, Block No: 166, S: 598416
# ASR: ASR001, AG: AG123, AN: 6, Block No: 166, S: 770681
# ASR: ASR001, AG: AG123, AN: 6, Block No: 166, S: 786667
# ASR: ASR001, AG: AG123, AN: 6, Block No: 167, S: 198289
# ASR: ASR001, AG: AG123, AN: 6, Block No: 167, S: 481807
# ASR: ASR001, AG: AG123, AN: 6, Block No: 167, S: 160257
# ASR: ASR001, AG: AG123, AN: 6, Block No: 167, S: 119448
# ASR: ASR001, AG: AG123, AN: 6, Block No: 168, S: 21264
# ASR: ASR001, AG: AG123, AN: 6, Block No: 168, S: 188891
# ASR: ASR001, AG: AG123, AN: 6, Block No: 168, S: 492320
# ASR: ASR001, AG: AG123, AN: 6, Block No: 168, S: 388248
# ASR: ASR001, AG: AG123, AN: 6, Block No: 169, S: 377866
# ASR: ASR001, AG: AG123, AN: 6, Block No: 169, S: 536435
# ASR: ASR001, AG: AG123, AN: 6, Block No: 169, S: 574294
# ASR: ASR001, AG: AG123, AN: 6, Block No: 169, S: 977381
# ASR: ASR001, AG: AG123, AN: 6, Block No: 170, S: 614924
# ASR: ASR001, AG: AG123, AN: 6, Block No: 170, S: 329468
# ASR: ASR001, AG: AG123, AN: 6, Block No: 170, S: 947530
# ASR: ASR001, AG: AG123, AN: 6, Block No: 170, S: 924393
# ASR: ASR001, AG: AG123, AN: 6, Block No: 171, S: 706758
# ASR: ASR001, AG: AG123, AN: 6, Block No: 171, S: 844772
# ASR: ASR001, AG: AG123, AN: 6, Block No: 171, S: 857717
# ASR: ASR001, AG: AG123, AN: 6, Block No: 171, S: 472023
# ASR: ASR001, AG: AG123, AN: 6, Block No: 172, S: 42173
# ASR: ASR001, AG: AG123, AN: 6, Block No: 172, S: 466048
# ASR: ASR001, AG: AG123, AN: 6, Block No: 172, S: 911025
# ASR: ASR001, AG: AG123, AN: 6, Block No: 172, S: 322586
# ASR: ASR001, AG: AG123, AN: 6, Block No: 173, S: 571799
# ASR: ASR001, AG: AG123, AN: 6, Block No: 173, S: 253814
# ASR: ASR001, AG: AG123, AN: 6, Block No: 173, S: 985779
# ASR: ASR001, AG: AG123, AN: 6, Block No: 173, S: 715185
# ASR: ASR001, AG: AG123, AN: 6, Block No: 174, S: 376754
# ASR: ASR001, AG: AG123, AN: 6, Block No: 174, S: 46613
# ASR: ASR001, AG: AG123, AN: 6, Block No: 174, S: 149829
# ASR: ASR001, AG: AG123, AN: 6, Block No: 174, S: 512626
# ASR: ASR001, AG: AG123, AN: 6, Block No: 175, S: 65064
# ASR: ASR001, AG: AG123, AN: 6, Block No: 175, S: 265999
# ASR: ASR001, AG: AG123, AN: 6, Block No: 175, S: 42606
# ASR: ASR001, AG: AG123, AN: 6, Block No: 175, S: 992669
# ASR: ASR001, AG: AG123, AN: 6, Block No: 176, S: 269260
# ASR: ASR001, AG: AG123, AN: 6, Block No: 176, S: 144789
# ASR: ASR001, AG: AG123, AN: 6, Block No: 176, S: 566315
# ASR: ASR001, AG: AG123, AN: 6, Block No: 176, S: 379483
# ASR: ASR001, AG: AG123, AN: 6, Block No: 177, S: 731813
# ASR: ASR001, AG: AG123, AN: 6, Block No: 177, S: 277969
# ASR: ASR001, AG: AG123, AN: 6, Block No: 177, S: 81100
# ASR: ASR001, AG: AG123, AN: 6, Block No: 177, S: 49753
# ASR: ASR001, AG: AG123, AN: 6, Block No: 178, S: 472022
# ASR: ASR001, AG: AG123, AN: 6, Block No: 178, S: 607995
# ASR: ASR001, AG: AG123, AN: 6, Block No: 178, S: 990435
# ASR: ASR001, AG: AG123, AN: 6, Block No: 178, S: 996725
# ASR: ASR001, AG: AG123, AN: 6, Block No: 179, S: 432807
# ASR: ASR001, AG: AG123, AN: 6, Block No: 179, S: 867011
# ASR: ASR001, AG: AG123, AN: 6, Block No: 179, S: 492698
# ASR: ASR001, AG: AG123, AN: 6, Block No: 179, S: 807623
# ASR: ASR001, AG: AG123, AN: 6, Block No: 180, S: 686863
# ASR: ASR001, AG: AG123, AN: 6, Block No: 180, S: 660923
# ASR: ASR001, AG: AG123, AN: 6, Block No: 180, S: 519568
# ASR: ASR001, AG: AG123, AN: 6, Block No: 180, S: 196862
# ASR: ASR001, AG: AG123, AN: 6, Block No: 181, S: 37536
# ASR: ASR001, AG: AG123, AN: 6, Block No: 181, S: 251186
# ASR: ASR001, AG: AG123, AN: 6, Block No: 181, S: 129644
# ASR: ASR001, AG: AG123, AN: 6, Block No: 181, S: 891304
# ASR: ASR001, AG: AG123, AN: 6, Block No: 182, S: 877491
# ASR: ASR001, AG: AG123, AN: 6, Block No: 182, S: 652433
# ASR: ASR001, AG: AG123, AN: 6, Block No: 182, S: 599784
# ASR: ASR001, AG: AG123, AN: 6, Block No: 182, S: 618170
# ASR: ASR001, AG: AG123, AN: 6, Block No: 183, S: 230275
# ASR: ASR001, AG: AG123, AN: 6, Block No: 183, S: 478485
# ASR: ASR001, AG: AG123, AN: 6, Block No: 183, S: 492931
# ASR: ASR001, AG: AG123, AN: 6, Block No: 183, S: 641886
# ASR: ASR001, AG: AG123, AN: 6, Block No: 184, S: 74933
# ASR: ASR001, AG: AG123, AN: 6, Block No: 184, S: 703084
# ASR: ASR001, AG: AG123, AN: 6, Block No: 184, S: 973737
# ASR: ASR001, AG: AG123, AN: 6, Block No: 184, S: 432982
# ASR: ASR001, AG: AG123, AN: 6, Block No: 185, S: 664230
# ASR: ASR001, AG: AG123, AN: 6, Block No: 185, S: 534347
# ASR: ASR001, AG: AG123, AN: 6, Block No: 185, S: 33380
# ASR: ASR001, AG: AG123, AN: 6, Block No: 185, S: 604190
# ASR: ASR001, AG: AG123, AN: 6, Block No: 186, S: 201453
# ASR: ASR001, AG: AG123, AN: 6, Block No: 186, S: 477767
# ASR: ASR001, AG: AG123, AN: 6, Block No: 186, S: 220383
# ASR: ASR001, AG: AG123, AN: 6, Block No: 186, S: 100682
# ASR: ASR001, AG: AG123, AN: 6, Block No: 187, S: 759154
# ASR: ASR001, AG: AG123, AN: 6, Block No: 187, S: 701098
# ASR: ASR001, AG: AG123, AN: 6, Block No: 187, S: 421994
# ASR: ASR001, AG: AG123, AN: 6, Block No: 187, S: 563032
# ASR: ASR001, AG: AG123, AN: 6, Block No: 188, S: 949957
# ASR: ASR001, AG: AG123, AN: 6, Block No: 188, S: 643982
# ASR: ASR001, AG: AG123, AN: 6, Block No: 188, S: 667509
# ASR: ASR001, AG: AG123, AN: 6, Block No: 188, S: 698458
# ASR: ASR001, AG: AG123, AN: 6, Block No: 189, S: 573928
# ASR: ASR001, AG: AG123, AN: 6, Block No: 189, S: 368530
# ASR: ASR001, AG: AG123, AN: 6, Block No: 189, S: 184736
# ASR: ASR001, AG: AG123, AN: 6, Block No: 189, S: 689665
# ASR: ASR001, AG: AG123, AN: 6, Block No: 190, S: 578527
# ASR: ASR001, AG: AG123, AN: 6, Block No: 190, S: 647054
# ASR: ASR001, AG: AG123, AN: 6, Block No: 190, S: 720450
# ASR: ASR001, AG: AG123, AN: 6, Block No: 190, S: 483118
# ASR: ASR001, AG: AG123, AN: 6, Block No: 191, S: 298979
# ASR: ASR001, AG: AG123, AN: 6, Block No: 191, S: 938851
# ASR: ASR001, AG: AG123, AN: 6, Block No: 191, S: 720161
# ASR: ASR001, AG: AG123, AN: 6, Block No: 191, S: 977457
# ASR: ASR001, AG: AG123, AN: 6, Block No: 192, S: 87721
# ASR: ASR001, AG: AG123, AN: 6, Block No: 192, S: 408426
# ASR: ASR001, AG: AG123, AN: 6, Block No: 192, S: 984454
# ASR: ASR001, AG: AG123, AN: 6, Block No: 192, S: 441054
# ASR: ASR001, AG: AG123, AN: 6, Block No: 193, S: 2530
# ASR: ASR001, AG: AG123, AN: 6, Block No: 193, S: 226983
# ASR: ASR001, AG: AG123, AN: 6, Block No: 193, S: 6653
# ASR: ASR001, AG: AG123, AN: 6, Block No: 193, S: 938902
# ASR: ASR001, AG: AG123, AN: 6, Block No: 194, S: 137639
# ASR: ASR001, AG: AG123, AN: 6, Block No: 194, S: 679101
# ASR: ASR001, AG: AG123, AN: 6, Block No: 194, S: 358141
# ASR: ASR001, AG: AG123, AN: 6, Block No: 194, S: 840297
# ASR: ASR001, AG: AG123, AN: 6, Block No: 195, S: 963632
# ASR: ASR001, AG: AG123, AN: 6, Block No: 195, S: 50971
# ASR: ASR001, AG: AG123, AN: 6, Block No: 195, S: 693171
# ASR: ASR001, AG: AG123, AN: 6, Block No: 195, S: 255192
# ASR: ASR001, AG: AG123, AN: 6, Block No: 196, S: 228122
# ASR: ASR001, AG: AG123, AN: 6, Block No: 196, S: 799992
# ASR: ASR001, AG: AG123, AN: 6, Block No: 196, S: 462903
# ASR: ASR001, AG: AG123, AN: 6, Block No: 196, S: 25595
# ASR: ASR001, AG: AG123, AN: 6, Block No: 197, S: 426115
# ASR: ASR001, AG: AG123, AN: 6, Block No: 197, S: 162499
# ASR: ASR001, AG: AG123, AN: 6, Block No: 197, S: 726090
# ASR: ASR001, AG: AG123, AN: 6, Block No: 197, S: 526662
# ASR: ASR001, AG: AG123, AN: 6, Block No: 198, S: 130782
# ASR: ASR001, AG: AG123, AN: 6, Block No: 198, S: 834832
# ASR: ASR001, AG: AG123, AN: 6, Block No: 198, S: 879392
# ASR: ASR001, AG: AG123, AN: 6, Block No: 198, S: 933867
# ASR: ASR001, AG: AG123, AN: 6, Block No: 199, S: 227643
# ASR: ASR001, AG: AG123, AN: 6, Block No: 199, S: 596786
# ASR: ASR001, AG: AG123, AN: 6, Block No: 199, S: 696012
# ASR: ASR001, AG: AG123, AN: 6, Block No: 199, S: 837616
# ASR: ASR001, AG: AG123, AN: 6, Block No: 200, S: 1448
# ASR: ASR001, AG: AG123, AN: 6, Block No: 200, S: 688845
# ASR: ASR001, AG: AG123, AN: 6, Block No: 200, S: 355078
# ASR: ASR001, AG: AG123, AN: 6, Block No: 200, S: 881982
# ASR: ASR001, AG: AG123, AN: 6, Block No: 201, S: 92975
# ASR: ASR001, AG: AG123, AN: 6, Block No: 201, S: 232248
# ASR: ASR001, AG: AG123, AN: 6, Block No: 201, S: 335995
# ASR: ASR001, AG: AG123, AN: 6, Block No: 201, S: 656661
# ASR: ASR001, AG: AG123, AN: 6, Block No: 202, S: 450571
# ASR: ASR001, AG: AG123, AN: 6, Block No: 202, S: 483129
# ASR: ASR001, AG: AG123, AN: 6, Block No: 202, S: 664654
# ASR: ASR001, AG: AG123, AN: 6, Block No: 202, S: 922225
# ASR: ASR001, AG: AG123, AN: 6, Block No: 203, S: 527009
# ASR: ASR001, AG: AG123, AN: 6, Block No: 203, S: 657819
# ASR: ASR001, AG: AG123, AN: 6, Block No: 203, S: 560880
# ASR: ASR001, AG: AG123, AN: 6, Block No: 203, S: 93287
# ASR: ASR001, AG: AG123, AN: 6, Block No: 204, S: 857912
# ASR: ASR001, AG: AG123, AN: 6, Block No: 204, S: 602861
# ASR: ASR001, AG: AG123, AN: 6, Block No: 204, S: 755769
# ASR: ASR001, AG: AG123, AN: 6, Block No: 204, S: 782257
# ASR: ASR001, AG: AG123, AN: 6, Block No: 205, S: 924659
# ASR: ASR001, AG: AG123, AN: 6, Block No: 205, S: 830948
# ASR: ASR001, AG: AG123, AN: 6, Block No: 205, S: 541957
# ASR: ASR001, AG: AG123, AN: 6, Block No: 205, S: 210513
# ASR: ASR001, AG: AG123, AN: 6, Block No: 206, S: 790383
# ASR: ASR001, AG: AG123, AN: 6, Block No: 206, S: 948939
# ASR: ASR001, AG: AG123, AN: 6, Block No: 206, S: 602476
# ASR: ASR001, AG: AG123, AN: 6, Block No: 206, S: 146760
# ASR: ASR001, AG: AG123, AN: 6, Block No: 207, S: 459376
# ASR: ASR001, AG: AG123, AN: 6, Block No: 207, S: 209421
# ASR: ASR001, AG: AG123, AN: 6, Block No: 207, S: 353842
# ASR: ASR001, AG: AG123, AN: 6, Block No: 207, S: 162088
# ASR: ASR001, AG: AG123, AN: 6, Block No: 208, S: 960243
# ASR: ASR001, AG: AG123, AN: 6, Block No: 208, S: 886915
# ASR: ASR001, AG: AG123, AN: 6, Block No: 208, S: 976714
# ASR: ASR001, AG: AG123, AN: 6, Block No: 208, S: 328950
# ASR: ASR001, AG: AG123, AN: 6, Block No: 209, S: 853321
# ASR: ASR001, AG: AG123, AN: 6, Block No: 209, S: 261553
# ASR: ASR001, AG: AG123, AN: 6, Block No: 209, S: 199712
# ASR: ASR001, AG: AG123, AN: 6, Block No: 209, S: 597183
# ASR: ASR001, AG: AG123, AN: 6, Block No: 210, S: 777405
# ASR: ASR001, AG: AG123, AN: 6, Block No: 210, S: 731216
# ASR: ASR001, AG: AG123, AN: 6, Block No: 210, S: 831856
# ASR: ASR001, AG: AG123, AN: 6, Block No: 210, S: 327451
# ASR: ASR001, AG: AG123, AN: 6, Block No: 211, S: 925420
# ASR: ASR001, AG: AG123, AN: 6, Block No: 211, S: 554686
# ASR: ASR001, AG: AG123, AN: 6, Block No: 211, S: 448730
# ASR: ASR001, AG: AG123, AN: 6, Block No: 211, S: 751850
# ASR: ASR001, AG: AG123, AN: 6, Block No: 212, S: 208575
# ASR: ASR001, AG: AG123, AN: 6, Block No: 212, S: 479349
# ASR: ASR001, AG: AG123, AN: 6, Block No: 212, S: 116546
# ASR: ASR001, AG: AG123, AN: 6, Block No: 212, S: 390851
# ASR: ASR001, AG: AG123, AN: 6, Block No: 213, S: 296471
# ASR: ASR001, AG: AG123, AN: 6, Block No: 213, S: 681942
# ASR: ASR001, AG: AG123, AN: 6, Block No: 213, S: 432004
# ASR: ASR001, AG: AG123, AN: 6, Block No: 213, S: 779650
# ASR: ASR001, AG: AG123, AN: 6, Block No: 214, S: 914758
# ASR: ASR001, AG: AG123, AN: 6, Block No: 214, S: 741886
# ASR: ASR001, AG: AG123, AN: 6, Block No: 214, S: 147874
# ASR: ASR001, AG: AG123, AN: 6, Block No: 214, S: 860930
# ASR: ASR001, AG: AG123, AN: 6, Block No: 215, S: 555207
# ASR: ASR001, AG: AG123, AN: 6, Block No: 215, S: 11800
# ASR: ASR001, AG: AG123, AN: 6, Block No: 215, S: 568180
# ASR: ASR001, AG: AG123, AN: 6, Block No: 215, S: 127310
# ASR: ASR001, AG: AG123, AN: 6, Block No: 216, S: 426475
# ASR: ASR001, AG: AG123, AN: 6, Block No: 216, S: 507694
# ASR: ASR001, AG: AG123, AN: 6, Block No: 216, S: 504957
# ASR: ASR001, AG: AG123, AN: 6, Block No: 216, S: 661468
# ASR: ASR001, AG: AG123, AN: 6, Block No: 217, S: 785102
# ASR: ASR001, AG: AG123, AN: 6, Block No: 217, S: 139914
# ASR: ASR001, AG: AG123, AN: 6, Block No: 217, S: 516830
# ASR: ASR001, AG: AG123, AN: 6, Block No: 217, S: 527351
# ASR: ASR001, AG: AG123, AN: 6, Block No: 218, S: 792830
# ASR: ASR001, AG: AG123, AN: 6, Block No: 218, S: 43318
# ASR: ASR001, AG: AG123, AN: 6, Block No: 218, S: 828956
# ASR: ASR001, AG: AG123, AN: 6, Block No: 218, S: 371172
# ASR: ASR001, AG: AG123, AN: 6, Block No: 219, S: 500849
# ASR: ASR001, AG: AG123, AN: 6, Block No: 219, S: 187860
# ASR: ASR001, AG: AG123, AN: 6, Block No: 219, S: 956088
# ASR: ASR001, AG: AG123, AN: 6, Block No: 219, S: 836163
# ASR: ASR001, AG: AG123, AN: 6, Block No: 220, S: 515768
# ASR: ASR001, AG: AG123, AN: 6, Block No: 220, S: 487811
# ASR: ASR001, AG: AG123, AN: 6, Block No: 220, S: 331228
# ASR: ASR001, AG: AG123, AN: 6, Block No: 220, S: 599124
# ASR: ASR001, AG: AG123, AN: 6, Block No: 221, S: 11400
# ...
# ASR: ASR001, AG: AG123, AN: 6, Block No: 933, S: 583779
# ASR: ASR001, AG: AG123, AN: 6, Block No: 933, S: 72124
# ASR: ASR001, AG: AG123, AN: 6, Block No: 934, S: 134579
# ASR: ASR001, AG: AG123, AN: 6, Block No: 934, S: 466831
# ASR: ASR001, AG: AG123, AN: 6, Block No: 934, S: 463938
# ASR: ASR001, AG: AG123, AN: 6, Block No: 934, S: 394425
# ASR: ASR001, AG: AG123, AN: 6, Block No: 935, S: 981002
# ASR: ASR001, AG: AG123, AN: 6, Block No: 935, S: 484900
# ASR: ASR001, AG: AG123, AN: 6, Block No: 935, S: 770067
# ASR: ASR001, AG: AG123, AN: 6, Block No: 935, S: 127426
# ASR: ASR001, AG: AG123, AN: 6, Block No: 936, S: 836715
# ASR: ASR001, AG: AG123, AN: 6, Block No: 936, S: 127718
# ASR: ASR001, AG: AG123, AN: 6, Block No: 936, S: 285498
# ASR: ASR001, AG: AG123, AN: 6, Block No: 936, S: 299845
# ASR: ASR001, AG: AG123, AN: 6, Block No: 937, S: 398683
# ASR: ASR001, AG: AG123, AN: 6, Block No: 937, S: 79139
# ASR: ASR001, AG: AG123, AN: 6, Block No: 937, S: 18653
# ASR: ASR001, AG: AG123, AN: 6, Block No: 937, S: 707484
# ASR: ASR001, AG: AG123, AN: 6, Block No: 938, S: 232082
# ASR: ASR001, AG: AG123, AN: 6, Block No: 938, S: 118815
# ASR: ASR001, AG: AG123, AN: 6, Block No: 938, S: 801911
# ASR: ASR001, AG: AG123, AN: 6, Block No: 938, S: 264464
# ASR: ASR001, AG: AG123, AN: 6, Block No: 939, S: 288073
# ASR: ASR001, AG: AG123, AN: 6, Block No: 939, S: 372965
# ASR: ASR001, AG: AG123, AN: 6, Block No: 939, S: 375952
# ASR: ASR001, AG: AG123, AN: 6, Block No: 939, S: 888342
# ASR: ASR001, AG: AG123, AN: 6, Block No: 940, S: 350186
# ASR: ASR001, AG: AG123, AN: 6, Block No: 940, S: 287332
# ASR: ASR001, AG: AG123, AN: 6, Block No: 940, S: 563452
# ASR: ASR001, AG: AG123, AN: 6, Block No: 940, S: 506949
# ASR: ASR001, AG: AG123, AN: 6, Block No: 941, S: 303139
# ASR: ASR001, AG: AG123, AN: 6, Block No: 941, S: 785546
# ASR: ASR001, AG: AG123, AN: 6, Block No: 941, S: 191640
# ASR: ASR001, AG: AG123, AN: 6, Block No: 941, S: 847631
# ASR: ASR001, AG: AG123, AN: 6, Block No: 942, S: 110853
# ASR: ASR001, AG: AG123, AN: 6, Block No: 942, S: 402060
# ASR: ASR001, AG: AG123, AN: 6, Block No: 942, S: 251122
# ASR: ASR001, AG: AG123, AN: 6, Block No: 942, S: 469625
# ASR: ASR001, AG: AG123, AN: 6, Block No: 943, S: 500727
# ASR: ASR001, AG: AG123, AN: 6, Block No: 943, S: 258533
# ASR: ASR001, AG: AG123, AN: 6, Block No: 943, S: 925726
# ASR: ASR001, AG: AG123, AN: 6, Block No: 943, S: 78248
# ASR: ASR001, AG: AG123, AN: 6, Block No: 944, S: 548765
# ASR: ASR001, AG: AG123, AN: 6, Block No: 944, S: 815754
# ASR: ASR001, AG: AG123, AN: 6, Block No: 944, S: 444570
# ASR: ASR001, AG: AG123, AN: 6, Block No: 944, S: 762062
# ASR: ASR001, AG: AG123, AN: 6, Block No: 945, S: 373996
# ASR: ASR001, AG: AG123, AN: 6, Block No: 945, S: 441583
# ASR: ASR001, AG: AG123, AN: 6, Block No: 945, S: 956746
# ASR: ASR001, AG: AG123, AN: 6, Block No: 945, S: 684613
# ASR: ASR001, AG: AG123, AN: 6, Block No: 946, S: 315530
# ASR: ASR001, AG: AG123, AN: 6, Block No: 946, S: 560924
# ASR: ASR001, AG: AG123, AN: 6, Block No: 946, S: 777587
# ASR: ASR001, AG: AG123, AN: 6, Block No: 946, S: 213124
# ASR: ASR001, AG: AG123, AN: 6, Block No: 947, S: 231560
# ASR: ASR001, AG: AG123, AN: 6, Block No: 947, S: 711224
# ASR: ASR001, AG: AG123, AN: 6, Block No: 947, S: 600589
# ASR: ASR001, AG: AG123, AN: 6, Block No: 947, S: 695238
# ASR: ASR001, AG: AG123, AN: 6, Block No: 948, S: 180120
# ASR: ASR001, AG: AG123, AN: 6, Block No: 948, S: 883005
# ASR: ASR001, AG: AG123, AN: 6, Block No: 948, S: 67301
# ASR: ASR001, AG: AG123, AN: 6, Block No: 948, S: 56165
# ASR: ASR001, AG: AG123, AN: 6, Block No: 949, S: 48053
# ASR: ASR001, AG: AG123, AN: 6, Block No: 949, S: 759783
# ASR: ASR001, AG: AG123, AN: 6, Block No: 949, S: 965130
# ASR: ASR001, AG: AG123, AN: 6, Block No: 949, S: 998136
# ASR: ASR001, AG: AG123, AN: 6, Block No: 950, S: 871556
# ASR: ASR001, AG: AG123, AN: 6, Block No: 950, S: 479983
# ASR: ASR001, AG: AG123, AN: 6, Block No: 950, S: 281706
# ASR: ASR001, AG: AG123, AN: 6, Block No: 950, S: 157969
# ASR: ASR001, AG: AG123, AN: 6, Block No: 951, S: 872358
# ASR: ASR001, AG: AG123, AN: 6, Block No: 951, S: 319682
# ASR: ASR001, AG: AG123, AN: 6, Block No: 951, S: 666798
# ASR: ASR001, AG: AG123, AN: 6, Block No: 951, S: 663304
# ASR: ASR001, AG: AG123, AN: 6, Block No: 952, S: 489689
# ASR: ASR001, AG: AG123, AN: 6, Block No: 952, S: 60492
# ASR: ASR001, AG: AG123, AN: 6, Block No: 952, S: 340507
# ASR: ASR001, AG: AG123, AN: 6, Block No: 952, S: 882748
# ASR: ASR001, AG: AG123, AN: 6, Block No: 953, S: 4027
# ASR: ASR001, AG: AG123, AN: 6, Block No: 953, S: 556128
# ASR: ASR001, AG: AG123, AN: 6, Block No: 953, S: 751444
# ASR: ASR001, AG: AG123, AN: 6, Block No: 953, S: 763375
# ASR: ASR001, AG: AG123, AN: 6, Block No: 954, S: 263506
# ASR: ASR001, AG: AG123, AN: 6, Block No: 954, S: 846778
# ASR: ASR001, AG: AG123, AN: 6, Block No: 954, S: 410532
# ASR: ASR001, AG: AG123, AN: 6, Block No: 954, S: 721789
# ASR: ASR001, AG: AG123, AN: 6, Block No: 955, S: 31634
# ASR: ASR001, AG: AG123, AN: 6, Block No: 955, S: 387313
# ASR: ASR001, AG: AG123, AN: 6, Block No: 955, S: 357471
# ASR: ASR001, AG: AG123, AN: 6, Block No: 955, S: 1103
# ASR: ASR001, AG: AG123, AN: 6, Block No: 956, S: 846070
# ASR: ASR001, AG: AG123, AN: 6, Block No: 956, S: 646521
# ASR: ASR001, AG: AG123, AN: 6, Block No: 956, S: 102162
# ASR: ASR001, AG: AG123, AN: 6, Block No: 956, S: 665701
# ASR: ASR001, AG: AG123, AN: 6, Block No: 957, S: 834278
# ASR: ASR001, AG: AG123, AN: 6, Block No: 957, S: 161799
# ASR: ASR001, AG: AG123, AN: 6, Block No: 957, S: 454542
# ASR: ASR001, AG: AG123, AN: 6, Block No: 957, S: 752432
# ASR: ASR001, AG: AG123, AN: 6, Block No: 958, S: 436666
# ASR: ASR001, AG: AG123, AN: 6, Block No: 958, S: 629141
# ASR: ASR001, AG: AG123, AN: 6, Block No: 958, S: 919830
# ASR: ASR001, AG: AG123, AN: 6, Block No: 958, S: 676949
# ASR: ASR001, AG: AG123, AN: 6, Block No: 959, S: 690433
# ASR: ASR001, AG: AG123, AN: 6, Block No: 959, S: 790809
# ASR: ASR001, AG: AG123, AN: 6, Block No: 959, S: 442057
# ASR: ASR001, AG: AG123, AN: 6, Block No: 959, S: 319734
# ASR: ASR001, AG: AG123, AN: 6, Block No: 960, S: 755542
# ASR: ASR001, AG: AG123, AN: 6, Block No: 960, S: 105320
# ASR: ASR001, AG: AG123, AN: 6, Block No: 960, S: 616816
# ASR: ASR001, AG: AG123, AN: 6, Block No: 960, S: 377721
# ASR: ASR001, AG: AG123, AN: 6, Block No: 961, S: 79058
# ASR: ASR001, AG: AG123, AN: 6, Block No: 961, S: 891905
# ASR: ASR001, AG: AG123, AN: 6, Block No: 961, S: 735157
# ASR: ASR001, AG: AG123, AN: 6, Block No: 961, S: 928524
# ASR: ASR001, AG: AG123, AN: 6, Block No: 962, S: 916203
# ASR: ASR001, AG: AG123, AN: 6, Block No: 962, S: 806581
# ASR: ASR001, AG: AG123, AN: 6, Block No: 962, S: 347581
# ASR: ASR001, AG: AG123, AN: 6, Block No: 962, S: 507547
# ASR: ASR001, AG: AG123, AN: 6, Block No: 963, S: 71187
# ASR: ASR001, AG: AG123, AN: 6, Block No: 963, S: 114042
# ASR: ASR001, AG: AG123, AN: 6, Block No: 963, S: 576205
# ASR: ASR001, AG: AG123, AN: 6, Block No: 963, S: 554242
# ASR: ASR001, AG: AG123, AN: 6, Block No: 964, S: 393101
# ASR: ASR001, AG: AG123, AN: 6, Block No: 964, S: 330088
# ASR: ASR001, AG: AG123, AN: 6, Block No: 964, S: 103797
# ASR: ASR001, AG: AG123, AN: 6, Block No: 964, S: 509656
# ASR: ASR001, AG: AG123, AN: 6, Block No: 965, S: 219654
# ASR: ASR001, AG: AG123, AN: 6, Block No: 965, S: 164540
# ASR: ASR001, AG: AG123, AN: 6, Block No: 965, S: 662101
# ASR: ASR001, AG: AG123, AN: 6, Block No: 965, S: 512555
# ASR: ASR001, AG: AG123, AN: 6, Block No: 966, S: 898136
# ASR: ASR001, AG: AG123, AN: 6, Block No: 966, S: 887378
# ASR: ASR001, AG: AG123, AN: 6, Block No: 966, S: 366610
# ASR: ASR001, AG: AG123, AN: 6, Block No: 966, S: 512152
# ASR: ASR001, AG: AG123, AN: 6, Block No: 967, S: 706951
# ASR: ASR001, AG: AG123, AN: 6, Block No: 967, S: 584116
# ASR: ASR001, AG: AG123, AN: 6, Block No: 967, S: 298208
# ASR: ASR001, AG: AG123, AN: 6, Block No: 967, S: 369471
# ASR: ASR001, AG: AG123, AN: 6, Block No: 968, S: 928311
# ASR: ASR001, AG: AG123, AN: 6, Block No: 968, S: 826936
# ASR: ASR001, AG: AG123, AN: 6, Block No: 968, S: 579420
# ASR: ASR001, AG: AG123, AN: 6, Block No: 968, S: 325566
# ASR: ASR001, AG: AG123, AN: 6, Block No: 969, S: 969337
# ASR: ASR001, AG: AG123, AN: 6, Block No: 969, S: 166637
# ASR: ASR001, AG: AG123, AN: 6, Block No: 969, S: 399151
# ASR: ASR001, AG: AG123, AN: 6, Block No: 969, S: 159071
# ASR: ASR001, AG: AG123, AN: 6, Block No: 970, S: 116397
# ASR: ASR001, AG: AG123, AN: 6, Block No: 970, S: 387575
# ASR: ASR001, AG: AG123, AN: 6, Block No: 970, S: 882798
# ASR: ASR001, AG: AG123, AN: 6, Block No: 970, S: 242500
# ASR: ASR001, AG: AG123, AN: 6, Block No: 971, S: 617696
# ASR: ASR001, AG: AG123, AN: 6, Block No: 971, S: 615836
# ASR: ASR001, AG: AG123, AN: 6, Block No: 971, S: 226526
# ASR: ASR001, AG: AG123, AN: 6, Block No: 971, S: 761556
# ASR: ASR001, AG: AG123, AN: 6, Block No: 972, S: 427783
# ASR: ASR001, AG: AG123, AN: 6, Block No: 972, S: 671771
# ASR: ASR001, AG: AG123, AN: 6, Block No: 972, S: 334625
# ASR: ASR001, AG: AG123, AN: 6, Block No: 972, S: 177417
# ASR: ASR001, AG: AG123, AN: 6, Block No: 973, S: 13394
# ASR: ASR001, AG: AG123, AN: 6, Block No: 973, S: 457372
# ASR: ASR001, AG: AG123, AN: 6, Block No: 973, S: 142825
# ASR: ASR001, AG: AG123, AN: 6, Block No: 973, S: 273372
# ASR: ASR001, AG: AG123, AN: 6, Block No: 974, S: 427107
# ASR: ASR001, AG: AG123, AN: 6, Block No: 974, S: 110368
# ASR: ASR001, AG: AG123, AN: 6, Block No: 974, S: 963607
# ASR: ASR001, AG: AG123, AN: 6, Block No: 974, S: 922457
# ASR: ASR001, AG: AG123, AN: 6, Block No: 975, S: 812384
# ASR: ASR001, AG: AG123, AN: 6, Block No: 975, S: 618106
# ASR: ASR001, AG: AG123, AN: 6, Block No: 975, S: 57701
# ASR: ASR001, AG: AG123, AN: 6, Block No: 975, S: 280251
# ASR: ASR001, AG: AG123, AN: 6, Block No: 976, S: 503991
# ASR: ASR001, AG: AG123, AN: 6, Block No: 976, S: 749530
# ASR: ASR001, AG: AG123, AN: 6, Block No: 976, S: 76748
# ASR: ASR001, AG: AG123, AN: 6, Block No: 976, S: 624309
# ASR: ASR001, AG: AG123, AN: 6, Block No: 977, S: 152915
# ASR: ASR001, AG: AG123, AN: 6, Block No: 977, S: 168303
# ASR: ASR001, AG: AG123, AN: 6, Block No: 977, S: 852643
# ASR: ASR001, AG: AG123, AN: 6, Block No: 977, S: 329675
# ASR: ASR001, AG: AG123, AN: 6, Block No: 978, S: 83010
# ASR: ASR001, AG: AG123, AN: 6, Block No: 978, S: 347496
# ASR: ASR001, AG: AG123, AN: 6, Block No: 978, S: 307707
# ASR: ASR001, AG: AG123, AN: 6, Block No: 978, S: 979780
# ASR: ASR001, AG: AG123, AN: 6, Block No: 979, S: 738045
# ASR: ASR001, AG: AG123, AN: 6, Block No: 979, S: 920553
# ASR: ASR001, AG: AG123, AN: 6, Block No: 979, S: 163875
# ASR: ASR001, AG: AG123, AN: 6, Block No: 979, S: 135110
# ASR: ASR001, AG: AG123, AN: 6, Block No: 980, S: 159907
# ASR: ASR001, AG: AG123, AN: 6, Block No: 980, S: 110052
# ASR: ASR001, AG: AG123, AN: 6, Block No: 980, S: 395688
# ASR: ASR001, AG: AG123, AN: 6, Block No: 980, S: 567306
# ASR: ASR001, AG: AG123, AN: 6, Block No: 981, S: 505725
# ASR: ASR001, AG: AG123, AN: 6, Block No: 981, S: 549802
# ASR: ASR001, AG: AG123, AN: 6, Block No: 981, S: 976298
# ASR: ASR001, AG: AG123, AN: 6, Block No: 981, S: 496987
# ASR: ASR001, AG: AG123, AN: 6, Block No: 982, S: 942948
# ASR: ASR001, AG: AG123, AN: 6, Block No: 982, S: 292676
# ASR: ASR001, AG: AG123, AN: 6, Block No: 982, S: 511018
# ASR: ASR001, AG: AG123, AN: 6, Block No: 982, S: 631462
# ASR: ASR001, AG: AG123, AN: 6, Block No: 983, S: 366444
# ASR: ASR001, AG: AG123, AN: 6, Block No: 983, S: 35504
# ASR: ASR001, AG: AG123, AN: 6, Block No: 983, S: 696173
# ASR: ASR001, AG: AG123, AN: 6, Block No: 983, S: 995828
# ASR: ASR001, AG: AG123, AN: 6, Block No: 984, S: 231760
# ASR: ASR001, AG: AG123, AN: 6, Block No: 984, S: 770549
# ASR: ASR001, AG: AG123, AN: 6, Block No: 984, S: 68550
# ASR: ASR001, AG: AG123, AN: 6, Block No: 984, S: 518717
# ASR: ASR001, AG: AG123, AN: 6, Block No: 985, S: 347010
# ASR: ASR001, AG: AG123, AN: 6, Block No: 985, S: 439413
# ASR: ASR001, AG: AG123, AN: 6, Block No: 985, S: 118560
# ASR: ASR001, AG: AG123, AN: 6, Block No: 985, S: 122450
# ASR: ASR001, AG: AG123, AN: 6, Block No: 986, S: 281620
# ASR: ASR001, AG: AG123, AN: 6, Block No: 986, S: 779833
# ASR: ASR001, AG: AG123, AN: 6, Block No: 986, S: 240679
# ASR: ASR001, AG: AG123, AN: 6, Block No: 986, S: 344373
# ASR: ASR001, AG: AG123, AN: 6, Block No: 987, S: 831185
# ASR: ASR001, AG: AG123, AN: 6, Block No: 987, S: 24327
# ASR: ASR001, AG: AG123, AN: 6, Block No: 987, S: 417161
# ASR: ASR001, AG: AG123, AN: 6, Block No: 987, S: 554162
# ASR: ASR001, AG: AG123, AN: 6, Block No: 988, S: 886778
# ASR: ASR001, AG: AG123, AN: 6, Block No: 988, S: 82791
# ASR: ASR001, AG: AG123, AN: 6, Block No: 988, S: 811831
# ASR: ASR001, AG: AG123, AN: 6, Block No: 988, S: 712749
# ASR: ASR001, AG: AG123, AN: 6, Block No: 989, S: 98382
# ASR: ASR001, AG: AG123, AN: 6, Block No: 989, S: 195481
# ASR: ASR001, AG: AG123, AN: 6, Block No: 989, S: 615875
# ASR: ASR001, AG: AG123, AN: 6, Block No: 989, S: 774373
# ASR: ASR001, AG: AG123, AN: 6, Block No: 990, S: 511105
# ASR: ASR001, AG: AG123, AN: 6, Block No: 990, S: 687008
# ASR: ASR001, AG: AG123, AN: 6, Block No: 990, S: 986360
# ASR: ASR001, AG: AG123, AN: 6, Block No: 990, S: 881506
# ASR: ASR001, AG: AG123, AN: 6, Block No: 991, S: 538039
# ASR: ASR001, AG: AG123, AN: 6, Block No: 991, S: 600666
# ASR: ASR001, AG: AG123, AN: 6, Block No: 991, S: 605265
# ASR: ASR001, AG: AG123, AN: 6, Block No: 991, S: 248451
# ASR: ASR001, AG: AG123, AN: 6, Block No: 992, S: 34599
# ASR: ASR001, AG: AG123, AN: 6, Block No: 992, S: 926881
# ASR: ASR001, AG: AG123, AN: 6, Block No: 992, S: 727007
# ASR: ASR001, AG: AG123, AN: 6, Block No: 992, S: 979649
# ASR: ASR001, AG: AG123, AN: 6, Block No: 993, S: 74700
# ASR: ASR001, AG: AG123, AN: 6, Block No: 993, S: 498834
# ASR: ASR001, AG: AG123, AN: 6, Block No: 993, S: 520597
# ASR: ASR001, AG: AG123, AN: 6, Block No: 993, S: 230269
# ASR: ASR001, AG: AG123, AN: 6, Block No: 994, S: 207650
# ASR: ASR001, AG: AG123, AN: 6, Block No: 994, S: 59557
# ASR: ASR001, AG: AG123, AN: 6, Block No: 994, S: 310066
# ASR: ASR001, AG: AG123, AN: 6, Block No: 994, S: 515533
# ASR: ASR001, AG: AG123, AN: 6, Block No: 995, S: 135143
# ASR: ASR001, AG: AG123, AN: 6, Block No: 995, S: 299954
# ASR: ASR001, AG: AG123, AN: 6, Block No: 995, S: 463799
# ASR: ASR001, AG: AG123, AN: 6, Block No: 995, S: 623283
# ASR: ASR001, AG: AG123, AN: 6, Block No: 996, S: 514734
# ASR: ASR001, AG: AG123, AN: 6, Block No: 996, S: 788644
# ASR: ASR001, AG: AG123, AN: 6, Block No: 996, S: 154776
# ASR: ASR001, AG: AG123, AN: 6, Block No: 996, S: 873216
# ASR: ASR001, AG: AG123, AN: 6, Block No: 997, S: 93811
# ASR: ASR001, AG: AG123, AN: 6, Block No: 997, S: 222474
# ASR: ASR001, AG: AG123, AN: 6, Block No: 997, S: 91431
# ASR: ASR001, AG: AG123, AN: 6, Block No: 997, S: 277903
# ASR: ASR001, AG: AG123, AN: 6, Block No: 998, S: 149531
# ASR: ASR001, AG: AG123, AN: 6, Block No: 998, S: 70958
# ASR: ASR001, AG: AG123, AN: 6, Block No: 998, S: 567984
# ASR: ASR001, AG: AG123, AN: 6, Block No: 998, S: 877520
# ASR: ASR001, AG: AG123, AN: 6, Block No: 999, S: 187247
# ASR: ASR001, AG: AG123, AN: 6, Block No: 999, S: 467279
# ASR: ASR001, AG: AG123, AN: 6, Block No: 999, S: 139416
# ASR: ASR001, AG: AG123, AN: 6, Block No: 999, S: 52993
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1000, S: 51206
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1000, S: 503113
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1000, S: 243894
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1000, S: 47676
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1001, S: 800381
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1001, S: 98319
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1001, S: 485083
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1001, S: 769072
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1002, S: 595867
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1002, S: 892021
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1002, S: 163857
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1002, S: 513398
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1003, S: 767774
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1003, S: 85015
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1003, S: 620796
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1003, S: 873886
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1004, S: 141187
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1004, S: 917653
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1004, S: 216488
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1004, S: 23850

# %%
import pandas as pd
import numpy as np

def coss_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, dsout='Alloc', seed=0):
    import sys  # Added import for sys module

    # Check if AN is less than 4
    if AN < 4:
        print("Length of CID number must be at least 4.")
        return

    TrtNo = len(P)
    # Check if the number of treatment regimen ratios matches the number of treatment regimens
    if TrtNo != len(T):
        print("Number of treatment regimen ratios must match the number of treatment regimens.")
        return

    # Check if there is at least one treatment regimen
    if TrtNo == 0:
        print("There must be at least one treatment regimen.")
        return

    # Adjust N if it exceeds the capacity between S and 10^AN
    if N > 10**AN - S:
        N = 10**AN - S

    # Check if N is less than BS
    if N < BS:
        print("Total CID number must be no less than the blocking factor.")
        return

    GrpNo = 0
    for i in range(TrtNo):
        GrpNo += P[i]

    # Check if BS is a multiple of the sum of treatment regimen ratios
    if BS % GrpNo != 0:
        print("Blocking size is not a multiple of the sum of treatment regimen ratios.")
        return

    total = BS * ((N + BS - 1) // BS)
    Blocks = total // BS
    EndNo = N + S - 1
    colen = AN
    cfmt = colen + brf

    ln = 996 // cfmt
    blockmin = BR
    blockmax = blockmin + Blocks - 1
    blkfmt = f"z{brf}"
    bsiz = len(str(BR))

    # Check if the length of Block No# range matches the size given
    if bsiz != brf:
        print("Length of Block No# range must match the size given.")
        return

    # Check if total is equal to BS and BS is greater than 1000
    if total == BS and BS > 1000:
        Grpno = BS // GrpNo

        # Create data for sch1
        sch1_data = []
        for i in range(TrtNo):
            for block_no in range(blockmin, blockmax + 1):
                GROUP = T[i]
                for _ in range(GrpNo):
                    ran = np.random.rand(seed)
                    sch1_data.append([ASR, GROUP, block_no, ran])  # Fixed the column order

        sch1_df = pd.DataFrame(sch1_data, columns=['ASR', 'GROUP', 'block_no', 'ran'])

        # Further processing logic here (use the 'sch1_df' DataFrame)

    else:
        Grps = ''
        for k in range(BS // GrpNo):
            for i in range(TrtNo):
                for j in range(P[i]):
                    Grps += str(T[i])  # Convert T[i] to string

        # Create data for sch1
        sch1_data = []
        alloc = S
        for block_no in range(blockmin, blockmax + 1):
            for _ in range(BS):
                ran = np.random.rand(seed)
                sch1_data.append([block_no, alloc, ran])
                alloc += 1

        sch1_df = pd.DataFrame(sch1_data, columns=['block_no', 'ALLOC', 'ran'])

        # Create data for sch2
        sch2_data = []
        for index, row in sch1_df.iterrows():
            ASR_val = ASR
            AG_val = AG
            ord_val = index % BS
            group_val = Grps[ord_val]
            ALLOC_val = row['ALLOC']
            sch2_data.append([ASR_val, AG_val, row['block_no'], group_val, ALLOC_val])  # Fixed the column order

        sch2_df = pd.DataFrame(sch2_data, columns=['ASR', 'AG', 'block_no', 'GROUP', 'ALLOC'])

        # Further processing logic here (use the 'sch2_df' DataFrame)

    # Sort sch2_df by ASR, block_no, AG, group, and alloc
    sch2_df.sort_values(by=['ASR', 'block_no', 'AG', 'GROUP', 'ALLOC'], inplace=True)

    # Create summary tables
    summary1 = sch2_df.groupby(['ASR', 'AG']).agg({'ALLOC': ['min', 'max', 'nunique']})
    summary2 = sch2_df.groupby(['GROUP']).agg({'ALLOC': ['min', 'max', 'nunique']})

    # Print summary tables
    print("ASR(ASR) AG(AG) Summary")
    print(summary1)

    print("\nASR(ASR) AG(AG) By Treatment Group")
    print(summary2)

    # Create dsout DataFrame
    dsout_data = sch2_df.copy()
    dsout_data['lineno'] = range(1, len(dsout_data) + 1)
    dsout_data['LINETEXT'] = ''
    dsout_data['ERRTEXT'] = ''
    dsout_df = dsout_data[['ASR', 'AG', 'lineno', 'LINETEXT', 'ERRTEXT']]

    # Output dsout_df (you can save it to a CSV or use it as needed)
    dsout_df.to_csv(f'{dsout}.csv', index=False)

    syserr = 0
    if syserr > 0:
        print(f"Proc DBLOAD return code = {syserr}")

# Test the function with sample data
sample_data = {
    "ASR": "ASR001",
    "AG": "AG123",
    "AN": 6,
    "S": 1000,
    "N": 999000,  # Adjusted N to be within the valid range
    "BS": 1000,
    "T": [1, 2, 1],
    "P": [1, 2, 1],
    "BR": 5000,  # Adjusted BR to match the length of 5000
    "brf": 4,    # Adjusted brf to match the length of 4
}

coss_prd(**sample_data)
# Out:
# ASR(ASR) AG(AG) Summary
#              ALLOC
#                min     max nunique
# ASR    AG
# ASR001 AG123  1000  999999  999000
#
# ASR(ASR) AG(AG) By Treatment Group
#       ALLOC
#         min     max nunique
# GROUP
# 1      1000  999999  499500
# 2      1001  999998  499500

# %%
import random
import pandas as pd

def cass_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, Table, dsout, seed):
    """
    Generate a patient component schedule for a clinical trial.

    Args:
        ASR: The ASR (Allocation Schedule Request) ID for the patient component schedule.
        AG: The AG (Allocation Generation set) ID for the patient component schedule.
        AN: The length of the CID (Component ID) number.
        S: The starting CID number.
        N: The total number of CID numbers.
        BS: The blocking factor.
        T: The number of treatment regimens.
        P: The ratios of the treatment regimens.
        BR: The starting block number.
        brf: The length of the block number range.
        Table: The name of the Oracle table where the schedule will be stored.
        dsout: The name of the SAS data set where the schedule will be stored.
        seed: The seed for the random number generator.

    Returns:
        A Pandas DataFrame containing the patient component schedule.
    """

    # Check the input parameters for validity.
    if AN < 4:
        raise ValueError("Length of CID number must be at least 4.")
    if T < 1:
        raise ValueError("There must be at least one treatment regimen.")
    if N < BS:
        raise ValueError("Total CID number must be no less than the blocking factor.")

    # Generate the patient component schedule.
    schedule = pd.DataFrame()
    for i in range(T):
        group_size = P[i]
        for j in range(group_size):
            block_no = random.randint(BR, BR + BS - 1)
            schedule = schedule.append({
                "ASR": ASR,
                "AG": AG,
                "GROUP": i + 1,
                "BLOCK_NO": block_no,
                "CID": S + j + block_no * BS
            }, ignore_index=True)

    # Sort the schedule by block number and treatment regimen.
    schedule = schedule.sort_values(by=["BLOCK_NO", "GROUP"])

    # Return the patient component schedule.
    return schedule

# Example usage:

schedule = cass_prd(ASR="123456",
                    AG="789012",
                    AN=4,
                    S=10000,
                    N=20000,
                    BS=100,
                    T=2,
                    P=[1, 2],
                    BR=1,
                    brf=3,
                    Table="TEMP_ALLOC_DAT_TBL",
                    dsout="Alloc",
                    seed=12345)

# Save the patient component schedule to a CSV file.
#schedule.to_csv("cass_prd.csv", index=False)
schedule
# Out:
# <ipython-input-11-7970d21c863e>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-11-7970d21c863e>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-11-7970d21c863e>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
#       ASR      AG  GROUP  BLOCK_NO    CID
# 2  123456  789012      2        56  15601
# 0  123456  789012      1        62  16200
# 1  123456  789012      2        95  19500

# %%
import random
import pandas as pd

def coss_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, Table, dsout, seed):
    """
    Generate a patient component schedule for a clinical trial.

    Args:
        ASR: The ASR (Allocation Schedule Request) ID for the patient component schedule.
        AG: The AG (Allocation Generation set) ID for the patient component schedule.
        AN: The length of the CID (Component ID) number.
        S: The starting CID number.
        N: The total number of CID numbers.
        BS: The blocking factor.
        T: The number of treatment regimens.
        P: The ratios of the treatment regimens.
        BR: The starting block number.
        brf: The length of the block number range.
        Table: The name of the Oracle table where the schedule will be stored.
        dsout: The name of the SAS data set where the schedule will be stored.
        seed: The seed for the random number generator.

    Returns:
        A Pandas DataFrame containing the patient component schedule.
    """

    # Check the input parameters for validity.
    if AN < 4:
        raise ValueError("Length of CID number must be at least 4.")
    if T < 1:
        raise ValueError("There must be at least one treatment regimen.")
    if N < BS:
        raise ValueError("Total CID number must be no less than blocking factor.")

    # Generate the patient component schedule.
    schedule = pd.DataFrame()
    for i in range(T):
        group_size = P[i]
        for j in range(group_size):
            block_no = random.randint(BR, BR + BS - 1)
            schedule = schedule.append({
                "ASR": ASR,
                "AG": AG,
                "GROUP": i + 1,
                "BLOCK_NO": block_no,
                "CID": S + j + block_no * BS
            }, ignore_index=True)

    # Sort the schedule by block number and treatment regimen.
    schedule = schedule.sort_values(by=["BLOCK_NO", "GROUP"])

    # Return the patient component schedule.
    return schedule

schedule = coss_prd(ASR="123456",
                    AG="789012",
                    AN=4,
                    S=10000,
                    N=10000,
                    BS=10,
                    T=3,
                    P=[1, 2, 3],
                    BR=1,
                    brf=3,
                    Table="TEMP_ALLOC_DAT_TBL",
                    dsout="Alloc",
                    seed=12345)

schedule
# Out:
# <ipython-input-37-dc323f2283bb>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-37-dc323f2283bb>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-37-dc323f2283bb>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-37-dc323f2283bb>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-37-dc323f2283bb>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-37-dc323f2283bb>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
#       ASR      AG  GROUP  BLOCK_NO    CID
# 5  123456  789012      3         2  10022
# 4  123456  789012      3         3  10031
# 3  123456  789012      3         6  10060
# 0  123456  789012      1         7  10070
# 1  123456  789012      2         8  10080
# 2  123456  789012      2        10  10101

# %%
import random
import pandas as pd

def coss_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, Table, dsout, seed):
    """
    Generate a patient component schedule for a clinical trial.

    Args:
        ASR: The ASR (Allocation Schedule Request) ID for the patient component schedule.
        AG: The AG (Allocation Generation set) ID for the patient component schedule.
        AN: The length of the CID (Component ID) number.
        S: The starting CID number.
        N: The total number of CID numbers.
        BS: The blocking factor.
        T: The number of treatment regimens.
        P: The ratios of the treatment regimens.
        BR: The starting block number.
        brf: The length of the block number range.
        Table: The name of the Oracle table where the schedule will be stored.
        dsout: The name of the SAS data set where the schedule will be stored.
        seed: The seed for the random number generator.

    Returns:
        A Pandas DataFrame containing the patient component schedule.
    """

    # Check the input parameters for validity.
    if AN < 4:
        raise ValueError("Length of CID number must be at least 4.")
    if T < 1:
        raise ValueError("There must be at least one treatment regimen.")
    if N < BS:
        raise ValueError("Total CID number must be no less than blocking factor.")

    # Generate the patient component schedule.
    schedule = pd.DataFrame()
    for i in range(T):
        group_size = P[i]
        block_no = random.randint(BR, BR + BS - 1)
        data = [{
            "ASR": ASR,
            "AG": AG,
            "GROUP": i + 1,
            "BLOCK_NO": block_no,
            "CID": S + j + block_no * BS
        } for j in range(group_size)]
        schedule = pd.concat([schedule, pd.DataFrame(data)], ignore_index=True)

    # Sort the schedule by block number and treatment regimen.
    schedule = schedule.sort_values(by=["BLOCK_NO", "GROUP"])

    # Return the patient component schedule.
    return schedule


schedule = coss_prd(ASR="123456",
                    AG="789012",
                    AN=4,
                    S=10000,
                    N=10000,
                    BS=10,
                    T=3,
                    P=[1, 2, 3],
                    BR=1,
                    brf=3,
                    Table="TEMP_ALLOC_DAT_TBL",
                    dsout="Alloc",
                    seed=12345)

print(schedule)
# Out:
#       ASR      AG  GROUP  BLOCK_NO    CID
# 0  123456  789012      1         3  10030
# 3  123456  789012      3         6  10060
# 4  123456  789012      3         6  10061
# 5  123456  789012      3         6  10062
# 1  123456  789012      2        10  10100
# 2  123456  789012      2        10  10101

# %%
import random
import pandas as pd

def cass_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, Table, dsout, seed, index=None):
    """
    Generate a patient component schedule for a clinical trial.

    Args:
        ASR: The ASR (Allocation Schedule Request) ID for the patient component schedule.
        AG: The AG (Allocation Generation set) ID for the patient component schedule.
        AN: The length of the CID (Component ID) number.
        S: The starting CID number.
        N: The total number of CID numbers.
        BS: The blocking factor.
        T: The number of treatment regimens.
        P: The ratios of the treatment regimens.
        BR: The starting block number.
        brf: The length of the block number range.
        Table: The name of the Oracle table where the schedule will be stored.
        dsout: The name of the SAS data set where the schedule will be stored.
        seed: The seed for the random number generator.

    Returns:
        A Pandas DataFrame containing the patient component schedule.
    """

    # Check the input parameters for validity.
    if AN < 4:
        raise ValueError("Length of CID number must be at least 4.")
    if T < 1:
        raise ValueError("There must be at least one treatment regimen.")
    if N < BS:
        raise ValueError("Total CID number must be no less than the blocking factor.")

    # Generate the patient component schedule.
    schedule = pd.DataFrame()
    for i in range(T):
        group_size = P[i]
        for j in range(group_size):
            block_no = random.randint(BR, BR + BS - 1)
            schedule = schedule.append({
                "ASR": ASR,
                "AG": AG,
                "GROUP": i + 1,
                "BLOCK_NO": block_no,
                "CID": S + j + block_no * BS
            }, ignore_index=True)

    # Sort the schedule by block number and treatment regimen.
    schedule = schedule.sort_values(by=["BLOCK_NO", "GROUP"])

    # Return the patient component schedule.
    return schedule.set_index(index)

# %%
schedule = cass_prd(ASR="123456",
                    AG="789012",
                    AN=4,
                    S=10000,
                    N=20000,
                    BS=100,
                    T=2,
                    P=[1, 2],
                    BR=1,
                    brf=3,
                    Table="TEMP_ALLOC_DAT_TBL",
                    dsout="Alloc",
                    seed=12345,
                    index=["row1"])

# Save the patient component schedule to a CSV file.
#schedule.to_csv("cass_prd.csv", index=False)
schedule
# Out:
# <ipython-input-16-a1878cfb7e05>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-16-a1878cfb7e05>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-16-a1878cfb7e05>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-99aa24d2f4d7> in <cell line: 1>()
# ----> 1 schedule = cass_prd(ASR="123456",
#       2                     AG="789012",
#       3                     AN=4,
#       4                     S=10000,
#       5                     N=20000,
#
# <ipython-input-16-a1878cfb7e05> in cass_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, Table, dsout, seed, index)
#      51
#      52     # Return the patient component schedule.
# ---> 53     return schedule.set_index(index)
#      54
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['row1'] are in the columns"
