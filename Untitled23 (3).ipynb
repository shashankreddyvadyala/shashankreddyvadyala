# %%
import random
import pandas as pd
from sqlalchemy import create_engine

def coss_prd(username='', password='', DB='', ASR=0, AG=0, AN=0, S=0, N=0, BS=0, T=(), P=(), BR=0, brf=0, Table='TEMP_ALLOC_DAT_TBL', dsout='Alloc', seed=0):
    # Set up local variables
    i = 0
    grpfmt = ""
    allocfmt = ""
    blkfmt = ""
    TrtNo = 0
    Grps = ""
    GrpNo = 0
    Blocks = 0
    Total = 0
    endno = 0
    colen = 0
    cfmt = ""

    # Validate parameter AN (>=4)
    allocfmt = f'z{AN}'
    grpfmt = 'z4.'
    if AN < 4:
        print("Length of CID number must be at least 4.")
        return

    # Validate parameters T and P
    TrtNo = len(T)
    if TrtNo != len(P):
        print("Number of treatment regimen ratios must match number of treatment regimens.")
        return

    if TrtNo == 0:
        print("There must be at least one treatment regimen.")
        return

    # Validate parameter N
    if N < BS:
        print("Total CID number must be no less than blocking factor.")
        return

    # Validate assumption 5
    GrpNo = 0
    for i in range(TrtNo):
        GrpNo += P[i]

    if BS % GrpNo != 0:
        print("Blocking size is not a multiple of the sum of treatment regimen ratios.")
        return

    # Validate assumption 6
    if (S + N - 10 ** AN) > 0:
        bigN = "9" * AN
        print(f"Total CID number N={N} exceeds the capacity between {S} and {bigN}")
        return

    # Derive macro variables
    total = BS * ((N + BS - 1) // BS)
    Blocks = total // BS
    EndNo = N + S - 1
    colen = AN
    cfmt = colen + brf

    # Derive and validate Block No# parameters
    ln = 996 // cfmt
    blockmin = BR
    blockmax = blockmin + Blocks - 1
    blkfmt = f'z{brf}'
    bsiz = len(str(BR))
    if bsiz != brf:
        print("Length of Block No# range must match the size given.")
        return

    # Generate and insert component schedules into a DataFrame
    schedules = []

    if total == BS and BS > 1000:
        GrpNo = BS // GrpNo

        for i in range(TrtNo):
            P[i] = GrpNo * P[i]

        for i in range(TrtNo):
            for block_no in range(blockmin, blockmax + 1):
                GROUP = T[i]
                for _ in range(P[i]):
                    ran = random.random()
                    schedules.append((ASR, AG, AN, block_no, S))
    else:
        for k in range(BS // GrpNo):
            for i in range(TrtNo):
                for j in range(P[i]):
                    Grps += T[i]

        for block_no in range(blockmin, blockmax + 1):
            for i in range(BS):
                ran = random.random()
                schedules.append((ASR, AG, random.randint(1, AN), block_no, S))
                S += 1

    # Create a DataFrame from the generated data
    df = pd.DataFrame(schedules, columns=['ASR', 'AG', 'AN', 'BlockNo', 'Alloc'])

    # Establish a database connection using SQLAlchemy
    engine = create_engine(f'oracle://{username}:{password}@{DB}')

    # Insert the DataFrame into the Oracle database table
    df.to_sql(Table, con=engine, if_exists='replace', index=False)

    # Optional: Generate summary reports using Pandas functions

    # Optional: Handle errors and generate error messages if needed
    print("Process completed successfully.")

# Example usage:
#coss_prd(username='your_username', password='your_password', DB='your_database_connection', ASR=123, AG=456, AN=789, S=1, N=1000, BS=100, T=[1, 2], P=[0.6, 0.4], BR=1, brf=9, Table='YourTableName')

# %%
import random
import pandas as pd

def coss_prd(ASR='', AG='', AN=0, S=0, N=0, BS=0, T='', P='', BR='', brf='', Table='TEMP_ALLOC_DAT_TBL', dsout='Alloc', seed=0):
    # Convert input parameters to appropriate types
    ASR = str(ASR)
    AG = str(AG)
    AN = int(AN)
    S = int(S)
    N = int(N)
    BS = int(BS)
    T = [int(t) for t in T.split()]
    P = [int(p) for p in P.split()]
    BR = str(BR)
    brf = str(brf)
    seed = int(seed)

    # Initialize local variables
    endno = N
    allocfmt = f'z{AN}.'
    grpfmt = 'z4.'
    TrtNo = len(P)

    # Check if the number of treatment regimen ratios matches the number of treatment regimens
    if TrtNo != len(T):
        print("Number of treatment regimen ratios must match the number of treatment regimens.")
        return

    # Check if there is at least one treatment regimen
    if TrtNo == 0:
        print("There must be at least one treatment regimen.")
        return

    # Check if N is greater than or equal to BS
    if N < BS:
        print("Total CID number must be no less than blocking factor.")
        return

    GrpNo = 0

    # Calculate the sum of treatment regimen ratios
    for i in range(TrtNo):
        grp_name = f'grp{P[i]}'
        globals()[grp_name] = P[i]
        GrpNo += P[i]

    # Check if BS is a multiple of the sum of treatment regimen ratios
    if BS % GrpNo != 0:
        print("Blocking size is not a multiple of the sum of treatment regimen ratios.")
        return

    # Check if N exceeds the capacity between S and 10^AN
    if S + N - 10**AN > 0:
        print(f"Total CID number N={N} exceeds the capacity between {S} and 10^{AN}")
        return

    # Calculate various parameters
    total = BS * ((N + BS - 1) // BS)
    Blocks = total // BS
    EndNo = N + S - 1
    colen = AN
    cfmt = colen + int(brf)

    ln = 996 // cfmt
    blockmin = int(BR)
    blockmax = blockmin + Blocks - 1
    blkfmt = f'z{int(brf)}.'
    bsiz = len(BR)

    # Check if the length of Block No# range matches the size given
    if bsiz != int(brf):
        print("Length of Block No# range must match the size given.")
        return

    # Check if total is equal to BS and BS is greater than 1000
    if total == BS and BS > 1000:
        Grpno = BS // GrpNo

        # Generate schedule data
        schedule_data = []
        for i in range(TrtNo):
            for block_no in range(blockmin, blockmax + 1):
                GROUP = f"Trt{T[i]}"
                for _ in range(grpno * P[i]):
                    ran = random.uniform(0, 1)
                    schedule_data.append((ASR, block_no, AG, GROUP, ran))

        # Create a DataFrame
        df = pd.DataFrame(schedule_data, columns=['ASR', 'block_no', 'AG', 'GROUP', 'ran'])

        # Additional processing or output as needed
        print(df)

    else:
        Grps = ""
        for k in range(BS // GrpNo):
            for i in range(TrtNo):
                for j in range(P[i]):
                    Grps += f" Trt{T[i]}"

        # Generate schedule data
        schedule_data = []
        alloc = S
        for block_no in range(blockmin, blockmax + 1):
            for _ in range(BS):
                ran = random.uniform(0, 1)
                schedule_data.append((ASR, block_no, AG, Grps.strip(), alloc, ran))
                alloc += 1

        # Create a DataFrame
        df = pd.DataFrame(schedule_data, columns=['ASR', 'block_no', 'AG', 'GROUP', 'alloc', 'ran'])

        # Additional processing or output as needed
        print(df)

# Sample data for testing
sample_data = {
    'ASR': 'ASR123',
    'AG': 'AG456',
    'AN': 6,
    'S': 1000,
    'N': 1000010,
    'BS': 60,
    'T': '1 2',
    'P': '20 40',
    'BR': '001',
    'brf': '3',
    'seed': 12345,
}

# Call the coss_prd function with the sample data
coss_prd(**sample_data)
# Out:
# Total CID number N=1000010 exceeds the capacity between 1000 and 10^6

# %%
import random

def coss_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, seed=0):
    schedules = []

    # Calculate the total number of schedules
    total_schedules = BS * ((N + BS - 1) // BS)

    # Check if the total CID number exceeds the capacity
    if N > 10 ** AN:
        print(f"Total CID number N={N} exceeds the capacity between {S} and {10 ** AN}")
        return schedules

    # Check if the blocking size is a multiple of the sum of treatment regimen ratios
    TrtNo = len(P)
    if TrtNo != len(T):
        print("Number of treatment regimen ratios must match the number of treatment regimens.")
        return schedules

    # Calculate the sum of treatment regimen ratios
    GrpNo = sum(P)

    # Check if the blocking size is a multiple of the sum of treatment regimen ratios
    if BS % GrpNo != 0:
        print("Blocking size is not a multiple of the sum of treatment regimen ratios.")
        return schedules

    # Generate schedules
    for block_no in range(BR, BR + (total_schedules // BS)):
        for i in range(TrtNo):
            for j in range(P[i]):
                ASR_schedule = ASR
                AG_schedule = AG
                block_schedule = block_no
                S_schedule = S + random.randint(0, 10 ** AN - 1)
                schedules.append((ASR_schedule, AG_schedule, AN, block_schedule, S_schedule))

    return schedules

if __name__ == "__main__":
    # Sample data
    sample_data = {
    "ASR": "ASR001",
    "AG": "AG123",
    "AN": 6,
    "S": 1000,
    "N": 1000000,  # Adjusted N value
    "BS": 1000,
    "T": [1, 2, 1],
    "P": [1, 2, 1],
    "BR": 5,
    "brf": 2,
}

    # Call the coss_prd function with the sample data
    schedules = coss_prd(**sample_data)

    # Further processing logic here (use the 'schedules' list)
    if schedules:
        print("Generated Schedules:")
        for schedule in schedules:
            ASR, AG, AN, block_no, S = schedule
            print(f"ASR: {ASR}, AG: {AG}, AN: {AN}, Block No: {block_no}, S: {S}")
# Out:
# Generated Schedules:
# ASR: ASR001, AG: AG123, AN: 6, Block No: 5, S: 5104
# ASR: ASR001, AG: AG123, AN: 6, Block No: 5, S: 966073
# ASR: ASR001, AG: AG123, AN: 6, Block No: 5, S: 740464
# ASR: ASR001, AG: AG123, AN: 6, Block No: 5, S: 546565
# ASR: ASR001, AG: AG123, AN: 6, Block No: 6, S: 924145
# ASR: ASR001, AG: AG123, AN: 6, Block No: 6, S: 896598
# ASR: ASR001, AG: AG123, AN: 6, Block No: 6, S: 662731
# ASR: ASR001, AG: AG123, AN: 6, Block No: 6, S: 322467
# ASR: ASR001, AG: AG123, AN: 6, Block No: 7, S: 972045
# ASR: ASR001, AG: AG123, AN: 6, Block No: 7, S: 956436
# ASR: ASR001, AG: AG123, AN: 6, Block No: 7, S: 543424
# ASR: ASR001, AG: AG123, AN: 6, Block No: 7, S: 720433
# ASR: ASR001, AG: AG123, AN: 6, Block No: 8, S: 248882
# ASR: ASR001, AG: AG123, AN: 6, Block No: 8, S: 970677
# ASR: ASR001, AG: AG123, AN: 6, Block No: 8, S: 727317
# ASR: ASR001, AG: AG123, AN: 6, Block No: 8, S: 193225
# ASR: ASR001, AG: AG123, AN: 6, Block No: 9, S: 12523
# ASR: ASR001, AG: AG123, AN: 6, Block No: 9, S: 641673
# ASR: ASR001, AG: AG123, AN: 6, Block No: 9, S: 614231
# ASR: ASR001, AG: AG123, AN: 6, Block No: 9, S: 603832
# ASR: ASR001, AG: AG123, AN: 6, Block No: 10, S: 801239
# ASR: ASR001, AG: AG123, AN: 6, Block No: 10, S: 119725
# ASR: ASR001, AG: AG123, AN: 6, Block No: 10, S: 943703
# ASR: ASR001, AG: AG123, AN: 6, Block No: 10, S: 611561
# ASR: ASR001, AG: AG123, AN: 6, Block No: 11, S: 370158
# ASR: ASR001, AG: AG123, AN: 6, Block No: 11, S: 600899
# ASR: ASR001, AG: AG123, AN: 6, Block No: 11, S: 940348
# ASR: ASR001, AG: AG123, AN: 6, Block No: 11, S: 615930
# ASR: ASR001, AG: AG123, AN: 6, Block No: 12, S: 576842
# ASR: ASR001, AG: AG123, AN: 6, Block No: 12, S: 230764
# ASR: ASR001, AG: AG123, AN: 6, Block No: 12, S: 462619
# ASR: ASR001, AG: AG123, AN: 6, Block No: 12, S: 442041
# ASR: ASR001, AG: AG123, AN: 6, Block No: 13, S: 512296
# ASR: ASR001, AG: AG123, AN: 6, Block No: 13, S: 934023
# ASR: ASR001, AG: AG123, AN: 6, Block No: 13, S: 71729
# ASR: ASR001, AG: AG123, AN: 6, Block No: 13, S: 937565
# ASR: ASR001, AG: AG123, AN: 6, Block No: 14, S: 429487
# ASR: ASR001, AG: AG123, AN: 6, Block No: 14, S: 647533
# ASR: ASR001, AG: AG123, AN: 6, Block No: 14, S: 295430
# ASR: ASR001, AG: AG123, AN: 6, Block No: 14, S: 987129
# ASR: ASR001, AG: AG123, AN: 6, Block No: 15, S: 155718
# ASR: ASR001, AG: AG123, AN: 6, Block No: 15, S: 350606
# ASR: ASR001, AG: AG123, AN: 6, Block No: 15, S: 610854
# ASR: ASR001, AG: AG123, AN: 6, Block No: 15, S: 209544
# ASR: ASR001, AG: AG123, AN: 6, Block No: 16, S: 885349
# ASR: ASR001, AG: AG123, AN: 6, Block No: 16, S: 342316
# ASR: ASR001, AG: AG123, AN: 6, Block No: 16, S: 560786
# ASR: ASR001, AG: AG123, AN: 6, Block No: 16, S: 583982
# ASR: ASR001, AG: AG123, AN: 6, Block No: 17, S: 432961
# ASR: ASR001, AG: AG123, AN: 6, Block No: 17, S: 873661
# ASR: ASR001, AG: AG123, AN: 6, Block No: 17, S: 89266
# ASR: ASR001, AG: AG123, AN: 6, Block No: 17, S: 817196
# ASR: ASR001, AG: AG123, AN: 6, Block No: 18, S: 483618
# ASR: ASR001, AG: AG123, AN: 6, Block No: 18, S: 579936
# ASR: ASR001, AG: AG123, AN: 6, Block No: 18, S: 33379
# ASR: ASR001, AG: AG123, AN: 6, Block No: 18, S: 628099
# ASR: ASR001, AG: AG123, AN: 6, Block No: 19, S: 5548
# ASR: ASR001, AG: AG123, AN: 6, Block No: 19, S: 142155
# ASR: ASR001, AG: AG123, AN: 6, Block No: 19, S: 285850
# ASR: ASR001, AG: AG123, AN: 6, Block No: 19, S: 124622
# ASR: ASR001, AG: AG123, AN: 6, Block No: 20, S: 240817
# ASR: ASR001, AG: AG123, AN: 6, Block No: 20, S: 546293
# ASR: ASR001, AG: AG123, AN: 6, Block No: 20, S: 726875
# ASR: ASR001, AG: AG123, AN: 6, Block No: 20, S: 67850
# ASR: ASR001, AG: AG123, AN: 6, Block No: 21, S: 196901
# ASR: ASR001, AG: AG123, AN: 6, Block No: 21, S: 429260
# ASR: ASR001, AG: AG123, AN: 6, Block No: 21, S: 545926
# ASR: ASR001, AG: AG123, AN: 6, Block No: 21, S: 404042
# ASR: ASR001, AG: AG123, AN: 6, Block No: 22, S: 867866
# ASR: ASR001, AG: AG123, AN: 6, Block No: 22, S: 851260
# ASR: ASR001, AG: AG123, AN: 6, Block No: 22, S: 728493
# ASR: ASR001, AG: AG123, AN: 6, Block No: 22, S: 321356
# ASR: ASR001, AG: AG123, AN: 6, Block No: 23, S: 502534
# ASR: ASR001, AG: AG123, AN: 6, Block No: 23, S: 974842
# ASR: ASR001, AG: AG123, AN: 6, Block No: 23, S: 733897
# ASR: ASR001, AG: AG123, AN: 6, Block No: 23, S: 129671
# ASR: ASR001, AG: AG123, AN: 6, Block No: 24, S: 91206
# ASR: ASR001, AG: AG123, AN: 6, Block No: 24, S: 911857
# ASR: ASR001, AG: AG123, AN: 6, Block No: 24, S: 740484
# ASR: ASR001, AG: AG123, AN: 6, Block No: 24, S: 82495
# ASR: ASR001, AG: AG123, AN: 6, Block No: 25, S: 612540
# ASR: ASR001, AG: AG123, AN: 6, Block No: 25, S: 162895
# ASR: ASR001, AG: AG123, AN: 6, Block No: 25, S: 729374
# ASR: ASR001, AG: AG123, AN: 6, Block No: 25, S: 749024
# ASR: ASR001, AG: AG123, AN: 6, Block No: 26, S: 116810
# ASR: ASR001, AG: AG123, AN: 6, Block No: 26, S: 555527
# ASR: ASR001, AG: AG123, AN: 6, Block No: 26, S: 717925
# ASR: ASR001, AG: AG123, AN: 6, Block No: 26, S: 909012
# ASR: ASR001, AG: AG123, AN: 6, Block No: 27, S: 855291
# ASR: ASR001, AG: AG123, AN: 6, Block No: 27, S: 589669
# ASR: ASR001, AG: AG123, AN: 6, Block No: 27, S: 512883
# ASR: ASR001, AG: AG123, AN: 6, Block No: 27, S: 390006
# ASR: ASR001, AG: AG123, AN: 6, Block No: 28, S: 406773
# ASR: ASR001, AG: AG123, AN: 6, Block No: 28, S: 234008
# ASR: ASR001, AG: AG123, AN: 6, Block No: 28, S: 167307
# ASR: ASR001, AG: AG123, AN: 6, Block No: 28, S: 822753
# ASR: ASR001, AG: AG123, AN: 6, Block No: 29, S: 196597
# ASR: ASR001, AG: AG123, AN: 6, Block No: 29, S: 241040
# ASR: ASR001, AG: AG123, AN: 6, Block No: 29, S: 134873
# ASR: ASR001, AG: AG123, AN: 6, Block No: 29, S: 555890
# ASR: ASR001, AG: AG123, AN: 6, Block No: 30, S: 12858
# ASR: ASR001, AG: AG123, AN: 6, Block No: 30, S: 73305
# ASR: ASR001, AG: AG123, AN: 6, Block No: 30, S: 258536
# ASR: ASR001, AG: AG123, AN: 6, Block No: 30, S: 10648
# ASR: ASR001, AG: AG123, AN: 6, Block No: 31, S: 581946
# ASR: ASR001, AG: AG123, AN: 6, Block No: 31, S: 240330
# ASR: ASR001, AG: AG123, AN: 6, Block No: 31, S: 563268
# ASR: ASR001, AG: AG123, AN: 6, Block No: 31, S: 333917
# ASR: ASR001, AG: AG123, AN: 6, Block No: 32, S: 505245
# ASR: ASR001, AG: AG123, AN: 6, Block No: 32, S: 168082
# ASR: ASR001, AG: AG123, AN: 6, Block No: 32, S: 45197
# ASR: ASR001, AG: AG123, AN: 6, Block No: 32, S: 711323
# ASR: ASR001, AG: AG123, AN: 6, Block No: 33, S: 199912
# ASR: ASR001, AG: AG123, AN: 6, Block No: 33, S: 813820
# ASR: ASR001, AG: AG123, AN: 6, Block No: 33, S: 492877
# ASR: ASR001, AG: AG123, AN: 6, Block No: 33, S: 516154
# ASR: ASR001, AG: AG123, AN: 6, Block No: 34, S: 806637
# ASR: ASR001, AG: AG123, AN: 6, Block No: 34, S: 433930
# ASR: ASR001, AG: AG123, AN: 6, Block No: 34, S: 372673
# ASR: ASR001, AG: AG123, AN: 6, Block No: 34, S: 803329
# ASR: ASR001, AG: AG123, AN: 6, Block No: 35, S: 281696
# ASR: ASR001, AG: AG123, AN: 6, Block No: 35, S: 515302
# ASR: ASR001, AG: AG123, AN: 6, Block No: 35, S: 131935
# ASR: ASR001, AG: AG123, AN: 6, Block No: 35, S: 834245
# ASR: ASR001, AG: AG123, AN: 6, Block No: 36, S: 755920
# ASR: ASR001, AG: AG123, AN: 6, Block No: 36, S: 486624
# ASR: ASR001, AG: AG123, AN: 6, Block No: 36, S: 184408
# ASR: ASR001, AG: AG123, AN: 6, Block No: 36, S: 458679
# ASR: ASR001, AG: AG123, AN: 6, Block No: 37, S: 283758
# ASR: ASR001, AG: AG123, AN: 6, Block No: 37, S: 647803
# ASR: ASR001, AG: AG123, AN: 6, Block No: 37, S: 24248
# ASR: ASR001, AG: AG123, AN: 6, Block No: 37, S: 257345
# ASR: ASR001, AG: AG123, AN: 6, Block No: 38, S: 480223
# ASR: ASR001, AG: AG123, AN: 6, Block No: 38, S: 29813
# ASR: ASR001, AG: AG123, AN: 6, Block No: 38, S: 110038
# ASR: ASR001, AG: AG123, AN: 6, Block No: 38, S: 909723
# ASR: ASR001, AG: AG123, AN: 6, Block No: 39, S: 900991
# ASR: ASR001, AG: AG123, AN: 6, Block No: 39, S: 16958
# ASR: ASR001, AG: AG123, AN: 6, Block No: 39, S: 964324
# ASR: ASR001, AG: AG123, AN: 6, Block No: 39, S: 147096
# ASR: ASR001, AG: AG123, AN: 6, Block No: 40, S: 798382
# ASR: ASR001, AG: AG123, AN: 6, Block No: 40, S: 379941
# ASR: ASR001, AG: AG123, AN: 6, Block No: 40, S: 162861
# ASR: ASR001, AG: AG123, AN: 6, Block No: 40, S: 21124
# ASR: ASR001, AG: AG123, AN: 6, Block No: 41, S: 232219
# ASR: ASR001, AG: AG123, AN: 6, Block No: 41, S: 964620
# ASR: ASR001, AG: AG123, AN: 6, Block No: 41, S: 221297
# ASR: ASR001, AG: AG123, AN: 6, Block No: 41, S: 800489
# ASR: ASR001, AG: AG123, AN: 6, Block No: 42, S: 141726
# ASR: ASR001, AG: AG123, AN: 6, Block No: 42, S: 374597
# ASR: ASR001, AG: AG123, AN: 6, Block No: 42, S: 261615
# ASR: ASR001, AG: AG123, AN: 6, Block No: 42, S: 285923
# ASR: ASR001, AG: AG123, AN: 6, Block No: 43, S: 368638
# ASR: ASR001, AG: AG123, AN: 6, Block No: 43, S: 313467
# ASR: ASR001, AG: AG123, AN: 6, Block No: 43, S: 999713
# ASR: ASR001, AG: AG123, AN: 6, Block No: 43, S: 293577
# ASR: ASR001, AG: AG123, AN: 6, Block No: 44, S: 475004
# ASR: ASR001, AG: AG123, AN: 6, Block No: 44, S: 197128
# ASR: ASR001, AG: AG123, AN: 6, Block No: 44, S: 27383
# ASR: ASR001, AG: AG123, AN: 6, Block No: 44, S: 850001
# ASR: ASR001, AG: AG123, AN: 6, Block No: 45, S: 616199
# ASR: ASR001, AG: AG123, AN: 6, Block No: 45, S: 563985
# ASR: ASR001, AG: AG123, AN: 6, Block No: 45, S: 537522
# ASR: ASR001, AG: AG123, AN: 6, Block No: 45, S: 929976
# ASR: ASR001, AG: AG123, AN: 6, Block No: 46, S: 271533
# ASR: ASR001, AG: AG123, AN: 6, Block No: 46, S: 338168
# ASR: ASR001, AG: AG123, AN: 6, Block No: 46, S: 350358
# ASR: ASR001, AG: AG123, AN: 6, Block No: 46, S: 78551
# ASR: ASR001, AG: AG123, AN: 6, Block No: 47, S: 530295
# ASR: ASR001, AG: AG123, AN: 6, Block No: 47, S: 415468
# ASR: ASR001, AG: AG123, AN: 6, Block No: 47, S: 341023
# ASR: ASR001, AG: AG123, AN: 6, Block No: 47, S: 420059
# ASR: ASR001, AG: AG123, AN: 6, Block No: 48, S: 796693
# ASR: ASR001, AG: AG123, AN: 6, Block No: 48, S: 54408
# ASR: ASR001, AG: AG123, AN: 6, Block No: 48, S: 832087
# ASR: ASR001, AG: AG123, AN: 6, Block No: 48, S: 933217
# ASR: ASR001, AG: AG123, AN: 6, Block No: 49, S: 271745
# ASR: ASR001, AG: AG123, AN: 6, Block No: 49, S: 235000
# ASR: ASR001, AG: AG123, AN: 6, Block No: 49, S: 684195
# ASR: ASR001, AG: AG123, AN: 6, Block No: 49, S: 226631
# ASR: ASR001, AG: AG123, AN: 6, Block No: 50, S: 955733
# ASR: ASR001, AG: AG123, AN: 6, Block No: 50, S: 846584
# ASR: ASR001, AG: AG123, AN: 6, Block No: 50, S: 33073
# ASR: ASR001, AG: AG123, AN: 6, Block No: 50, S: 710329
# ASR: ASR001, AG: AG123, AN: 6, Block No: 51, S: 244646
# ASR: ASR001, AG: AG123, AN: 6, Block No: 51, S: 618426
# ASR: ASR001, AG: AG123, AN: 6, Block No: 51, S: 893409
# ASR: ASR001, AG: AG123, AN: 6, Block No: 51, S: 411203
# ASR: ASR001, AG: AG123, AN: 6, Block No: 52, S: 758518
# ASR: ASR001, AG: AG123, AN: 6, Block No: 52, S: 211769
# ASR: ASR001, AG: AG123, AN: 6, Block No: 52, S: 623843
# ASR: ASR001, AG: AG123, AN: 6, Block No: 52, S: 405623
# ASR: ASR001, AG: AG123, AN: 6, Block No: 53, S: 763042
# ASR: ASR001, AG: AG123, AN: 6, Block No: 53, S: 844076
# ASR: ASR001, AG: AG123, AN: 6, Block No: 53, S: 464866
# ASR: ASR001, AG: AG123, AN: 6, Block No: 53, S: 21180
# ASR: ASR001, AG: AG123, AN: 6, Block No: 54, S: 676936
# ASR: ASR001, AG: AG123, AN: 6, Block No: 54, S: 927531
# ASR: ASR001, AG: AG123, AN: 6, Block No: 54, S: 242228
# ASR: ASR001, AG: AG123, AN: 6, Block No: 54, S: 482267
# ASR: ASR001, AG: AG123, AN: 6, Block No: 55, S: 639992
# ASR: ASR001, AG: AG123, AN: 6, Block No: 55, S: 611638
# ASR: ASR001, AG: AG123, AN: 6, Block No: 55, S: 267240
# ASR: ASR001, AG: AG123, AN: 6, Block No: 55, S: 117585
# ASR: ASR001, AG: AG123, AN: 6, Block No: 56, S: 627402
# ASR: ASR001, AG: AG123, AN: 6, Block No: 56, S: 193600
# ASR: ASR001, AG: AG123, AN: 6, Block No: 56, S: 750214
# ASR: ASR001, AG: AG123, AN: 6, Block No: 56, S: 337536
# ASR: ASR001, AG: AG123, AN: 6, Block No: 57, S: 79840
# ASR: ASR001, AG: AG123, AN: 6, Block No: 57, S: 269759
# ASR: ASR001, AG: AG123, AN: 6, Block No: 57, S: 745874
# ASR: ASR001, AG: AG123, AN: 6, Block No: 57, S: 833920
# ASR: ASR001, AG: AG123, AN: 6, Block No: 58, S: 271513
# ASR: ASR001, AG: AG123, AN: 6, Block No: 58, S: 609534
# ASR: ASR001, AG: AG123, AN: 6, Block No: 58, S: 900242
# ASR: ASR001, AG: AG123, AN: 6, Block No: 58, S: 164324
# ASR: ASR001, AG: AG123, AN: 6, Block No: 59, S: 328811
# ASR: ASR001, AG: AG123, AN: 6, Block No: 59, S: 631219
# ASR: ASR001, AG: AG123, AN: 6, Block No: 59, S: 618972
# ASR: ASR001, AG: AG123, AN: 6, Block No: 59, S: 438996
# ASR: ASR001, AG: AG123, AN: 6, Block No: 60, S: 288393
# ASR: ASR001, AG: AG123, AN: 6, Block No: 60, S: 792175
# ASR: ASR001, AG: AG123, AN: 6, Block No: 60, S: 964931
# ASR: ASR001, AG: AG123, AN: 6, Block No: 60, S: 431483
# ASR: ASR001, AG: AG123, AN: 6, Block No: 61, S: 517482
# ASR: ASR001, AG: AG123, AN: 6, Block No: 61, S: 413761
# ASR: ASR001, AG: AG123, AN: 6, Block No: 61, S: 816343
# ASR: ASR001, AG: AG123, AN: 6, Block No: 61, S: 250234
# ASR: ASR001, AG: AG123, AN: 6, Block No: 62, S: 623119
# ASR: ASR001, AG: AG123, AN: 6, Block No: 62, S: 440951
# ASR: ASR001, AG: AG123, AN: 6, Block No: 62, S: 442948
# ASR: ASR001, AG: AG123, AN: 6, Block No: 62, S: 938876
# ASR: ASR001, AG: AG123, AN: 6, Block No: 63, S: 386079
# ASR: ASR001, AG: AG123, AN: 6, Block No: 63, S: 958072
# ASR: ASR001, AG: AG123, AN: 6, Block No: 63, S: 493855
# ASR: ASR001, AG: AG123, AN: 6, Block No: 63, S: 806785
# ASR: ASR001, AG: AG123, AN: 6, Block No: 64, S: 590473
# ASR: ASR001, AG: AG123, AN: 6, Block No: 64, S: 563585
# ASR: ASR001, AG: AG123, AN: 6, Block No: 64, S: 9168
# ASR: ASR001, AG: AG123, AN: 6, Block No: 64, S: 339316
# ASR: ASR001, AG: AG123, AN: 6, Block No: 65, S: 594406
# ASR: ASR001, AG: AG123, AN: 6, Block No: 65, S: 459012
# ASR: ASR001, AG: AG123, AN: 6, Block No: 65, S: 799542
# ASR: ASR001, AG: AG123, AN: 6, Block No: 65, S: 960392
# ASR: ASR001, AG: AG123, AN: 6, Block No: 66, S: 807485
# ASR: ASR001, AG: AG123, AN: 6, Block No: 66, S: 508441
# ASR: ASR001, AG: AG123, AN: 6, Block No: 66, S: 896785
# ASR: ASR001, AG: AG123, AN: 6, Block No: 66, S: 176458
# ASR: ASR001, AG: AG123, AN: 6, Block No: 67, S: 6325
# ASR: ASR001, AG: AG123, AN: 6, Block No: 67, S: 804779
# ASR: ASR001, AG: AG123, AN: 6, Block No: 67, S: 586585
# ASR: ASR001, AG: AG123, AN: 6, Block No: 67, S: 575403
# ASR: ASR001, AG: AG123, AN: 6, Block No: 68, S: 543939
# ASR: ASR001, AG: AG123, AN: 6, Block No: 68, S: 919149
# ASR: ASR001, AG: AG123, AN: 6, Block No: 68, S: 586705
# ASR: ASR001, AG: AG123, AN: 6, Block No: 68, S: 334352
# ASR: ASR001, AG: AG123, AN: 6, Block No: 69, S: 481474
# ASR: ASR001, AG: AG123, AN: 6, Block No: 69, S: 138514
# ASR: ASR001, AG: AG123, AN: 6, Block No: 69, S: 319638
# ASR: ASR001, AG: AG123, AN: 6, Block No: 69, S: 784820
# ASR: ASR001, AG: AG123, AN: 6, Block No: 70, S: 667056
# ASR: ASR001, AG: AG123, AN: 6, Block No: 70, S: 94937
# ASR: ASR001, AG: AG123, AN: 6, Block No: 70, S: 841751
# ASR: ASR001, AG: AG123, AN: 6, Block No: 70, S: 672989
# ASR: ASR001, AG: AG123, AN: 6, Block No: 71, S: 390995
# ASR: ASR001, AG: AG123, AN: 6, Block No: 71, S: 823374
# ASR: ASR001, AG: AG123, AN: 6, Block No: 71, S: 254964
# ASR: ASR001, AG: AG123, AN: 6, Block No: 71, S: 565293
# ASR: ASR001, AG: AG123, AN: 6, Block No: 72, S: 373041
# ASR: ASR001, AG: AG123, AN: 6, Block No: 72, S: 64557
# ASR: ASR001, AG: AG123, AN: 6, Block No: 72, S: 5843
# ASR: ASR001, AG: AG123, AN: 6, Block No: 72, S: 662209
# ASR: ASR001, AG: AG123, AN: 6, Block No: 73, S: 945053
# ASR: ASR001, AG: AG123, AN: 6, Block No: 73, S: 468493
# ASR: ASR001, AG: AG123, AN: 6, Block No: 73, S: 816368
# ASR: ASR001, AG: AG123, AN: 6, Block No: 73, S: 671803
# ASR: ASR001, AG: AG123, AN: 6, Block No: 74, S: 511094
# ASR: ASR001, AG: AG123, AN: 6, Block No: 74, S: 475660
# ASR: ASR001, AG: AG123, AN: 6, Block No: 74, S: 994905
# ASR: ASR001, AG: AG123, AN: 6, Block No: 74, S: 837311
# ASR: ASR001, AG: AG123, AN: 6, Block No: 75, S: 441770
# ASR: ASR001, AG: AG123, AN: 6, Block No: 75, S: 865490
# ASR: ASR001, AG: AG123, AN: 6, Block No: 75, S: 897839
# ASR: ASR001, AG: AG123, AN: 6, Block No: 75, S: 531151
# ASR: ASR001, AG: AG123, AN: 6, Block No: 76, S: 203828
# ASR: ASR001, AG: AG123, AN: 6, Block No: 76, S: 336569
# ASR: ASR001, AG: AG123, AN: 6, Block No: 76, S: 52310
# ASR: ASR001, AG: AG123, AN: 6, Block No: 76, S: 835627
# ASR: ASR001, AG: AG123, AN: 6, Block No: 77, S: 385146
# ASR: ASR001, AG: AG123, AN: 6, Block No: 77, S: 171955
# ASR: ASR001, AG: AG123, AN: 6, Block No: 77, S: 559097
# ASR: ASR001, AG: AG123, AN: 6, Block No: 77, S: 127847
# ASR: ASR001, AG: AG123, AN: 6, Block No: 78, S: 654099
# ASR: ASR001, AG: AG123, AN: 6, Block No: 78, S: 859095
# ASR: ASR001, AG: AG123, AN: 6, Block No: 78, S: 614097
# ASR: ASR001, AG: AG123, AN: 6, Block No: 78, S: 368234
# ASR: ASR001, AG: AG123, AN: 6, Block No: 79, S: 121957
# ASR: ASR001, AG: AG123, AN: 6, Block No: 79, S: 113221
# ASR: ASR001, AG: AG123, AN: 6, Block No: 79, S: 132078
# ASR: ASR001, AG: AG123, AN: 6, Block No: 79, S: 704141
# ASR: ASR001, AG: AG123, AN: 6, Block No: 80, S: 644200
# ASR: ASR001, AG: AG123, AN: 6, Block No: 80, S: 883193
# ASR: ASR001, AG: AG123, AN: 6, Block No: 80, S: 70262
# ASR: ASR001, AG: AG123, AN: 6, Block No: 80, S: 22551
# ASR: ASR001, AG: AG123, AN: 6, Block No: 81, S: 18211
# ASR: ASR001, AG: AG123, AN: 6, Block No: 81, S: 711069
# ASR: ASR001, AG: AG123, AN: 6, Block No: 81, S: 51054
# ASR: ASR001, AG: AG123, AN: 6, Block No: 81, S: 490280
# ASR: ASR001, AG: AG123, AN: 6, Block No: 82, S: 452972
# ASR: ASR001, AG: AG123, AN: 6, Block No: 82, S: 492895
# ASR: ASR001, AG: AG123, AN: 6, Block No: 82, S: 802073
# ASR: ASR001, AG: AG123, AN: 6, Block No: 82, S: 790887
# ASR: ASR001, AG: AG123, AN: 6, Block No: 83, S: 598619
# ASR: ASR001, AG: AG123, AN: 6, Block No: 83, S: 928838
# ASR: ASR001, AG: AG123, AN: 6, Block No: 83, S: 226592
# ASR: ASR001, AG: AG123, AN: 6, Block No: 83, S: 214301
# ASR: ASR001, AG: AG123, AN: 6, Block No: 84, S: 986103
# ASR: ASR001, AG: AG123, AN: 6, Block No: 84, S: 892820
# ASR: ASR001, AG: AG123, AN: 6, Block No: 84, S: 950519
# ASR: ASR001, AG: AG123, AN: 6, Block No: 84, S: 19059
# ASR: ASR001, AG: AG123, AN: 6, Block No: 85, S: 142526
# ASR: ASR001, AG: AG123, AN: 6, Block No: 85, S: 852983
# ASR: ASR001, AG: AG123, AN: 6, Block No: 85, S: 608516
# ASR: ASR001, AG: AG123, AN: 6, Block No: 85, S: 787720
# ASR: ASR001, AG: AG123, AN: 6, Block No: 86, S: 815771
# ASR: ASR001, AG: AG123, AN: 6, Block No: 86, S: 23214
# ASR: ASR001, AG: AG123, AN: 6, Block No: 86, S: 949692
# ASR: ASR001, AG: AG123, AN: 6, Block No: 86, S: 960608
# ASR: ASR001, AG: AG123, AN: 6, Block No: 87, S: 46392
# ASR: ASR001, AG: AG123, AN: 6, Block No: 87, S: 842879
# ASR: ASR001, AG: AG123, AN: 6, Block No: 87, S: 668060
# ASR: ASR001, AG: AG123, AN: 6, Block No: 87, S: 865730
# ASR: ASR001, AG: AG123, AN: 6, Block No: 88, S: 773167
# ASR: ASR001, AG: AG123, AN: 6, Block No: 88, S: 661637
# ASR: ASR001, AG: AG123, AN: 6, Block No: 88, S: 789312
# ASR: ASR001, AG: AG123, AN: 6, Block No: 88, S: 364294
# ASR: ASR001, AG: AG123, AN: 6, Block No: 89, S: 531738
# ASR: ASR001, AG: AG123, AN: 6, Block No: 89, S: 524282
# ASR: ASR001, AG: AG123, AN: 6, Block No: 89, S: 541470
# ASR: ASR001, AG: AG123, AN: 6, Block No: 89, S: 651976
# ASR: ASR001, AG: AG123, AN: 6, Block No: 90, S: 916928
# ASR: ASR001, AG: AG123, AN: 6, Block No: 90, S: 330807
# ASR: ASR001, AG: AG123, AN: 6, Block No: 90, S: 513644
# ASR: ASR001, AG: AG123, AN: 6, Block No: 90, S: 534865
# ASR: ASR001, AG: AG123, AN: 6, Block No: 91, S: 62037
# ASR: ASR001, AG: AG123, AN: 6, Block No: 91, S: 468848
# ASR: ASR001, AG: AG123, AN: 6, Block No: 91, S: 577362
# ASR: ASR001, AG: AG123, AN: 6, Block No: 91, S: 814086
# ASR: ASR001, AG: AG123, AN: 6, Block No: 92, S: 446188
# ASR: ASR001, AG: AG123, AN: 6, Block No: 92, S: 928140
# ASR: ASR001, AG: AG123, AN: 6, Block No: 92, S: 92541
# ASR: ASR001, AG: AG123, AN: 6, Block No: 92, S: 276962
# ASR: ASR001, AG: AG123, AN: 6, Block No: 93, S: 804724
# ASR: ASR001, AG: AG123, AN: 6, Block No: 93, S: 794151
# ASR: ASR001, AG: AG123, AN: 6, Block No: 93, S: 763750
# ASR: ASR001, AG: AG123, AN: 6, Block No: 93, S: 531458
# ASR: ASR001, AG: AG123, AN: 6, Block No: 94, S: 483096
# ASR: ASR001, AG: AG123, AN: 6, Block No: 94, S: 573345
# ASR: ASR001, AG: AG123, AN: 6, Block No: 94, S: 861643
# ASR: ASR001, AG: AG123, AN: 6, Block No: 94, S: 909982
# ASR: ASR001, AG: AG123, AN: 6, Block No: 95, S: 933369
# ASR: ASR001, AG: AG123, AN: 6, Block No: 95, S: 131989
# ASR: ASR001, AG: AG123, AN: 6, Block No: 95, S: 510776
# ASR: ASR001, AG: AG123, AN: 6, Block No: 95, S: 448732
# ASR: ASR001, AG: AG123, AN: 6, Block No: 96, S: 829047
# ASR: ASR001, AG: AG123, AN: 6, Block No: 96, S: 383388
# ASR: ASR001, AG: AG123, AN: 6, Block No: 96, S: 982305
# ASR: ASR001, AG: AG123, AN: 6, Block No: 96, S: 509310
# ASR: ASR001, AG: AG123, AN: 6, Block No: 97, S: 853751
# ASR: ASR001, AG: AG123, AN: 6, Block No: 97, S: 564216
# ASR: ASR001, AG: AG123, AN: 6, Block No: 97, S: 620309
# ASR: ASR001, AG: AG123, AN: 6, Block No: 97, S: 561872
# ASR: ASR001, AG: AG123, AN: 6, Block No: 98, S: 691984
# ASR: ASR001, AG: AG123, AN: 6, Block No: 98, S: 558695
# ASR: ASR001, AG: AG123, AN: 6, Block No: 98, S: 447824
# ASR: ASR001, AG: AG123, AN: 6, Block No: 98, S: 264411
# ASR: ASR001, AG: AG123, AN: 6, Block No: 99, S: 474317
# ASR: ASR001, AG: AG123, AN: 6, Block No: 99, S: 765320
# ASR: ASR001, AG: AG123, AN: 6, Block No: 99, S: 770461
# ASR: ASR001, AG: AG123, AN: 6, Block No: 99, S: 937197
# ASR: ASR001, AG: AG123, AN: 6, Block No: 100, S: 680200
# ASR: ASR001, AG: AG123, AN: 6, Block No: 100, S: 877792
# ASR: ASR001, AG: AG123, AN: 6, Block No: 100, S: 669692
# ASR: ASR001, AG: AG123, AN: 6, Block No: 100, S: 683063
# ASR: ASR001, AG: AG123, AN: 6, Block No: 101, S: 203974
# ASR: ASR001, AG: AG123, AN: 6, Block No: 101, S: 198649
# ASR: ASR001, AG: AG123, AN: 6, Block No: 101, S: 705202
# ASR: ASR001, AG: AG123, AN: 6, Block No: 101, S: 807779
# ASR: ASR001, AG: AG123, AN: 6, Block No: 102, S: 324913
# ASR: ASR001, AG: AG123, AN: 6, Block No: 102, S: 753532
# ASR: ASR001, AG: AG123, AN: 6, Block No: 102, S: 663947
# ASR: ASR001, AG: AG123, AN: 6, Block No: 102, S: 287302
# ASR: ASR001, AG: AG123, AN: 6, Block No: 103, S: 101853
# ASR: ASR001, AG: AG123, AN: 6, Block No: 103, S: 545399
# ASR: ASR001, AG: AG123, AN: 6, Block No: 103, S: 353465
# ASR: ASR001, AG: AG123, AN: 6, Block No: 103, S: 880478
# ASR: ASR001, AG: AG123, AN: 6, Block No: 104, S: 996877
# ASR: ASR001, AG: AG123, AN: 6, Block No: 104, S: 626336
# ASR: ASR001, AG: AG123, AN: 6, Block No: 104, S: 11346
# ASR: ASR001, AG: AG123, AN: 6, Block No: 104, S: 481101
# ASR: ASR001, AG: AG123, AN: 6, Block No: 105, S: 83743
# ASR: ASR001, AG: AG123, AN: 6, Block No: 105, S: 118913
# ASR: ASR001, AG: AG123, AN: 6, Block No: 105, S: 334555
# ASR: ASR001, AG: AG123, AN: 6, Block No: 105, S: 199203
# ASR: ASR001, AG: AG123, AN: 6, Block No: 106, S: 841877
# ASR: ASR001, AG: AG123, AN: 6, Block No: 106, S: 369334
# ASR: ASR001, AG: AG123, AN: 6, Block No: 106, S: 662353
# ASR: ASR001, AG: AG123, AN: 6, Block No: 106, S: 115208
# ASR: ASR001, AG: AG123, AN: 6, Block No: 107, S: 332808
# ASR: ASR001, AG: AG123, AN: 6, Block No: 107, S: 214774
# ASR: ASR001, AG: AG123, AN: 6, Block No: 107, S: 793211
# ASR: ASR001, AG: AG123, AN: 6, Block No: 107, S: 200623
# ASR: ASR001, AG: AG123, AN: 6, Block No: 108, S: 117365
# ASR: ASR001, AG: AG123, AN: 6, Block No: 108, S: 872063
# ASR: ASR001, AG: AG123, AN: 6, Block No: 108, S: 360851
# ASR: ASR001, AG: AG123, AN: 6, Block No: 108, S: 443613
# ASR: ASR001, AG: AG123, AN: 6, Block No: 109, S: 277152
# ASR: ASR001, AG: AG123, AN: 6, Block No: 109, S: 564220
# ASR: ASR001, AG: AG123, AN: 6, Block No: 109, S: 384522
# ASR: ASR001, AG: AG123, AN: 6, Block No: 109, S: 633721
# ASR: ASR001, AG: AG123, AN: 6, Block No: 110, S: 771341
# ASR: ASR001, AG: AG123, AN: 6, Block No: 110, S: 501799
# ASR: ASR001, AG: AG123, AN: 6, Block No: 110, S: 984423
# ASR: ASR001, AG: AG123, AN: 6, Block No: 110, S: 653259
# ASR: ASR001, AG: AG123, AN: 6, Block No: 111, S: 901285
# ASR: ASR001, AG: AG123, AN: 6, Block No: 111, S: 250336
# ASR: ASR001, AG: AG123, AN: 6, Block No: 111, S: 660804
# ASR: ASR001, AG: AG123, AN: 6, Block No: 111, S: 372213
# ASR: ASR001, AG: AG123, AN: 6, Block No: 112, S: 182970
# ASR: ASR001, AG: AG123, AN: 6, Block No: 112, S: 196384
# ASR: ASR001, AG: AG123, AN: 6, Block No: 112, S: 972841
# ASR: ASR001, AG: AG123, AN: 6, Block No: 112, S: 318566
# ASR: ASR001, AG: AG123, AN: 6, Block No: 113, S: 272113
# ASR: ASR001, AG: AG123, AN: 6, Block No: 113, S: 144553
# ASR: ASR001, AG: AG123, AN: 6, Block No: 113, S: 704956
# ASR: ASR001, AG: AG123, AN: 6, Block No: 113, S: 50338
# ASR: ASR001, AG: AG123, AN: 6, Block No: 114, S: 283595
# ASR: ASR001, AG: AG123, AN: 6, Block No: 114, S: 153486
# ASR: ASR001, AG: AG123, AN: 6, Block No: 114, S: 914789
# ASR: ASR001, AG: AG123, AN: 6, Block No: 114, S: 79265
# ASR: ASR001, AG: AG123, AN: 6, Block No: 115, S: 421638
# ASR: ASR001, AG: AG123, AN: 6, Block No: 115, S: 188620
# ASR: ASR001, AG: AG123, AN: 6, Block No: 115, S: 640419
# ASR: ASR001, AG: AG123, AN: 6, Block No: 115, S: 613209
# ASR: ASR001, AG: AG123, AN: 6, Block No: 116, S: 817985
# ASR: ASR001, AG: AG123, AN: 6, Block No: 116, S: 913085
# ASR: ASR001, AG: AG123, AN: 6, Block No: 116, S: 24244
# ASR: ASR001, AG: AG123, AN: 6, Block No: 116, S: 501450
# ASR: ASR001, AG: AG123, AN: 6, Block No: 117, S: 892752
# ASR: ASR001, AG: AG123, AN: 6, Block No: 117, S: 864307
# ASR: ASR001, AG: AG123, AN: 6, Block No: 117, S: 541310
# ASR: ASR001, AG: AG123, AN: 6, Block No: 117, S: 700684
# ASR: ASR001, AG: AG123, AN: 6, Block No: 118, S: 583492
# ASR: ASR001, AG: AG123, AN: 6, Block No: 118, S: 958147
# ASR: ASR001, AG: AG123, AN: 6, Block No: 118, S: 355236
# ASR: ASR001, AG: AG123, AN: 6, Block No: 118, S: 824974
# ASR: ASR001, AG: AG123, AN: 6, Block No: 119, S: 460932
# ASR: ASR001, AG: AG123, AN: 6, Block No: 119, S: 845730
# ASR: ASR001, AG: AG123, AN: 6, Block No: 119, S: 501905
# ASR: ASR001, AG: AG123, AN: 6, Block No: 119, S: 678204
# ASR: ASR001, AG: AG123, AN: 6, Block No: 120, S: 997346
# ASR: ASR001, AG: AG123, AN: 6, Block No: 120, S: 352973
# ASR: ASR001, AG: AG123, AN: 6, Block No: 120, S: 229758
# ASR: ASR001, AG: AG123, AN: 6, Block No: 120, S: 722837
# ASR: ASR001, AG: AG123, AN: 6, Block No: 121, S: 105355
# ASR: ASR001, AG: AG123, AN: 6, Block No: 121, S: 246216
# ASR: ASR001, AG: AG123, AN: 6, Block No: 121, S: 102887
# ASR: ASR001, AG: AG123, AN: 6, Block No: 121, S: 316979
# ASR: ASR001, AG: AG123, AN: 6, Block No: 122, S: 757923
# ASR: ASR001, AG: AG123, AN: 6, Block No: 122, S: 685810
# ASR: ASR001, AG: AG123, AN: 6, Block No: 122, S: 813422
# ASR: ASR001, AG: AG123, AN: 6, Block No: 122, S: 643791
# ASR: ASR001, AG: AG123, AN: 6, Block No: 123, S: 941468
# ASR: ASR001, AG: AG123, AN: 6, Block No: 123, S: 832589
# ASR: ASR001, AG: AG123, AN: 6, Block No: 123, S: 240433
# ASR: ASR001, AG: AG123, AN: 6, Block No: 123, S: 392599
# ASR: ASR001, AG: AG123, AN: 6, Block No: 124, S: 412793
# ASR: ASR001, AG: AG123, AN: 6, Block No: 124, S: 475577
# ASR: ASR001, AG: AG123, AN: 6, Block No: 124, S: 760855
# ASR: ASR001, AG: AG123, AN: 6, Block No: 124, S: 307209
# ASR: ASR001, AG: AG123, AN: 6, Block No: 125, S: 58503
# ASR: ASR001, AG: AG123, AN: 6, Block No: 125, S: 843578
# ASR: ASR001, AG: AG123, AN: 6, Block No: 125, S: 925510
# ASR: ASR001, AG: AG123, AN: 6, Block No: 125, S: 808515
# ASR: ASR001, AG: AG123, AN: 6, Block No: 126, S: 445245
# ASR: ASR001, AG: AG123, AN: 6, Block No: 126, S: 251024
# ASR: ASR001, AG: AG123, AN: 6, Block No: 126, S: 609896
# ASR: ASR001, AG: AG123, AN: 6, Block No: 126, S: 408532
# ASR: ASR001, AG: AG123, AN: 6, Block No: 127, S: 44313
# ASR: ASR001, AG: AG123, AN: 6, Block No: 127, S: 763764
# ASR: ASR001, AG: AG123, AN: 6, Block No: 127, S: 547842
# ASR: ASR001, AG: AG123, AN: 6, Block No: 127, S: 538193
# ASR: ASR001, AG: AG123, AN: 6, Block No: 128, S: 830665
# ASR: ASR001, AG: AG123, AN: 6, Block No: 128, S: 871446
# ASR: ASR001, AG: AG123, AN: 6, Block No: 128, S: 141298
# ASR: ASR001, AG: AG123, AN: 6, Block No: 128, S: 748019
# ASR: ASR001, AG: AG123, AN: 6, Block No: 129, S: 736175
# ASR: ASR001, AG: AG123, AN: 6, Block No: 129, S: 846513
# ASR: ASR001, AG: AG123, AN: 6, Block No: 129, S: 266846
# ASR: ASR001, AG: AG123, AN: 6, Block No: 129, S: 583157
# ASR: ASR001, AG: AG123, AN: 6, Block No: 130, S: 912741
# ASR: ASR001, AG: AG123, AN: 6, Block No: 130, S: 955535
# ASR: ASR001, AG: AG123, AN: 6, Block No: 130, S: 762842
# ASR: ASR001, AG: AG123, AN: 6, Block No: 130, S: 566210
# ASR: ASR001, AG: AG123, AN: 6, Block No: 131, S: 442637
# ASR: ASR001, AG: AG123, AN: 6, Block No: 131, S: 265597
# ASR: ASR001, AG: AG123, AN: 6, Block No: 131, S: 27785
# ASR: ASR001, AG: AG123, AN: 6, Block No: 131, S: 916643
# ASR: ASR001, AG: AG123, AN: 6, Block No: 132, S: 810216
# ASR: ASR001, AG: AG123, AN: 6, Block No: 132, S: 518126
# ASR: ASR001, AG: AG123, AN: 6, Block No: 132, S: 363034
# ASR: ASR001, AG: AG123, AN: 6, Block No: 132, S: 62150
# ASR: ASR001, AG: AG123, AN: 6, Block No: 133, S: 450981
# ASR: ASR001, AG: AG123, AN: 6, Block No: 133, S: 39484
# ASR: ASR001, AG: AG123, AN: 6, Block No: 133, S: 685507
# ASR: ASR001, AG: AG123, AN: 6, Block No: 133, S: 628869
# ASR: ASR001, AG: AG123, AN: 6, Block No: 134, S: 66744
# ASR: ASR001, AG: AG123, AN: 6, Block No: 134, S: 108617
# ASR: ASR001, AG: AG123, AN: 6, Block No: 134, S: 197842
# ASR: ASR001, AG: AG123, AN: 6, Block No: 134, S: 909567
# ASR: ASR001, AG: AG123, AN: 6, Block No: 135, S: 573745
# ASR: ASR001, AG: AG123, AN: 6, Block No: 135, S: 237854
# ASR: ASR001, AG: AG123, AN: 6, Block No: 135, S: 426998
# ASR: ASR001, AG: AG123, AN: 6, Block No: 135, S: 428361
# ASR: ASR001, AG: AG123, AN: 6, Block No: 136, S: 619910
# ASR: ASR001, AG: AG123, AN: 6, Block No: 136, S: 295814
# ASR: ASR001, AG: AG123, AN: 6, Block No: 136, S: 614540
# ASR: ASR001, AG: AG123, AN: 6, Block No: 136, S: 657678
# ASR: ASR001, AG: AG123, AN: 6, Block No: 137, S: 249135
# ASR: ASR001, AG: AG123, AN: 6, Block No: 137, S: 257217
# ASR: ASR001, AG: AG123, AN: 6, Block No: 137, S: 917049
# ASR: ASR001, AG: AG123, AN: 6, Block No: 137, S: 528994
# ASR: ASR001, AG: AG123, AN: 6, Block No: 138, S: 671281
# ASR: ASR001, AG: AG123, AN: 6, Block No: 138, S: 18056
# ASR: ASR001, AG: AG123, AN: 6, Block No: 138, S: 824050
# ASR: ASR001, AG: AG123, AN: 6, Block No: 138, S: 693156
# ASR: ASR001, AG: AG123, AN: 6, Block No: 139, S: 612710
# ASR: ASR001, AG: AG123, AN: 6, Block No: 139, S: 782675
# ASR: ASR001, AG: AG123, AN: 6, Block No: 139, S: 934917
# ASR: ASR001, AG: AG123, AN: 6, Block No: 139, S: 164776
# ASR: ASR001, AG: AG123, AN: 6, Block No: 140, S: 784779
# ASR: ASR001, AG: AG123, AN: 6, Block No: 140, S: 226943
# ASR: ASR001, AG: AG123, AN: 6, Block No: 140, S: 229376
# ASR: ASR001, AG: AG123, AN: 6, Block No: 140, S: 394256
# ASR: ASR001, AG: AG123, AN: 6, Block No: 141, S: 43004
# ASR: ASR001, AG: AG123, AN: 6, Block No: 141, S: 89461
# ASR: ASR001, AG: AG123, AN: 6, Block No: 141, S: 715119
# ASR: ASR001, AG: AG123, AN: 6, Block No: 141, S: 425122
# ASR: ASR001, AG: AG123, AN: 6, Block No: 142, S: 456661
# ASR: ASR001, AG: AG123, AN: 6, Block No: 142, S: 215769
# ASR: ASR001, AG: AG123, AN: 6, Block No: 142, S: 614511
# ASR: ASR001, AG: AG123, AN: 6, Block No: 142, S: 814602
# ASR: ASR001, AG: AG123, AN: 6, Block No: 143, S: 777742
# ASR: ASR001, AG: AG123, AN: 6, Block No: 143, S: 448850
# ASR: ASR001, AG: AG123, AN: 6, Block No: 143, S: 85960
# ASR: ASR001, AG: AG123, AN: 6, Block No: 143, S: 345003
# ASR: ASR001, AG: AG123, AN: 6, Block No: 144, S: 342227
# ASR: ASR001, AG: AG123, AN: 6, Block No: 144, S: 713376
# ASR: ASR001, AG: AG123, AN: 6, Block No: 144, S: 479153
# ASR: ASR001, AG: AG123, AN: 6, Block No: 144, S: 645063
# ASR: ASR001, AG: AG123, AN: 6, Block No: 145, S: 205154
# ASR: ASR001, AG: AG123, AN: 6, Block No: 145, S: 513136
# ASR: ASR001, AG: AG123, AN: 6, Block No: 145, S: 64490
# ASR: ASR001, AG: AG123, AN: 6, Block No: 145, S: 153598
# ASR: ASR001, AG: AG123, AN: 6, Block No: 146, S: 939918
# ASR: ASR001, AG: AG123, AN: 6, Block No: 146, S: 457047
# ASR: ASR001, AG: AG123, AN: 6, Block No: 146, S: 597194
# ASR: ASR001, AG: AG123, AN: 6, Block No: 146, S: 361099
# ASR: ASR001, AG: AG123, AN: 6, Block No: 147, S: 826746
# ASR: ASR001, AG: AG123, AN: 6, Block No: 147, S: 451351
# ASR: ASR001, AG: AG123, AN: 6, Block No: 147, S: 101810
# ASR: ASR001, AG: AG123, AN: 6, Block No: 147, S: 587921
# ASR: ASR001, AG: AG123, AN: 6, Block No: 148, S: 244949
# ASR: ASR001, AG: AG123, AN: 6, Block No: 148, S: 656834
# ASR: ASR001, AG: AG123, AN: 6, Block No: 148, S: 962679
# ASR: ASR001, AG: AG123, AN: 6, Block No: 148, S: 523760
# ASR: ASR001, AG: AG123, AN: 6, Block No: 149, S: 378315
# ASR: ASR001, AG: AG123, AN: 6, Block No: 149, S: 921549
# ASR: ASR001, AG: AG123, AN: 6, Block No: 149, S: 227141
# ASR: ASR001, AG: AG123, AN: 6, Block No: 149, S: 116483
# ASR: ASR001, AG: AG123, AN: 6, Block No: 150, S: 185961
# ASR: ASR001, AG: AG123, AN: 6, Block No: 150, S: 516080
# ASR: ASR001, AG: AG123, AN: 6, Block No: 150, S: 125555
# ASR: ASR001, AG: AG123, AN: 6, Block No: 150, S: 48443
# ASR: ASR001, AG: AG123, AN: 6, Block No: 151, S: 123348
# ASR: ASR001, AG: AG123, AN: 6, Block No: 151, S: 970861
# ASR: ASR001, AG: AG123, AN: 6, Block No: 151, S: 341226
# ASR: ASR001, AG: AG123, AN: 6, Block No: 151, S: 192634
# ASR: ASR001, AG: AG123, AN: 6, Block No: 152, S: 175056
# ASR: ASR001, AG: AG123, AN: 6, Block No: 152, S: 32535
# ASR: ASR001, AG: AG123, AN: 6, Block No: 152, S: 425722
# ASR: ASR001, AG: AG123, AN: 6, Block No: 152, S: 446833
# ASR: ASR001, AG: AG123, AN: 6, Block No: 153, S: 483431
# ASR: ASR001, AG: AG123, AN: 6, Block No: 153, S: 70689
# ASR: ASR001, AG: AG123, AN: 6, Block No: 153, S: 918079
# ASR: ASR001, AG: AG123, AN: 6, Block No: 153, S: 423938
# ASR: ASR001, AG: AG123, AN: 6, Block No: 154, S: 731612
# ASR: ASR001, AG: AG123, AN: 6, Block No: 154, S: 719570
# ASR: ASR001, AG: AG123, AN: 6, Block No: 154, S: 850255
# ASR: ASR001, AG: AG123, AN: 6, Block No: 154, S: 989018
# ASR: ASR001, AG: AG123, AN: 6, Block No: 155, S: 43697
# ASR: ASR001, AG: AG123, AN: 6, Block No: 155, S: 619149
# ASR: ASR001, AG: AG123, AN: 6, Block No: 155, S: 313373
# ASR: ASR001, AG: AG123, AN: 6, Block No: 155, S: 887831
# ASR: ASR001, AG: AG123, AN: 6, Block No: 156, S: 559893
# ASR: ASR001, AG: AG123, AN: 6, Block No: 156, S: 607186
# ASR: ASR001, AG: AG123, AN: 6, Block No: 156, S: 333932
# ASR: ASR001, AG: AG123, AN: 6, Block No: 156, S: 803853
# ASR: ASR001, AG: AG123, AN: 6, Block No: 157, S: 535925
# ASR: ASR001, AG: AG123, AN: 6, Block No: 157, S: 57624
# ASR: ASR001, AG: AG123, AN: 6, Block No: 157, S: 923808
# ASR: ASR001, AG: AG123, AN: 6, Block No: 157, S: 314768
# ASR: ASR001, AG: AG123, AN: 6, Block No: 158, S: 388134
# ASR: ASR001, AG: AG123, AN: 6, Block No: 158, S: 272508
# ASR: ASR001, AG: AG123, AN: 6, Block No: 158, S: 589651
# ASR: ASR001, AG: AG123, AN: 6, Block No: 158, S: 154614
# ASR: ASR001, AG: AG123, AN: 6, Block No: 159, S: 913283
# ASR: ASR001, AG: AG123, AN: 6, Block No: 159, S: 962363
# ASR: ASR001, AG: AG123, AN: 6, Block No: 159, S: 444247
# ASR: ASR001, AG: AG123, AN: 6, Block No: 159, S: 947850
# ASR: ASR001, AG: AG123, AN: 6, Block No: 160, S: 425333
# ASR: ASR001, AG: AG123, AN: 6, Block No: 160, S: 542657
# ASR: ASR001, AG: AG123, AN: 6, Block No: 160, S: 168162
# ASR: ASR001, AG: AG123, AN: 6, Block No: 160, S: 365582
# ASR: ASR001, AG: AG123, AN: 6, Block No: 161, S: 34792
# ASR: ASR001, AG: AG123, AN: 6, Block No: 161, S: 238717
# ASR: ASR001, AG: AG123, AN: 6, Block No: 161, S: 179976
# ASR: ASR001, AG: AG123, AN: 6, Block No: 161, S: 726090
# ASR: ASR001, AG: AG123, AN: 6, Block No: 162, S: 997873
# ASR: ASR001, AG: AG123, AN: 6, Block No: 162, S: 169265
# ASR: ASR001, AG: AG123, AN: 6, Block No: 162, S: 631228
# ASR: ASR001, AG: AG123, AN: 6, Block No: 162, S: 105788
# ASR: ASR001, AG: AG123, AN: 6, Block No: 163, S: 807398
# ASR: ASR001, AG: AG123, AN: 6, Block No: 163, S: 754169
# ASR: ASR001, AG: AG123, AN: 6, Block No: 163, S: 118421
# ASR: ASR001, AG: AG123, AN: 6, Block No: 163, S: 67362
# ASR: ASR001, AG: AG123, AN: 6, Block No: 164, S: 150209
# ASR: ASR001, AG: AG123, AN: 6, Block No: 164, S: 908838
# ASR: ASR001, AG: AG123, AN: 6, Block No: 164, S: 798541
# ASR: ASR001, AG: AG123, AN: 6, Block No: 164, S: 731649
# ASR: ASR001, AG: AG123, AN: 6, Block No: 165, S: 503853
# ASR: ASR001, AG: AG123, AN: 6, Block No: 165, S: 882563
# ASR: ASR001, AG: AG123, AN: 6, Block No: 165, S: 415961
# ASR: ASR001, AG: AG123, AN: 6, Block No: 165, S: 345774
# ASR: ASR001, AG: AG123, AN: 6, Block No: 166, S: 201091
# ASR: ASR001, AG: AG123, AN: 6, Block No: 166, S: 984573
# ASR: ASR001, AG: AG123, AN: 6, Block No: 166, S: 916368
# ASR: ASR001, AG: AG123, AN: 6, Block No: 166, S: 815115
# ASR: ASR001, AG: AG123, AN: 6, Block No: 167, S: 306483
# ASR: ASR001, AG: AG123, AN: 6, Block No: 167, S: 246414
# ASR: ASR001, AG: AG123, AN: 6, Block No: 167, S: 343174
# ASR: ASR001, AG: AG123, AN: 6, Block No: 167, S: 773129
# ASR: ASR001, AG: AG123, AN: 6, Block No: 168, S: 445662
# ASR: ASR001, AG: AG123, AN: 6, Block No: 168, S: 969263
# ASR: ASR001, AG: AG123, AN: 6, Block No: 168, S: 192903
# ASR: ASR001, AG: AG123, AN: 6, Block No: 168, S: 887452
# ASR: ASR001, AG: AG123, AN: 6, Block No: 169, S: 14810
# ASR: ASR001, AG: AG123, AN: 6, Block No: 169, S: 152064
# ASR: ASR001, AG: AG123, AN: 6, Block No: 169, S: 715855
# ASR: ASR001, AG: AG123, AN: 6, Block No: 169, S: 464590
# ASR: ASR001, AG: AG123, AN: 6, Block No: 170, S: 533475
# ASR: ASR001, AG: AG123, AN: 6, Block No: 170, S: 602776
# ASR: ASR001, AG: AG123, AN: 6, Block No: 170, S: 918636
# ASR: ASR001, AG: AG123, AN: 6, Block No: 170, S: 788739
# ASR: ASR001, AG: AG123, AN: 6, Block No: 171, S: 422136
# ASR: ASR001, AG: AG123, AN: 6, Block No: 171, S: 766339
# ASR: ASR001, AG: AG123, AN: 6, Block No: 171, S: 772552
# ASR: ASR001, AG: AG123, AN: 6, Block No: 171, S: 355844
# ASR: ASR001, AG: AG123, AN: 6, Block No: 172, S: 308086
# ASR: ASR001, AG: AG123, AN: 6, Block No: 172, S: 153613
# ASR: ASR001, AG: AG123, AN: 6, Block No: 172, S: 766209
# ASR: ASR001, AG: AG123, AN: 6, Block No: 172, S: 653018
# ASR: ASR001, AG: AG123, AN: 6, Block No: 173, S: 802917
# ASR: ASR001, AG: AG123, AN: 6, Block No: 173, S: 870018
# ASR: ASR001, AG: AG123, AN: 6, Block No: 173, S: 46017
# ASR: ASR001, AG: AG123, AN: 6, Block No: 173, S: 860594
# ASR: ASR001, AG: AG123, AN: 6, Block No: 174, S: 49679
# ASR: ASR001, AG: AG123, AN: 6, Block No: 174, S: 569350
# ASR: ASR001, AG: AG123, AN: 6, Block No: 174, S: 669892
# ASR: ASR001, AG: AG123, AN: 6, Block No: 174, S: 175655
# ASR: ASR001, AG: AG123, AN: 6, Block No: 175, S: 46782
# ASR: ASR001, AG: AG123, AN: 6, Block No: 175, S: 608300
# ASR: ASR001, AG: AG123, AN: 6, Block No: 175, S: 457246
# ASR: ASR001, AG: AG123, AN: 6, Block No: 175, S: 284060
# ASR: ASR001, AG: AG123, AN: 6, Block No: 176, S: 525668
# ASR: ASR001, AG: AG123, AN: 6, Block No: 176, S: 510084
# ASR: ASR001, AG: AG123, AN: 6, Block No: 176, S: 208958
# ASR: ASR001, AG: AG123, AN: 6, Block No: 176, S: 900879
# ASR: ASR001, AG: AG123, AN: 6, Block No: 177, S: 19990
# ASR: ASR001, AG: AG123, AN: 6, Block No: 177, S: 659762
# ASR: ASR001, AG: AG123, AN: 6, Block No: 177, S: 316930
# ASR: ASR001, AG: AG123, AN: 6, Block No: 177, S: 316047
# ASR: ASR001, AG: AG123, AN: 6, Block No: 178, S: 410995
# ASR: ASR001, AG: AG123, AN: 6, Block No: 178, S: 696126
# ASR: ASR001, AG: AG123, AN: 6, Block No: 178, S: 705884
# ASR: ASR001, AG: AG123, AN: 6, Block No: 178, S: 249113
# ASR: ASR001, AG: AG123, AN: 6, Block No: 179, S: 967162
# ASR: ASR001, AG: AG123, AN: 6, Block No: 179, S: 166556
# ASR: ASR001, AG: AG123, AN: 6, Block No: 179, S: 651198
# ASR: ASR001, AG: AG123, AN: 6, Block No: 179, S: 934630
# ASR: ASR001, AG: AG123, AN: 6, Block No: 180, S: 920965
# ASR: ASR001, AG: AG123, AN: 6, Block No: 180, S: 604002
# ASR: ASR001, AG: AG123, AN: 6, Block No: 180, S: 654722
# ASR: ASR001, AG: AG123, AN: 6, Block No: 180, S: 35831
# ASR: ASR001, AG: AG123, AN: 6, Block No: 181, S: 51128
# ASR: ASR001, AG: AG123, AN: 6, Block No: 181, S: 229411
# ASR: ASR001, AG: AG123, AN: 6, Block No: 181, S: 681770
# ASR: ASR001, AG: AG123, AN: 6, Block No: 181, S: 50413
# ASR: ASR001, AG: AG123, AN: 6, Block No: 182, S: 282272
# ASR: ASR001, AG: AG123, AN: 6, Block No: 182, S: 556536
# ASR: ASR001, AG: AG123, AN: 6, Block No: 182, S: 175661
# ASR: ASR001, AG: AG123, AN: 6, Block No: 182, S: 773408
# ASR: ASR001, AG: AG123, AN: 6, Block No: 183, S: 911089
# ASR: ASR001, AG: AG123, AN: 6, Block No: 183, S: 616561
# ASR: ASR001, AG: AG123, AN: 6, Block No: 183, S: 349454
# ASR: ASR001, AG: AG123, AN: 6, Block No: 183, S: 443856
# ASR: ASR001, AG: AG123, AN: 6, Block No: 184, S: 674615
# ASR: ASR001, AG: AG123, AN: 6, Block No: 184, S: 528109
# ASR: ASR001, AG: AG123, AN: 6, Block No: 184, S: 955185
# ASR: ASR001, AG: AG123, AN: 6, Block No: 184, S: 887108
# ASR: ASR001, AG: AG123, AN: 6, Block No: 185, S: 372136
# ASR: ASR001, AG: AG123, AN: 6, Block No: 185, S: 901567
# ASR: ASR001, AG: AG123, AN: 6, Block No: 185, S: 872221
# ASR: ASR001, AG: AG123, AN: 6, Block No: 185, S: 668884
# ASR: ASR001, AG: AG123, AN: 6, Block No: 186, S: 862437
# ASR: ASR001, AG: AG123, AN: 6, Block No: 186, S: 715814
# ASR: ASR001, AG: AG123, AN: 6, Block No: 186, S: 887479
# ASR: ASR001, AG: AG123, AN: 6, Block No: 186, S: 763711
# ASR: ASR001, AG: AG123, AN: 6, Block No: 187, S: 848885
# ASR: ASR001, AG: AG123, AN: 6, Block No: 187, S: 4322
# ASR: ASR001, AG: AG123, AN: 6, Block No: 187, S: 541453
# ASR: ASR001, AG: AG123, AN: 6, Block No: 187, S: 71250
# ASR: ASR001, AG: AG123, AN: 6, Block No: 188, S: 545094
# ASR: ASR001, AG: AG123, AN: 6, Block No: 188, S: 290505
# ASR: ASR001, AG: AG123, AN: 6, Block No: 188, S: 750344
# ASR: ASR001, AG: AG123, AN: 6, Block No: 188, S: 426975
# ASR: ASR001, AG: AG123, AN: 6, Block No: 189, S: 557944
# ASR: ASR001, AG: AG123, AN: 6, Block No: 189, S: 647467
# ASR: ASR001, AG: AG123, AN: 6, Block No: 189, S: 303324
# ASR: ASR001, AG: AG123, AN: 6, Block No: 189, S: 646329
# ASR: ASR001, AG: AG123, AN: 6, Block No: 190, S: 913719
# ASR: ASR001, AG: AG123, AN: 6, Block No: 190, S: 316849
# ASR: ASR001, AG: AG123, AN: 6, Block No: 190, S: 405012
# ASR: ASR001, AG: AG123, AN: 6, Block No: 190, S: 58034
# ASR: ASR001, AG: AG123, AN: 6, Block No: 191, S: 188718
# ASR: ASR001, AG: AG123, AN: 6, Block No: 191, S: 670594
# ASR: ASR001, AG: AG123, AN: 6, Block No: 191, S: 73475
# ASR: ASR001, AG: AG123, AN: 6, Block No: 191, S: 768302
# ASR: ASR001, AG: AG123, AN: 6, Block No: 192, S: 280263
# ASR: ASR001, AG: AG123, AN: 6, Block No: 192, S: 123057
# ASR: ASR001, AG: AG123, AN: 6, Block No: 192, S: 946010
# ASR: ASR001, AG: AG123, AN: 6, Block No: 192, S: 36623
# ASR: ASR001, AG: AG123, AN: 6, Block No: 193, S: 212796
# ASR: ASR001, AG: AG123, AN: 6, Block No: 193, S: 579688
# ASR: ASR001, AG: AG123, AN: 6, Block No: 193, S: 859156
# ASR: ASR001, AG: AG123, AN: 6, Block No: 193, S: 294147
# ASR: ASR001, AG: AG123, AN: 6, Block No: 194, S: 870167
# ASR: ASR001, AG: AG123, AN: 6, Block No: 194, S: 652880
# ASR: ASR001, AG: AG123, AN: 6, Block No: 194, S: 52007
# ASR: ASR001, AG: AG123, AN: 6, Block No: 194, S: 381624
# ASR: ASR001, AG: AG123, AN: 6, Block No: 195, S: 574043
# ASR: ASR001, AG: AG123, AN: 6, Block No: 195, S: 71807
# ASR: ASR001, AG: AG123, AN: 6, Block No: 195, S: 867624
# ASR: ASR001, AG: AG123, AN: 6, Block No: 195, S: 253089
# ASR: ASR001, AG: AG123, AN: 6, Block No: 196, S: 347397
# ASR: ASR001, AG: AG123, AN: 6, Block No: 196, S: 98445
# ASR: ASR001, AG: AG123, AN: 6, Block No: 196, S: 401454
# ASR: ASR001, AG: AG123, AN: 6, Block No: 196, S: 890214
# ASR: ASR001, AG: AG123, AN: 6, Block No: 197, S: 943255
# ASR: ASR001, AG: AG123, AN: 6, Block No: 197, S: 661155
# ASR: ASR001, AG: AG123, AN: 6, Block No: 197, S: 618429
# ASR: ASR001, AG: AG123, AN: 6, Block No: 197, S: 747089
# ASR: ASR001, AG: AG123, AN: 6, Block No: 198, S: 472286
# ASR: ASR001, AG: AG123, AN: 6, Block No: 198, S: 919260
# ASR: ASR001, AG: AG123, AN: 6, Block No: 198, S: 31292
# ASR: ASR001, AG: AG123, AN: 6, Block No: 198, S: 869146
# ASR: ASR001, AG: AG123, AN: 6, Block No: 199, S: 596534
# ASR: ASR001, AG: AG123, AN: 6, Block No: 199, S: 746961
# ASR: ASR001, AG: AG123, AN: 6, Block No: 199, S: 203019
# ASR: ASR001, AG: AG123, AN: 6, Block No: 199, S: 314144
# ASR: ASR001, AG: AG123, AN: 6, Block No: 200, S: 823218
# ASR: ASR001, AG: AG123, AN: 6, Block No: 200, S: 321868
# ASR: ASR001, AG: AG123, AN: 6, Block No: 200, S: 485228
# ASR: ASR001, AG: AG123, AN: 6, Block No: 200, S: 218006
# ASR: ASR001, AG: AG123, AN: 6, Block No: 201, S: 936974
# ASR: ASR001, AG: AG123, AN: 6, Block No: 201, S: 285747
# ASR: ASR001, AG: AG123, AN: 6, Block No: 201, S: 679797
# ASR: ASR001, AG: AG123, AN: 6, Block No: 201, S: 7047
# ASR: ASR001, AG: AG123, AN: 6, Block No: 202, S: 718756
# ASR: ASR001, AG: AG123, AN: 6, Block No: 202, S: 176442
# ASR: ASR001, AG: AG123, AN: 6, Block No: 202, S: 520151
# ASR: ASR001, AG: AG123, AN: 6, Block No: 202, S: 196049
# ASR: ASR001, AG: AG123, AN: 6, Block No: 203, S: 761857
# ASR: ASR001, AG: AG123, AN: 6, Block No: 203, S: 168654
# ASR: ASR001, AG: AG123, AN: 6, Block No: 203, S: 954642
# ASR: ASR001, AG: AG123, AN: 6, Block No: 203, S: 194972
# ASR: ASR001, AG: AG123, AN: 6, Block No: 204, S: 866907
# ASR: ASR001, AG: AG123, AN: 6, Block No: 204, S: 692097
# ASR: ASR001, AG: AG123, AN: 6, Block No: 204, S: 858027
# ASR: ASR001, AG: AG123, AN: 6, Block No: 204, S: 204369
# ASR: ASR001, AG: AG123, AN: 6, Block No: 205, S: 583939
# ASR: ASR001, AG: AG123, AN: 6, Block No: 205, S: 725167
# ASR: ASR001, AG: AG123, AN: 6, Block No: 205, S: 680023
# ASR: ASR001, AG: AG123, AN: 6, Block No: 205, S: 1302
# ASR: ASR001, AG: AG123, AN: 6, Block No: 206, S: 358801
# ASR: ASR001, AG: AG123, AN: 6, Block No: 206, S: 860307
# ASR: ASR001, AG: AG123, AN: 6, Block No: 206, S: 518912
# ASR: ASR001, AG: AG123, AN: 6, Block No: 206, S: 472548
# ASR: ASR001, AG: AG123, AN: 6, Block No: 207, S: 247029
# ASR: ASR001, AG: AG123, AN: 6, Block No: 207, S: 935050
# ASR: ASR001, AG: AG123, AN: 6, Block No: 207, S: 56600
# ASR: ASR001, AG: AG123, AN: 6, Block No: 207, S: 447034
# ASR: ASR001, AG: AG123, AN: 6, Block No: 208, S: 972271
# ASR: ASR001, AG: AG123, AN: 6, Block No: 208, S: 275380
# ASR: ASR001, AG: AG123, AN: 6, Block No: 208, S: 607128
# ASR: ASR001, AG: AG123, AN: 6, Block No: 208, S: 724374
# ASR: ASR001, AG: AG123, AN: 6, Block No: 209, S: 510127
# ASR: ASR001, AG: AG123, AN: 6, Block No: 209, S: 95341
# ASR: ASR001, AG: AG123, AN: 6, Block No: 209, S: 444087
# ASR: ASR001, AG: AG123, AN: 6, Block No: 209, S: 860202
# ASR: ASR001, AG: AG123, AN: 6, Block No: 210, S: 72624
# ASR: ASR001, AG: AG123, AN: 6, Block No: 210, S: 901803
# ASR: ASR001, AG: AG123, AN: 6, Block No: 210, S: 563945
# ASR: ASR001, AG: AG123, AN: 6, Block No: 210, S: 623308
# ASR: ASR001, AG: AG123, AN: 6, Block No: 211, S: 587216
# ASR: ASR001, AG: AG123, AN: 6, Block No: 211, S: 57239
# ASR: ASR001, AG: AG123, AN: 6, Block No: 211, S: 256531
# ASR: ASR001, AG: AG123, AN: 6, Block No: 211, S: 527416
# ASR: ASR001, AG: AG123, AN: 6, Block No: 212, S: 362641
# ASR: ASR001, AG: AG123, AN: 6, Block No: 212, S: 487017
# ASR: ASR001, AG: AG123, AN: 6, Block No: 212, S: 328169
# ASR: ASR001, AG: AG123, AN: 6, Block No: 212, S: 799724
# ASR: ASR001, AG: AG123, AN: 6, Block No: 213, S: 866453
# ASR: ASR001, AG: AG123, AN: 6, Block No: 213, S: 116556
# ASR: ASR001, AG: AG123, AN: 6, Block No: 213, S: 438178
# ASR: ASR001, AG: AG123, AN: 6, Block No: 213, S: 424329
# ASR: ASR001, AG: AG123, AN: 6, Block No: 214, S: 422245
# ASR: ASR001, AG: AG123, AN: 6, Block No: 214, S: 393944
# ASR: ASR001, AG: AG123, AN: 6, Block No: 214, S: 813664
# ASR: ASR001, AG: AG123, AN: 6, Block No: 214, S: 74254
# ASR: ASR001, AG: AG123, AN: 6, Block No: 215, S: 913701
# ASR: ASR001, AG: AG123, AN: 6, Block No: 215, S: 853987
# ASR: ASR001, AG: AG123, AN: 6, Block No: 215, S: 143337
# ASR: ASR001, AG: AG123, AN: 6, Block No: 215, S: 425532
# ASR: ASR001, AG: AG123, AN: 6, Block No: 216, S: 591348
# ASR: ASR001, AG: AG123, AN: 6, Block No: 216, S: 704460
# ASR: ASR001, AG: AG123, AN: 6, Block No: 216, S: 974448
# ASR: ASR001, AG: AG123, AN: 6, Block No: 216, S: 124775
# ASR: ASR001, AG: AG123, AN: 6, Block No: 217, S: 943725
# ASR: ASR001, AG: AG123, AN: 6, Block No: 217, S: 942063
# ASR: ASR001, AG: AG123, AN: 6, Block No: 217, S: 888041
# ASR: ASR001, AG: AG123, AN: 6, Block No: 217, S: 808594
# ASR: ASR001, AG: AG123, AN: 6, Block No: 218, S: 947409
# ASR: ASR001, AG: AG123, AN: 6, Block No: 218, S: 121598
# ASR: ASR001, AG: AG123, AN: 6, Block No: 218, S: 320998
# ASR: ASR001, AG: AG123, AN: 6, Block No: 218, S: 307517
# ASR: ASR001, AG: AG123, AN: 6, Block No: 219, S: 684287
# ASR: ASR001, AG: AG123, AN: 6, Block No: 219, S: 144868
# ASR: ASR001, AG: AG123, AN: 6, Block No: 219, S: 877765
# ASR: ASR001, AG: AG123, AN: 6, Block No: 219, S: 92993
# ASR: ASR001, AG: AG123, AN: 6, Block No: 220, S: 988259
# ASR: ASR001, AG: AG123, AN: 6, Block No: 220, S: 225983
# ASR: ASR001, AG: AG123, AN: 6, Block No: 220, S: 913530
# ASR: ASR001, AG: AG123, AN: 6, Block No: 220, S: 162820
# ASR: ASR001, AG: AG123, AN: 6, Block No: 221, S: 127070
# ...
# ASR: ASR001, AG: AG123, AN: 6, Block No: 933, S: 26167
# ASR: ASR001, AG: AG123, AN: 6, Block No: 933, S: 483588
# ASR: ASR001, AG: AG123, AN: 6, Block No: 934, S: 912706
# ASR: ASR001, AG: AG123, AN: 6, Block No: 934, S: 168249
# ASR: ASR001, AG: AG123, AN: 6, Block No: 934, S: 997451
# ASR: ASR001, AG: AG123, AN: 6, Block No: 934, S: 913135
# ASR: ASR001, AG: AG123, AN: 6, Block No: 935, S: 431828
# ASR: ASR001, AG: AG123, AN: 6, Block No: 935, S: 466433
# ASR: ASR001, AG: AG123, AN: 6, Block No: 935, S: 693584
# ASR: ASR001, AG: AG123, AN: 6, Block No: 935, S: 291229
# ASR: ASR001, AG: AG123, AN: 6, Block No: 936, S: 267057
# ASR: ASR001, AG: AG123, AN: 6, Block No: 936, S: 765424
# ASR: ASR001, AG: AG123, AN: 6, Block No: 936, S: 198930
# ASR: ASR001, AG: AG123, AN: 6, Block No: 936, S: 612710
# ASR: ASR001, AG: AG123, AN: 6, Block No: 937, S: 158851
# ASR: ASR001, AG: AG123, AN: 6, Block No: 937, S: 245551
# ASR: ASR001, AG: AG123, AN: 6, Block No: 937, S: 225464
# ASR: ASR001, AG: AG123, AN: 6, Block No: 937, S: 276944
# ASR: ASR001, AG: AG123, AN: 6, Block No: 938, S: 496540
# ASR: ASR001, AG: AG123, AN: 6, Block No: 938, S: 279381
# ASR: ASR001, AG: AG123, AN: 6, Block No: 938, S: 712793
# ASR: ASR001, AG: AG123, AN: 6, Block No: 938, S: 995952
# ASR: ASR001, AG: AG123, AN: 6, Block No: 939, S: 957815
# ASR: ASR001, AG: AG123, AN: 6, Block No: 939, S: 46917
# ASR: ASR001, AG: AG123, AN: 6, Block No: 939, S: 911255
# ASR: ASR001, AG: AG123, AN: 6, Block No: 939, S: 827502
# ASR: ASR001, AG: AG123, AN: 6, Block No: 940, S: 534447
# ASR: ASR001, AG: AG123, AN: 6, Block No: 940, S: 596200
# ASR: ASR001, AG: AG123, AN: 6, Block No: 940, S: 399047
# ASR: ASR001, AG: AG123, AN: 6, Block No: 940, S: 496701
# ASR: ASR001, AG: AG123, AN: 6, Block No: 941, S: 995568
# ASR: ASR001, AG: AG123, AN: 6, Block No: 941, S: 812355
# ASR: ASR001, AG: AG123, AN: 6, Block No: 941, S: 918135
# ASR: ASR001, AG: AG123, AN: 6, Block No: 941, S: 723120
# ASR: ASR001, AG: AG123, AN: 6, Block No: 942, S: 798202
# ASR: ASR001, AG: AG123, AN: 6, Block No: 942, S: 150242
# ASR: ASR001, AG: AG123, AN: 6, Block No: 942, S: 51209
# ASR: ASR001, AG: AG123, AN: 6, Block No: 942, S: 500138
# ASR: ASR001, AG: AG123, AN: 6, Block No: 943, S: 981550
# ASR: ASR001, AG: AG123, AN: 6, Block No: 943, S: 678099
# ASR: ASR001, AG: AG123, AN: 6, Block No: 943, S: 761796
# ASR: ASR001, AG: AG123, AN: 6, Block No: 943, S: 519896
# ASR: ASR001, AG: AG123, AN: 6, Block No: 944, S: 692650
# ASR: ASR001, AG: AG123, AN: 6, Block No: 944, S: 471886
# ASR: ASR001, AG: AG123, AN: 6, Block No: 944, S: 799245
# ASR: ASR001, AG: AG123, AN: 6, Block No: 944, S: 914209
# ASR: ASR001, AG: AG123, AN: 6, Block No: 945, S: 395202
# ASR: ASR001, AG: AG123, AN: 6, Block No: 945, S: 523766
# ASR: ASR001, AG: AG123, AN: 6, Block No: 945, S: 405688
# ASR: ASR001, AG: AG123, AN: 6, Block No: 945, S: 512629
# ASR: ASR001, AG: AG123, AN: 6, Block No: 946, S: 939295
# ASR: ASR001, AG: AG123, AN: 6, Block No: 946, S: 441424
# ASR: ASR001, AG: AG123, AN: 6, Block No: 946, S: 410784
# ASR: ASR001, AG: AG123, AN: 6, Block No: 946, S: 735201
# ASR: ASR001, AG: AG123, AN: 6, Block No: 947, S: 534276
# ASR: ASR001, AG: AG123, AN: 6, Block No: 947, S: 888197
# ASR: ASR001, AG: AG123, AN: 6, Block No: 947, S: 935779
# ASR: ASR001, AG: AG123, AN: 6, Block No: 947, S: 676768
# ASR: ASR001, AG: AG123, AN: 6, Block No: 948, S: 38011
# ASR: ASR001, AG: AG123, AN: 6, Block No: 948, S: 235927
# ASR: ASR001, AG: AG123, AN: 6, Block No: 948, S: 558487
# ASR: ASR001, AG: AG123, AN: 6, Block No: 948, S: 36175
# ASR: ASR001, AG: AG123, AN: 6, Block No: 949, S: 409172
# ASR: ASR001, AG: AG123, AN: 6, Block No: 949, S: 665800
# ASR: ASR001, AG: AG123, AN: 6, Block No: 949, S: 645146
# ASR: ASR001, AG: AG123, AN: 6, Block No: 949, S: 714595
# ASR: ASR001, AG: AG123, AN: 6, Block No: 950, S: 31784
# ASR: ASR001, AG: AG123, AN: 6, Block No: 950, S: 978484
# ASR: ASR001, AG: AG123, AN: 6, Block No: 950, S: 626113
# ASR: ASR001, AG: AG123, AN: 6, Block No: 950, S: 954028
# ASR: ASR001, AG: AG123, AN: 6, Block No: 951, S: 616027
# ASR: ASR001, AG: AG123, AN: 6, Block No: 951, S: 483941
# ASR: ASR001, AG: AG123, AN: 6, Block No: 951, S: 785836
# ASR: ASR001, AG: AG123, AN: 6, Block No: 951, S: 11252
# ASR: ASR001, AG: AG123, AN: 6, Block No: 952, S: 614566
# ASR: ASR001, AG: AG123, AN: 6, Block No: 952, S: 188421
# ASR: ASR001, AG: AG123, AN: 6, Block No: 952, S: 287836
# ASR: ASR001, AG: AG123, AN: 6, Block No: 952, S: 105101
# ASR: ASR001, AG: AG123, AN: 6, Block No: 953, S: 103653
# ASR: ASR001, AG: AG123, AN: 6, Block No: 953, S: 81851
# ASR: ASR001, AG: AG123, AN: 6, Block No: 953, S: 797746
# ASR: ASR001, AG: AG123, AN: 6, Block No: 953, S: 510498
# ASR: ASR001, AG: AG123, AN: 6, Block No: 954, S: 461626
# ASR: ASR001, AG: AG123, AN: 6, Block No: 954, S: 733779
# ASR: ASR001, AG: AG123, AN: 6, Block No: 954, S: 862558
# ASR: ASR001, AG: AG123, AN: 6, Block No: 954, S: 942523
# ASR: ASR001, AG: AG123, AN: 6, Block No: 955, S: 431504
# ASR: ASR001, AG: AG123, AN: 6, Block No: 955, S: 692764
# ASR: ASR001, AG: AG123, AN: 6, Block No: 955, S: 1245
# ASR: ASR001, AG: AG123, AN: 6, Block No: 955, S: 476344
# ASR: ASR001, AG: AG123, AN: 6, Block No: 956, S: 384393
# ASR: ASR001, AG: AG123, AN: 6, Block No: 956, S: 38908
# ASR: ASR001, AG: AG123, AN: 6, Block No: 956, S: 117600
# ASR: ASR001, AG: AG123, AN: 6, Block No: 956, S: 830657
# ASR: ASR001, AG: AG123, AN: 6, Block No: 957, S: 894437
# ASR: ASR001, AG: AG123, AN: 6, Block No: 957, S: 878768
# ASR: ASR001, AG: AG123, AN: 6, Block No: 957, S: 956006
# ASR: ASR001, AG: AG123, AN: 6, Block No: 957, S: 108184
# ASR: ASR001, AG: AG123, AN: 6, Block No: 958, S: 441613
# ASR: ASR001, AG: AG123, AN: 6, Block No: 958, S: 628521
# ASR: ASR001, AG: AG123, AN: 6, Block No: 958, S: 60738
# ASR: ASR001, AG: AG123, AN: 6, Block No: 958, S: 928477
# ASR: ASR001, AG: AG123, AN: 6, Block No: 959, S: 649091
# ASR: ASR001, AG: AG123, AN: 6, Block No: 959, S: 965109
# ASR: ASR001, AG: AG123, AN: 6, Block No: 959, S: 750410
# ASR: ASR001, AG: AG123, AN: 6, Block No: 959, S: 894552
# ASR: ASR001, AG: AG123, AN: 6, Block No: 960, S: 151242
# ASR: ASR001, AG: AG123, AN: 6, Block No: 960, S: 289940
# ASR: ASR001, AG: AG123, AN: 6, Block No: 960, S: 509392
# ASR: ASR001, AG: AG123, AN: 6, Block No: 960, S: 297330
# ASR: ASR001, AG: AG123, AN: 6, Block No: 961, S: 859850
# ASR: ASR001, AG: AG123, AN: 6, Block No: 961, S: 384324
# ASR: ASR001, AG: AG123, AN: 6, Block No: 961, S: 164385
# ASR: ASR001, AG: AG123, AN: 6, Block No: 961, S: 672514
# ASR: ASR001, AG: AG123, AN: 6, Block No: 962, S: 113394
# ASR: ASR001, AG: AG123, AN: 6, Block No: 962, S: 306233
# ASR: ASR001, AG: AG123, AN: 6, Block No: 962, S: 701005
# ASR: ASR001, AG: AG123, AN: 6, Block No: 962, S: 635364
# ASR: ASR001, AG: AG123, AN: 6, Block No: 963, S: 984775
# ASR: ASR001, AG: AG123, AN: 6, Block No: 963, S: 287136
# ASR: ASR001, AG: AG123, AN: 6, Block No: 963, S: 22484
# ASR: ASR001, AG: AG123, AN: 6, Block No: 963, S: 266923
# ASR: ASR001, AG: AG123, AN: 6, Block No: 964, S: 266139
# ASR: ASR001, AG: AG123, AN: 6, Block No: 964, S: 96067
# ASR: ASR001, AG: AG123, AN: 6, Block No: 964, S: 496763
# ASR: ASR001, AG: AG123, AN: 6, Block No: 964, S: 430916
# ASR: ASR001, AG: AG123, AN: 6, Block No: 965, S: 421659
# ASR: ASR001, AG: AG123, AN: 6, Block No: 965, S: 298526
# ASR: ASR001, AG: AG123, AN: 6, Block No: 965, S: 871167
# ASR: ASR001, AG: AG123, AN: 6, Block No: 965, S: 918169
# ASR: ASR001, AG: AG123, AN: 6, Block No: 966, S: 623255
# ASR: ASR001, AG: AG123, AN: 6, Block No: 966, S: 285201
# ASR: ASR001, AG: AG123, AN: 6, Block No: 966, S: 360465
# ASR: ASR001, AG: AG123, AN: 6, Block No: 966, S: 93992
# ASR: ASR001, AG: AG123, AN: 6, Block No: 967, S: 567053
# ASR: ASR001, AG: AG123, AN: 6, Block No: 967, S: 232263
# ASR: ASR001, AG: AG123, AN: 6, Block No: 967, S: 117915
# ASR: ASR001, AG: AG123, AN: 6, Block No: 967, S: 8125
# ASR: ASR001, AG: AG123, AN: 6, Block No: 968, S: 63124
# ASR: ASR001, AG: AG123, AN: 6, Block No: 968, S: 886751
# ASR: ASR001, AG: AG123, AN: 6, Block No: 968, S: 195585
# ASR: ASR001, AG: AG123, AN: 6, Block No: 968, S: 967017
# ASR: ASR001, AG: AG123, AN: 6, Block No: 969, S: 948041
# ASR: ASR001, AG: AG123, AN: 6, Block No: 969, S: 161740
# ASR: ASR001, AG: AG123, AN: 6, Block No: 969, S: 565558
# ASR: ASR001, AG: AG123, AN: 6, Block No: 969, S: 43463
# ASR: ASR001, AG: AG123, AN: 6, Block No: 970, S: 633363
# ASR: ASR001, AG: AG123, AN: 6, Block No: 970, S: 327426
# ASR: ASR001, AG: AG123, AN: 6, Block No: 970, S: 757524
# ASR: ASR001, AG: AG123, AN: 6, Block No: 970, S: 40922
# ASR: ASR001, AG: AG123, AN: 6, Block No: 971, S: 801703
# ASR: ASR001, AG: AG123, AN: 6, Block No: 971, S: 101366
# ASR: ASR001, AG: AG123, AN: 6, Block No: 971, S: 508072
# ASR: ASR001, AG: AG123, AN: 6, Block No: 971, S: 885319
# ASR: ASR001, AG: AG123, AN: 6, Block No: 972, S: 949907
# ASR: ASR001, AG: AG123, AN: 6, Block No: 972, S: 417512
# ASR: ASR001, AG: AG123, AN: 6, Block No: 972, S: 538384
# ASR: ASR001, AG: AG123, AN: 6, Block No: 972, S: 299995
# ASR: ASR001, AG: AG123, AN: 6, Block No: 973, S: 762417
# ASR: ASR001, AG: AG123, AN: 6, Block No: 973, S: 108489
# ASR: ASR001, AG: AG123, AN: 6, Block No: 973, S: 55739
# ASR: ASR001, AG: AG123, AN: 6, Block No: 973, S: 103955
# ASR: ASR001, AG: AG123, AN: 6, Block No: 974, S: 268459
# ASR: ASR001, AG: AG123, AN: 6, Block No: 974, S: 859671
# ASR: ASR001, AG: AG123, AN: 6, Block No: 974, S: 219651
# ASR: ASR001, AG: AG123, AN: 6, Block No: 974, S: 91826
# ASR: ASR001, AG: AG123, AN: 6, Block No: 975, S: 114210
# ASR: ASR001, AG: AG123, AN: 6, Block No: 975, S: 51993
# ASR: ASR001, AG: AG123, AN: 6, Block No: 975, S: 891310
# ASR: ASR001, AG: AG123, AN: 6, Block No: 975, S: 307350
# ASR: ASR001, AG: AG123, AN: 6, Block No: 976, S: 230879
# ASR: ASR001, AG: AG123, AN: 6, Block No: 976, S: 179945
# ASR: ASR001, AG: AG123, AN: 6, Block No: 976, S: 836788
# ASR: ASR001, AG: AG123, AN: 6, Block No: 976, S: 622142
# ASR: ASR001, AG: AG123, AN: 6, Block No: 977, S: 411961
# ASR: ASR001, AG: AG123, AN: 6, Block No: 977, S: 916016
# ASR: ASR001, AG: AG123, AN: 6, Block No: 977, S: 282617
# ASR: ASR001, AG: AG123, AN: 6, Block No: 977, S: 310718
# ASR: ASR001, AG: AG123, AN: 6, Block No: 978, S: 370679
# ASR: ASR001, AG: AG123, AN: 6, Block No: 978, S: 49489
# ASR: ASR001, AG: AG123, AN: 6, Block No: 978, S: 131509
# ASR: ASR001, AG: AG123, AN: 6, Block No: 978, S: 76329
# ASR: ASR001, AG: AG123, AN: 6, Block No: 979, S: 877547
# ASR: ASR001, AG: AG123, AN: 6, Block No: 979, S: 225104
# ASR: ASR001, AG: AG123, AN: 6, Block No: 979, S: 577386
# ASR: ASR001, AG: AG123, AN: 6, Block No: 979, S: 575177
# ASR: ASR001, AG: AG123, AN: 6, Block No: 980, S: 877915
# ASR: ASR001, AG: AG123, AN: 6, Block No: 980, S: 186165
# ASR: ASR001, AG: AG123, AN: 6, Block No: 980, S: 173575
# ASR: ASR001, AG: AG123, AN: 6, Block No: 980, S: 993563
# ASR: ASR001, AG: AG123, AN: 6, Block No: 981, S: 764826
# ASR: ASR001, AG: AG123, AN: 6, Block No: 981, S: 12594
# ASR: ASR001, AG: AG123, AN: 6, Block No: 981, S: 450055
# ASR: ASR001, AG: AG123, AN: 6, Block No: 981, S: 680961
# ASR: ASR001, AG: AG123, AN: 6, Block No: 982, S: 870713
# ASR: ASR001, AG: AG123, AN: 6, Block No: 982, S: 655839
# ASR: ASR001, AG: AG123, AN: 6, Block No: 982, S: 765105
# ASR: ASR001, AG: AG123, AN: 6, Block No: 982, S: 135962
# ASR: ASR001, AG: AG123, AN: 6, Block No: 983, S: 434064
# ASR: ASR001, AG: AG123, AN: 6, Block No: 983, S: 214537
# ASR: ASR001, AG: AG123, AN: 6, Block No: 983, S: 22186
# ASR: ASR001, AG: AG123, AN: 6, Block No: 983, S: 594216
# ASR: ASR001, AG: AG123, AN: 6, Block No: 984, S: 932695
# ASR: ASR001, AG: AG123, AN: 6, Block No: 984, S: 324085
# ASR: ASR001, AG: AG123, AN: 6, Block No: 984, S: 983653
# ASR: ASR001, AG: AG123, AN: 6, Block No: 984, S: 821514
# ASR: ASR001, AG: AG123, AN: 6, Block No: 985, S: 86504
# ASR: ASR001, AG: AG123, AN: 6, Block No: 985, S: 558601
# ASR: ASR001, AG: AG123, AN: 6, Block No: 985, S: 384849
# ASR: ASR001, AG: AG123, AN: 6, Block No: 985, S: 746710
# ASR: ASR001, AG: AG123, AN: 6, Block No: 986, S: 71566
# ASR: ASR001, AG: AG123, AN: 6, Block No: 986, S: 520226
# ASR: ASR001, AG: AG123, AN: 6, Block No: 986, S: 748162
# ASR: ASR001, AG: AG123, AN: 6, Block No: 986, S: 884521
# ASR: ASR001, AG: AG123, AN: 6, Block No: 987, S: 838591
# ASR: ASR001, AG: AG123, AN: 6, Block No: 987, S: 896985
# ASR: ASR001, AG: AG123, AN: 6, Block No: 987, S: 443419
# ASR: ASR001, AG: AG123, AN: 6, Block No: 987, S: 167765
# ASR: ASR001, AG: AG123, AN: 6, Block No: 988, S: 897815
# ASR: ASR001, AG: AG123, AN: 6, Block No: 988, S: 491075
# ASR: ASR001, AG: AG123, AN: 6, Block No: 988, S: 99629
# ASR: ASR001, AG: AG123, AN: 6, Block No: 988, S: 558050
# ASR: ASR001, AG: AG123, AN: 6, Block No: 989, S: 674728
# ASR: ASR001, AG: AG123, AN: 6, Block No: 989, S: 479372
# ASR: ASR001, AG: AG123, AN: 6, Block No: 989, S: 472667
# ASR: ASR001, AG: AG123, AN: 6, Block No: 989, S: 685323
# ASR: ASR001, AG: AG123, AN: 6, Block No: 990, S: 353905
# ASR: ASR001, AG: AG123, AN: 6, Block No: 990, S: 540188
# ASR: ASR001, AG: AG123, AN: 6, Block No: 990, S: 743998
# ASR: ASR001, AG: AG123, AN: 6, Block No: 990, S: 769680
# ASR: ASR001, AG: AG123, AN: 6, Block No: 991, S: 492034
# ASR: ASR001, AG: AG123, AN: 6, Block No: 991, S: 43700
# ASR: ASR001, AG: AG123, AN: 6, Block No: 991, S: 565253
# ASR: ASR001, AG: AG123, AN: 6, Block No: 991, S: 206929
# ASR: ASR001, AG: AG123, AN: 6, Block No: 992, S: 463030
# ASR: ASR001, AG: AG123, AN: 6, Block No: 992, S: 29798
# ASR: ASR001, AG: AG123, AN: 6, Block No: 992, S: 768582
# ASR: ASR001, AG: AG123, AN: 6, Block No: 992, S: 210976
# ASR: ASR001, AG: AG123, AN: 6, Block No: 993, S: 85086
# ASR: ASR001, AG: AG123, AN: 6, Block No: 993, S: 348366
# ASR: ASR001, AG: AG123, AN: 6, Block No: 993, S: 996186
# ASR: ASR001, AG: AG123, AN: 6, Block No: 993, S: 714357
# ASR: ASR001, AG: AG123, AN: 6, Block No: 994, S: 571923
# ASR: ASR001, AG: AG123, AN: 6, Block No: 994, S: 834131
# ASR: ASR001, AG: AG123, AN: 6, Block No: 994, S: 106571
# ASR: ASR001, AG: AG123, AN: 6, Block No: 994, S: 524009
# ASR: ASR001, AG: AG123, AN: 6, Block No: 995, S: 868030
# ASR: ASR001, AG: AG123, AN: 6, Block No: 995, S: 182363
# ASR: ASR001, AG: AG123, AN: 6, Block No: 995, S: 3865
# ASR: ASR001, AG: AG123, AN: 6, Block No: 995, S: 197373
# ASR: ASR001, AG: AG123, AN: 6, Block No: 996, S: 68167
# ASR: ASR001, AG: AG123, AN: 6, Block No: 996, S: 158319
# ASR: ASR001, AG: AG123, AN: 6, Block No: 996, S: 182403
# ASR: ASR001, AG: AG123, AN: 6, Block No: 996, S: 264102
# ASR: ASR001, AG: AG123, AN: 6, Block No: 997, S: 980391
# ASR: ASR001, AG: AG123, AN: 6, Block No: 997, S: 392785
# ASR: ASR001, AG: AG123, AN: 6, Block No: 997, S: 855329
# ASR: ASR001, AG: AG123, AN: 6, Block No: 997, S: 74560
# ASR: ASR001, AG: AG123, AN: 6, Block No: 998, S: 28651
# ASR: ASR001, AG: AG123, AN: 6, Block No: 998, S: 843284
# ASR: ASR001, AG: AG123, AN: 6, Block No: 998, S: 577808
# ASR: ASR001, AG: AG123, AN: 6, Block No: 998, S: 115574
# ASR: ASR001, AG: AG123, AN: 6, Block No: 999, S: 832546
# ASR: ASR001, AG: AG123, AN: 6, Block No: 999, S: 828506
# ASR: ASR001, AG: AG123, AN: 6, Block No: 999, S: 312109
# ASR: ASR001, AG: AG123, AN: 6, Block No: 999, S: 622842
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1000, S: 454203
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1000, S: 646179
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1000, S: 421966
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1000, S: 354677
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1001, S: 639706
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1001, S: 930718
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1001, S: 408155
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1001, S: 280972
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1002, S: 153089
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1002, S: 312029
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1002, S: 228339
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1002, S: 858872
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1003, S: 483100
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1003, S: 517132
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1003, S: 183078
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1003, S: 301569
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1004, S: 567276
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1004, S: 669420
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1004, S: 282682
# ASR: ASR001, AG: AG123, AN: 6, Block No: 1004, S: 172617

# %%
import pandas as pd
import numpy as np

def coss_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, dsout='Alloc', seed=0):
    import sys  # Added import for sys module

    # Check if AN is less than 4
    if AN < 4:
        print("Length of CID number must be at least 4.")
        return

    TrtNo = len(P)
    # Check if the number of treatment regimen ratios matches the number of treatment regimens
    if TrtNo != len(T):
        print("Number of treatment regimen ratios must match the number of treatment regimens.")
        return

    # Check if there is at least one treatment regimen
    if TrtNo == 0:
        print("There must be at least one treatment regimen.")
        return

    # Adjust N if it exceeds the capacity between S and 10^AN
    if N > 10**AN - S:
        N = 10**AN - S

    # Check if N is less than BS
    if N < BS:
        print("Total CID number must be no less than the blocking factor.")
        return

    GrpNo = 0
    for i in range(TrtNo):
        GrpNo += P[i]

    # Check if BS is a multiple of the sum of treatment regimen ratios
    if BS % GrpNo != 0:
        print("Blocking size is not a multiple of the sum of treatment regimen ratios.")
        return

    total = BS * ((N + BS - 1) // BS)
    Blocks = total // BS
    EndNo = N + S - 1
    colen = AN
    cfmt = colen + brf

    ln = 996 // cfmt
    blockmin = BR
    blockmax = blockmin + Blocks - 1
    blkfmt = f"z{brf}"
    bsiz = len(str(BR))

    # Check if the length of Block No# range matches the size given
    if bsiz != brf:
        print("Length of Block No# range must match the size given.")
        return

    # Check if total is equal to BS and BS is greater than 1000
    if total == BS and BS > 1000:
        Grpno = BS // GrpNo

        # Create data for sch1
        sch1_data = []
        for i in range(TrtNo):
            for block_no in range(blockmin, blockmax + 1):
                GROUP = T[i]
                for _ in range(GrpNo):
                    ran = np.random.rand(seed)
                    sch1_data.append([ASR, GROUP, block_no, ran])  # Fixed the column order

        sch1_df = pd.DataFrame(sch1_data, columns=['ASR', 'GROUP', 'block_no', 'ran'])

        # Further processing logic here (use the 'sch1_df' DataFrame)

    else:
        Grps = ''
        for k in range(BS // GrpNo):
            for i in range(TrtNo):
                for j in range(P[i]):
                    Grps += str(T[i])  # Convert T[i] to string

        # Create data for sch1
        sch1_data = []
        alloc = S
        for block_no in range(blockmin, blockmax + 1):
            for _ in range(BS):
                ran = np.random.rand(seed)
                sch1_data.append([block_no, alloc, ran])
                alloc += 1

        sch1_df = pd.DataFrame(sch1_data, columns=['block_no', 'ALLOC', 'ran'])

        # Create data for sch2
        sch2_data = []
        for index, row in sch1_df.iterrows():
            ASR_val = ASR
            AG_val = AG
            ord_val = index % BS
            group_val = Grps[ord_val]
            ALLOC_val = row['ALLOC']
            sch2_data.append([ASR_val, AG_val, row['block_no'], group_val, ALLOC_val])  # Fixed the column order

        sch2_df = pd.DataFrame(sch2_data, columns=['ASR', 'AG', 'block_no', 'GROUP', 'ALLOC'])

        # Further processing logic here (use the 'sch2_df' DataFrame)

    # Sort sch2_df by ASR, block_no, AG, group, and alloc
    sch2_df.sort_values(by=['ASR', 'block_no', 'AG', 'GROUP', 'ALLOC'], inplace=True)

    # Create summary tables
    summary1 = sch2_df.groupby(['ASR', 'AG']).agg({'ALLOC': ['min', 'max', 'nunique']})
    summary2 = sch2_df.groupby(['GROUP']).agg({'ALLOC': ['min', 'max', 'nunique']})

    # Print summary tables
    print("ASR(ASR) AG(AG) Summary")
    print(summary1)

    print("\nASR(ASR) AG(AG) By Treatment Group")
    print(summary2)

    # Create dsout DataFrame
    dsout_data = sch2_df.copy()
    dsout_data['lineno'] = range(1, len(dsout_data) + 1)
    dsout_data['LINETEXT'] = ''
    dsout_data['ERRTEXT'] = ''
    dsout_df = dsout_data[['ASR', 'AG', 'lineno', 'LINETEXT', 'ERRTEXT']]

    # Output dsout_df (you can save it to a CSV or use it as needed)
    dsout_df.to_csv(f'{dsout}.csv', index=False)

    syserr = 0
    if syserr > 0:
        print(f"Proc DBLOAD return code = {syserr}")

# Test the function with sample data
sample_data = {
    "ASR": "ASR001",
    "AG": "AG123",
    "AN": 6,
    "S": 1000,
    "N": 999000,  # Adjusted N to be within the valid range
    "BS": 1000,
    "T": [1, 2, 1],
    "P": [1, 2, 1],
    "BR": 5000,  # Adjusted BR to match the length of 5000
    "brf": 4,    # Adjusted brf to match the length of 4
}

coss_prd(**sample_data)
# Out:
# ASR(ASR) AG(AG) Summary
#              ALLOC
#                min     max nunique
# ASR    AG
# ASR001 AG123  1000  999999  999000
#
# ASR(ASR) AG(AG) By Treatment Group
#       ALLOC
#         min     max nunique
# GROUP
# 1      1000  999999  499500
# 2      1001  999998  499500

# %%
import random
import pandas as pd

def cass_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, Table, dsout, seed):
    """
    Generate a patient component schedule for a clinical trial.

    Args:
        ASR: The ASR (Allocation Schedule Request) ID for the patient component schedule.
        AG: The AG (Allocation Generation set) ID for the patient component schedule.
        AN: The length of the CID (Component ID) number.
        S: The starting CID number.
        N: The total number of CID numbers.
        BS: The blocking factor.
        T: The number of treatment regimens.
        P: The ratios of the treatment regimens.
        BR: The starting block number.
        brf: The length of the block number range.
        Table: The name of the Oracle table where the schedule will be stored.
        dsout: The name of the SAS data set where the schedule will be stored.
        seed: The seed for the random number generator.

    Returns:
        A Pandas DataFrame containing the patient component schedule.
    """

    # Check the input parameters for validity.
    if AN < 4:
        raise ValueError("Length of CID number must be at least 4.")
    if T < 1:
        raise ValueError("There must be at least one treatment regimen.")
    if N < BS:
        raise ValueError("Total CID number must be no less than the blocking factor.")

    # Generate the patient component schedule.
    schedule = pd.DataFrame()
    for i in range(T):
        group_size = P[i]
        for j in range(group_size):
            block_no = random.randint(BR, BR + BS - 1)
            schedule = schedule.append({
                "ASR": ASR,
                "AG": AG,
                "GROUP": i + 1,
                "BLOCK_NO": block_no,
                "CID": S + j + block_no * BS
            }, ignore_index=True)

    # Sort the schedule by block number and treatment regimen.
    schedule = schedule.sort_values(by=["BLOCK_NO", "GROUP"])

    # Return the patient component schedule.
    return schedule

# Example usage:

schedule = cass_prd(ASR="123456",
                    AG="789012",
                    AN=4,
                    S=10000,
                    N=20000,
                    BS=100,
                    T=2,
                    P=[1, 2],
                    BR=1,
                    brf=3,
                    Table="TEMP_ALLOC_DAT_TBL",
                    dsout="Alloc",
                    seed=12345)

# Save the patient component schedule to a CSV file.
#schedule.to_csv("cass_prd.csv", index=False)
schedule
# Out:
# <ipython-input-11-7970d21c863e>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-11-7970d21c863e>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-11-7970d21c863e>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
#       ASR      AG  GROUP  BLOCK_NO    CID
# 2  123456  789012      2        56  15601
# 0  123456  789012      1        62  16200
# 1  123456  789012      2        95  19500

# %%
import random
import pandas as pd

def coss_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, Table, dsout, seed):
    """
    Generate a patient component schedule for a clinical trial.

    Args:
        ASR: The ASR (Allocation Schedule Request) ID for the patient component schedule.
        AG: The AG (Allocation Generation set) ID for the patient component schedule.
        AN: The length of the CID (Component ID) number.
        S: The starting CID number.
        N: The total number of CID numbers.
        BS: The blocking factor.
        T: The number of treatment regimens.
        P: The ratios of the treatment regimens.
        BR: The starting block number.
        brf: The length of the block number range.
        Table: The name of the Oracle table where the schedule will be stored.
        dsout: The name of the SAS data set where the schedule will be stored.
        seed: The seed for the random number generator.

    Returns:
        A Pandas DataFrame containing the patient component schedule.
    """

    # Check the input parameters for validity.
    if AN < 4:
        raise ValueError("Length of CID number must be at least 4.")
    if T < 1:
        raise ValueError("There must be at least one treatment regimen.")
    if N < BS:
        raise ValueError("Total CID number must be no less than blocking factor.")

    # Generate the patient component schedule.
    schedule = pd.DataFrame()
    for i in range(T):
        group_size = P[i]
        for j in range(group_size):
            block_no = random.randint(BR, BR + BS - 1)
            schedule = schedule.append({
                "ASR": ASR,
                "AG": AG,
                "GROUP": i + 1,
                "BLOCK_NO": block_no,
                "CID": S + j + block_no * BS
            }, ignore_index=True)

    # Sort the schedule by block number and treatment regimen.
    schedule = schedule.sort_values(by=["BLOCK_NO", "GROUP"])

    # Return the patient component schedule.
    return schedule

schedule = coss_prd(ASR="123456",
                    AG="789012",
                    AN=4,
                    S=10000,
                    N=10000,
                    BS=10,
                    T=3,
                    P=[1, 2, 3],
                    BR=1,
                    brf=3,
                    Table="TEMP_ALLOC_DAT_TBL",
                    dsout="Alloc",
                    seed=12345)

schedule
# Out:
# <ipython-input-37-dc323f2283bb>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-37-dc323f2283bb>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-37-dc323f2283bb>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-37-dc323f2283bb>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-37-dc323f2283bb>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-37-dc323f2283bb>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
#       ASR      AG  GROUP  BLOCK_NO    CID
# 5  123456  789012      3         2  10022
# 4  123456  789012      3         3  10031
# 3  123456  789012      3         6  10060
# 0  123456  789012      1         7  10070
# 1  123456  789012      2         8  10080
# 2  123456  789012      2        10  10101

# %%
import random
import pandas as pd

def coss_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, Table, dsout, seed):
    """
    Generate a patient component schedule for a clinical trial.

    Args:
        ASR: The ASR (Allocation Schedule Request) ID for the patient component schedule.
        AG: The AG (Allocation Generation set) ID for the patient component schedule.
        AN: The length of the CID (Component ID) number.
        S: The starting CID number.
        N: The total number of CID numbers.
        BS: The blocking factor.
        T: The number of treatment regimens.
        P: The ratios of the treatment regimens.
        BR: The starting block number.
        brf: The length of the block number range.
        Table: The name of the Oracle table where the schedule will be stored.
        dsout: The name of the SAS data set where the schedule will be stored.
        seed: The seed for the random number generator.

    Returns:
        A Pandas DataFrame containing the patient component schedule.
    """

    # Check the input parameters for validity.
    if AN < 4:
        raise ValueError("Length of CID number must be at least 4.")
    if T < 1:
        raise ValueError("There must be at least one treatment regimen.")
    if N < BS:
        raise ValueError("Total CID number must be no less than blocking factor.")

    # Generate the patient component schedule.
    schedule = pd.DataFrame()
    for i in range(T):
        group_size = P[i]
        block_no = random.randint(BR, BR + BS - 1)
        data = [{
            "ASR": ASR,
            "AG": AG,
            "GROUP": i + 1,
            "BLOCK_NO": block_no,
            "CID": S + j + block_no * BS
        } for j in range(group_size)]
        schedule = pd.concat([schedule, pd.DataFrame(data)], ignore_index=True)

    # Sort the schedule by block number and treatment regimen.
    schedule = schedule.sort_values(by=["BLOCK_NO", "GROUP"])

    # Return the patient component schedule.
    return schedule


schedule = coss_prd(ASR="123456",
                    AG="789012",
                    AN=4,
                    S=10000,
                    N=10000,
                    BS=10,
                    T=3,
                    P=[1, 2, 3],
                    BR=1,
                    brf=3,
                    Table="TEMP_ALLOC_DAT_TBL",
                    dsout="Alloc",
                    seed=12345)

print(schedule)
# Out:
#       ASR      AG  GROUP  BLOCK_NO    CID
# 0  123456  789012      1         3  10030
# 3  123456  789012      3         6  10060
# 4  123456  789012      3         6  10061
# 5  123456  789012      3         6  10062
# 1  123456  789012      2        10  10100
# 2  123456  789012      2        10  10101

# %%
import random
import pandas as pd

def cass_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, Table, dsout, seed, index=None):
    """
    Generate a patient component schedule for a clinical trial.

    Args:
        ASR: The ASR (Allocation Schedule Request) ID for the patient component schedule.
        AG: The AG (Allocation Generation set) ID for the patient component schedule.
        AN: The length of the CID (Component ID) number.
        S: The starting CID number.
        N: The total number of CID numbers.
        BS: The blocking factor.
        T: The number of treatment regimens.
        P: The ratios of the treatment regimens.
        BR: The starting block number.
        brf: The length of the block number range.
        Table: The name of the Oracle table where the schedule will be stored.
        dsout: The name of the SAS data set where the schedule will be stored.
        seed: The seed for the random number generator.

    Returns:
        A Pandas DataFrame containing the patient component schedule.
    """

    # Check the input parameters for validity.
    if AN < 4:
        raise ValueError("Length of CID number must be at least 4.")
    if T < 1:
        raise ValueError("There must be at least one treatment regimen.")
    if N < BS:
        raise ValueError("Total CID number must be no less than the blocking factor.")

    # Generate the patient component schedule.
    schedule = pd.DataFrame()
    for i in range(T):
        group_size = P[i]
        for j in range(group_size):
            block_no = random.randint(BR, BR + BS - 1)
            schedule = schedule.append({
                "ASR": ASR,
                "AG": AG,
                "GROUP": i + 1,
                "BLOCK_NO": block_no,
                "CID": S + j + block_no * BS
            }, ignore_index=True)

    # Sort the schedule by block number and treatment regimen.
    schedule = schedule.sort_values(by=["BLOCK_NO", "GROUP"])

    # Return the patient component schedule.
    return schedule.set_index(index)

# %%
schedule = cass_prd(ASR="123456",
                    AG="789012",
                    AN=4,
                    S=10000,
                    N=20000,
                    BS=100,
                    T=2,
                    P=[1, 2],
                    BR=1,
                    brf=3,
                    Table="TEMP_ALLOC_DAT_TBL",
                    dsout="Alloc",
                    seed=12345,
                    index=["row1"])

# Save the patient component schedule to a CSV file.
#schedule.to_csv("cass_prd.csv", index=False)
schedule
# Out:
# <ipython-input-16-a1878cfb7e05>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-16-a1878cfb7e05>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# <ipython-input-16-a1878cfb7e05>:41: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schedule = schedule.append({
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-99aa24d2f4d7> in <cell line: 1>()
# ----> 1 schedule = cass_prd(ASR="123456",
#       2                     AG="789012",
#       3                     AN=4,
#       4                     S=10000,
#       5                     N=20000,
#
# <ipython-input-16-a1878cfb7e05> in cass_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, Table, dsout, seed, index)
#      51
#      52     # Return the patient component schedule.
# ---> 53     return schedule.set_index(index)
#      54
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['row1'] are in the columns"

# %%
import random
import pandas as pd

def coss_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, Table, dsout, seed):
    """
    Generate a patient component schedule for a clinical trial.

    Args:
        ASR: The ASR (Allocation Schedule Request) ID for the patient component schedule.
        AG: The AG (Allocation Generation set) ID for the patient component schedule.
        AN: The length of the CID (Component ID) number.
        S: The starting CID number.
        N: The total number of CID numbers.
        BS: The blocking factor.
        T: The number of treatment regimens.
        P: The ratios of the treatment regimens.
        BR: The starting block number.
        brf: The length of the block number range.
        Table: The name of the Oracle table where the schedule will be stored.
        dsout: The name of the SAS data set where the schedule will be stored.
        seed: The seed for the random number generator.

    Returns:
        A Pandas DataFrame containing the patient component schedule.
    """

    # Check the input parameters for validity.
    if AN < 4:
        raise ValueError("Length of CID number must be at least 4.")
    if T < 1:
        raise ValueError("There must be at least one treatment regimen.")
    if N < BS:
        raise ValueError("Total CID number must be no less than blocking factor.")

    # Generate the patient component schedule.
    schedule = pd.DataFrame()
    for i in range(T):
        group_size = P[i]
        block_no = random.randint(BR, BR + BS - 1)
        data = [{
            "ASR": ASR,
            "AG": AG,
            "GROUP": i + 1,
            "BLOCK_NO": block_no,
            "CID": S + j + block_no * BS
        } for j in range(group_size)]
        schedule = pd.concat([schedule, pd.DataFrame(data)], ignore_index=True)

    # Sort the schedule by block number and treatment regimen.
    schedule = schedule.sort_values(by=["BLOCK_NO", "GROUP"])

    # Return the patient component schedule.
    return schedule


schedule = coss_prd(ASR="123456",
                    AG="789012",
                    AN=4,
                    S=10000,
                    N=10000,
                    BS=10,
                    T=3,
                    P=[1, 2, 3],
                    BR=1,
                    brf=3,
                    Table="TEMP_ALLOC_DAT_TBL",
                    dsout="Alloc",
                    seed=12345)

print(schedule)

import unittest

class CossPrdTest(unittest.TestCase):

    def test_coss_prd(self):
        # Arrange
        input_parameters = {
            "ASR": "123456",
            "AG": "789012",
            "AN": 4,
            "S": 10000,
            "N": 10000,
            "BS": 10,
            "T": 3,
            "P": [1, 2, 3],
            "BR": 1,
            "brf": 3,
            "Table": "TEMP_ALLOC_DAT_TBL",
            "dsout": "Alloc",
            "seed": 12345
        }

        # Act
        output_dataframe = coss_prd(**input_parameters)

        # Assert
        self.assertEqual(output_dataframe.shape[0], 1000)
        self.assertEqual(output_dataframe.shape[1], 5)
        self.assertEqual(list(output_dataframe.columns), ["ASR", "AG", "GROUP", "BLOCK_NO", "CID"])
        self.assertTrue(output_dataframe.sort_values(by=["BLOCK_NO", "GROUP"]).equals(output_dataframe))

if __name__ == "__main__":
    unittest.main()
# Out:
# E
# ======================================================================
# ERROR: /root/ (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute '/root/'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (errors=1)
#       ASR      AG  GROUP  BLOCK_NO    CID
# 1  123456  789012      2         2  10020
# 2  123456  789012      2         2  10021
# 0  123456  789012      1         7  10070
# 3  123456  789012      3         8  10080
# 4  123456  789012      3         8  10081
# 5  123456  789012      3         8  10082
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import unittest

class CossPrdTest(unittest.TestCase):

    def test_coss_prd(self):
        # Arrange
        input_parameters = {
            "ASR": "123456",
            "AG": "789012",
            "AN": 4,
            "S": 10000,
            "N": 10000,
            "BS": 10,
            "T": 3,
            "P": [1, 2, 3],
            "BR": 1,
            "brf": 3,
            "Table": "TEMP_ALLOC_DAT_TBL",
            "dsout": "Alloc",
            "seed": 12345
        }

        # Act
        output_dataframe = coss_prd(**input_parameters)

        # Assert
        self.assertEqual(output_dataframe.shape[0], 1000)
        self.assertEqual(output_dataframe.shape[1], 5)
        self.assertEqual(list(output_dataframe.columns), ["ASR", "AG", "GROUP", "BLOCK_NO", "CID"])
        self.assertTrue(output_dataframe.sort_values(by=["BLOCK_NO", "GROUP"]).equals(output_dataframe))

if __name__ == "__main__":
    unittest.main()
# Out:
# E
# ======================================================================
# ERROR: /root/ (unittest.loader._FailedTest)
# ----------------------------------------------------------------------
# AttributeError: module '__main__' has no attribute '/root/'
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.005s
#
# FAILED (errors=1)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: True
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import random
import time

def coss_prd(ASR, AG, AN, S, N, BS, T, P, BR, brf, seed=0):
    schedules = []

    # Calculate the total number of schedules
    total_schedules = BS * ((N + BS - 1) // BS)

    # Check if the total CID number exceeds the capacity
    if N > 10 ** AN:
        print(f"Total CID number N={N} exceeds the capacity between {S} and {10 ** AN}")
        return schedules

    # Check if the blocking size is a multiple of the sum of treatment regimen ratios
    TrtNo = len(P)
    if TrtNo != len(T):
        print("Number of treatment regimen ratios must match the number of treatment regimens.")
        return schedules

    # Calculate the sum of treatment regimen ratios
    GrpNo = sum(P)

    # Check if the blocking size is a multiple of the sum of treatment regimen ratios
    if BS % GrpNo != 0:
        print("Blocking size is not a multiple of the sum of treatment regimen ratios.")
        return schedules

    # Generate schedules
    start_time = time.time()
    for block_no in range(BR, BR + (total_schedules // BS)):
        for i in range(TrtNo):
            for j in range(P[i]):
                ASR_schedule = ASR
                AG_schedule = AG
                block_schedule = block_no
                S_schedule = S + random.randint(0, 10 ** AN - 1)
                schedules.append((ASR_schedule, AG_schedule, AN, block_schedule, S_schedule))
    end_time = time.time()
    runtime = end_time - start_time

    return schedules, runtime

if __name__ == "__main__":
    # Sample data
    sample_data = {
    "ASR": "ASR001",
    "AG": "AG123",
    "AN": 6,
    "S": 1000,
    "N": 1000000,  # Adjusted N value
    "BS": 1000,
    "T": [1, 2, 1],
    "P": [1, 2, 1],
    "BR": 5,
    "brf": 2,
}

    # Run all test cases
    test_cases = 14
    for test_case_number in range(1, test_cases + 1):
        # Set the seed for the random number generator
        random.seed(test_case_number)

        # Call the coss_prd function with the sample data
        schedules, runtime = coss_prd(**sample_data)

        # Print the test case results
        print(f"Test case {test_case_number} passed: runtime is {runtime:.3f} seconds")
# Out:
# Test case 1 passed: runtime is 0.053 seconds
# Test case 2 passed: runtime is 0.040 seconds
# Test case 3 passed: runtime is 0.052 seconds
# Test case 4 passed: runtime is 0.044 seconds
# Test case 5 passed: runtime is 0.042 seconds
# Test case 6 passed: runtime is 0.035 seconds
# Test case 7 passed: runtime is 0.030 seconds
# Test case 8 passed: runtime is 0.033 seconds
# Test case 9 passed: runtime is 0.028 seconds
# Test case 10 passed: runtime is 0.036 seconds
# Test case 11 passed: runtime is 0.078 seconds
# Test case 12 passed: runtime is 0.071 seconds
# Test case 13 passed: runtime is 0.069 seconds
# Test case 14 passed: runtime is 0.042 seconds
